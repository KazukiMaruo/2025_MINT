# %%
# ~~~~~~~~~~~~~~ Libraries
import sys, os
import mne # Python package for processing and analyzing electrophysiological data
import numpy as np
from glob import glob # look for all the pathnames matching a specified pattern according to the rules
import matplotlib.pyplot as plt
from mne.preprocessing import ICA # ICA (Independent Component Analysis) algorithm, which is for artifact removal
import json
import re
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from scipy.stats import permutation_test
import matplotlib.pyplot as plt
from itertools import combinations
import pandas as pd
import seaborn as sns
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
# ~~~~~~~~~~~~~~ Libraries ~~~~~~~~~~~~~~

# %%
# ~~~~~~~~~~~~~~ Parameters
group = 'baby'
modality = 'visual' # 'visual' or 'audio'

# ML parameters
window_size = 1 # 1 sample = 2ms, 5 samples = 10 ms
n_splits = 10
clf = LogisticRegression(max_iter=2000)

# Print out each parameter
print(f"{modality} data is processed")
print("Machine learning parameters:")
print(f"  Window size: {window_size} samples ({window_size * 2} ms)")
print(f"  Classifier: {clf.__class__.__name__}")
# ~~~~~~~~~~~~~~ Parameters ~~~~~~~~~~~~~~
# Out:
# visual data is processed
# Machine learning parameters:
#   Window size: 1 samples (2 ms)
#   Classifier: LogisticRegression

# %%
# ~~~~~~~~~~~~~~ Set the working directory
path = f"/u/kazma/MINT/data/{group}/interim/{modality}"
sub_folders = [f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]
sub_folders_sorted = sorted(sub_folders, key=lambda x: int(re.search(r'\d+', x).group())) # Sort the folders based on the numeric part after "sub-"
# ~~~~~~~~~~~~~~ Set the working directory ~~~~~~~~~~~~~~

# %%
### SUB_LOOP
subject = sub_folders_sorted[1]

# each subject's file name
sub_filename = os.path.join(path, subject, 'epochs-epo.fif') 
# Load epochs
epochs = mne.read_epochs(sub_filename, preload=True)

# Get the info about the data
conditions = list(epochs.event_id.keys()) # list of conditions
n_conditions = len(conditions) # number of conditions
n_trials = len(epochs) # number of trials
n_samples = epochs.get_data().shape[2]
min_time = epochs.times[0]*1000   # First time point in milli seconds
max_time = epochs.times[-1]*1000    # Last time point in milli seconds

# list for avg accuracy for each time window
all_decoding_accuracy = []
# Out:
# Reading /u/kazma/MINT/data/baby/interim/visual/sub-02/epochs-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 438 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
# ~~~~~~~~~~~~~~ Time point loop
for timepoint in range(n_samples): # Loop over the each time point

    # Initialize the decoding dictionary with each condition containing a list of flattened sample windows
    decoding_dict = {}

    for condition in conditions:
        x = epochs[condition] 
        x = x.get_data() # the shape: (n_trials, n_channels, n_times)
        x = x[:,:,timepoint] # extract one time point = 31 (channels) * 210 (trials)
        decoding_dict[condition] = x

    # Dictionary to store decoding results for each pair
    pairwise_decoding_accuracies = {}

    for i in range(n_conditions):
        for j in range(i + 1, n_conditions):

            cond1 = conditions[i]
            cond2 = conditions[j]
                
            # Prepare data
            data_cond1 = decoding_dict[cond1]
            data_cond2 = decoding_dict[cond2]
            data = np.vstack((data_cond1, data_cond2))
            labels = np.hstack((np.zeros(len(data_cond1)), np.ones(len(data_cond2))))

            # Set cross-validation
            cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42) # StratifiedKFold ensures that each fold has a proportional representation of both classes, so each fold maintains a 50:50 balance of numerosity 1 and numerosity 2 trials.

            # Time-resolved decoding storage
            decoding_accuracies = []

            # Cross-validation
            for train_idx, test_idx in cv.split(data, labels):
                X_train, X_test = data[train_idx], data[test_idx] # the EEG data for training and testing.
                y_train, y_test = labels[train_idx], labels[test_idx] # corresponding labels for the training and testing data.

                # standardization
                scaler = StandardScaler()
                X_train = scaler.fit_transform(X_train) # get mean and standard deviation from this
                X_test = scaler.transform(X_test) # get mean and standard deviation from this

                # Train logistic regression
                clf = LogisticRegression(max_iter=2000)
                clf.fit(X_train, y_train) # trains the classifier on the training data (X_train) with labels (y_train).
                accuracy = clf.score(X_test, y_test)
                decoding_accuracies.append(accuracy) # calculates the classification accuracy by comparing the true labels (y_test) with the predicted labels (y_pred).

            # average the accuracy within a time point
            avg_accuracy = np.mean(decoding_accuracies)

            # Store the average accuracy for the condition pair
            pairwise_decoding_accuracies[(cond1, cond2)] = avg_accuracy

            print(f"Average accuracy for {cond1} vs {cond2} in time points {timepoint}: {avg_accuracy:.2f}")

    # Average accuracy for this time point across CV folds
    all_decoding_accuracy.append(pairwise_decoding_accuracies)
    print(f"Time point {timepoint} is done")
# ~~~~~~~~~~~~~~ WINDOW_LOOP
# Out:
# Average accuracy for numerosity 1 vs numerosity 2 in time points 0: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 0: 0.47
# Average accuracy for numerosity 1 vs numerosity 4 in time points 0: 0.58
# Average accuracy for numerosity 1 vs numerosity 5 in time points 0: 0.40
# Average accuracy for numerosity 1 vs numerosity 6 in time points 0: 0.55
# Average accuracy for numerosity 2 vs numerosity 3 in time points 0: 0.55
# Average accuracy for numerosity 2 vs numerosity 4 in time points 0: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 0: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 0: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 0: 0.53
# Average accuracy for numerosity 3 vs numerosity 5 in time points 0: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 0: 0.53
# Average accuracy for numerosity 4 vs numerosity 5 in time points 0: 0.55
# Average accuracy for numerosity 4 vs numerosity 6 in time points 0: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 0: 0.50
# Time point 0 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 1: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 1: 0.45
# Average accuracy for numerosity 1 vs numerosity 4 in time points 1: 0.60
# Average accuracy for numerosity 1 vs numerosity 5 in time points 1: 0.40
# Average accuracy for numerosity 1 vs numerosity 6 in time points 1: 0.55
# Average accuracy for numerosity 2 vs numerosity 3 in time points 1: 0.56
# Average accuracy for numerosity 2 vs numerosity 4 in time points 1: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 1: 0.54
# Average accuracy for numerosity 2 vs numerosity 6 in time points 1: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 1: 0.54
# Average accuracy for numerosity 3 vs numerosity 5 in time points 1: 0.39
# Average accuracy for numerosity 3 vs numerosity 6 in time points 1: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 1: 0.54
# Average accuracy for numerosity 4 vs numerosity 6 in time points 1: 0.52
# Average accuracy for numerosity 5 vs numerosity 6 in time points 1: 0.51
# Time point 1 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 2: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 2: 0.44
# Average accuracy for numerosity 1 vs numerosity 4 in time points 2: 0.57
# Average accuracy for numerosity 1 vs numerosity 5 in time points 2: 0.42
# Average accuracy for numerosity 1 vs numerosity 6 in time points 2: 0.55
# Average accuracy for numerosity 2 vs numerosity 3 in time points 2: 0.58
# Average accuracy for numerosity 2 vs numerosity 4 in time points 2: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 2: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 2: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 2: 0.55
# Average accuracy for numerosity 3 vs numerosity 5 in time points 2: 0.37
# Average accuracy for numerosity 3 vs numerosity 6 in time points 2: 0.48
# Average accuracy for numerosity 4 vs numerosity 5 in time points 2: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 2: 0.52
# Average accuracy for numerosity 5 vs numerosity 6 in time points 2: 0.48
# Time point 2 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 3: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 3: 0.44
# Average accuracy for numerosity 1 vs numerosity 4 in time points 3: 0.57
# Average accuracy for numerosity 1 vs numerosity 5 in time points 3: 0.39
# Average accuracy for numerosity 1 vs numerosity 6 in time points 3: 0.55
# Average accuracy for numerosity 2 vs numerosity 3 in time points 3: 0.57
# Average accuracy for numerosity 2 vs numerosity 4 in time points 3: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 3: 0.56
# Average accuracy for numerosity 2 vs numerosity 6 in time points 3: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 3: 0.55
# Average accuracy for numerosity 3 vs numerosity 5 in time points 3: 0.39
# Average accuracy for numerosity 3 vs numerosity 6 in time points 3: 0.48
# Average accuracy for numerosity 4 vs numerosity 5 in time points 3: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 3: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 3: 0.48
# Time point 3 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 4: 0.54
# Average accuracy for numerosity 1 vs numerosity 3 in time points 4: 0.43
# Average accuracy for numerosity 1 vs numerosity 4 in time points 4: 0.58
# Average accuracy for numerosity 1 vs numerosity 5 in time points 4: 0.40
# Average accuracy for numerosity 1 vs numerosity 6 in time points 4: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 4: 0.59
# Average accuracy for numerosity 2 vs numerosity 4 in time points 4: 0.46
# Average accuracy for numerosity 2 vs numerosity 5 in time points 4: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 4: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 4: 0.58
# Average accuracy for numerosity 3 vs numerosity 5 in time points 4: 0.40
# Average accuracy for numerosity 3 vs numerosity 6 in time points 4: 0.44
# Average accuracy for numerosity 4 vs numerosity 5 in time points 4: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 4: 0.54
# Average accuracy for numerosity 5 vs numerosity 6 in time points 4: 0.48
# Time point 4 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 5: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 5: 0.40
# Average accuracy for numerosity 1 vs numerosity 4 in time points 5: 0.59
# Average accuracy for numerosity 1 vs numerosity 5 in time points 5: 0.42
# Average accuracy for numerosity 1 vs numerosity 6 in time points 5: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 5: 0.60
# Average accuracy for numerosity 2 vs numerosity 4 in time points 5: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 5: 0.56
# Average accuracy for numerosity 2 vs numerosity 6 in time points 5: 0.53
# Average accuracy for numerosity 3 vs numerosity 4 in time points 5: 0.55
# Average accuracy for numerosity 3 vs numerosity 5 in time points 5: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 5: 0.42
# Average accuracy for numerosity 4 vs numerosity 5 in time points 5: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 5: 0.56
# Average accuracy for numerosity 5 vs numerosity 6 in time points 5: 0.45
# Time point 5 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 6: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 6: 0.38
# Average accuracy for numerosity 1 vs numerosity 4 in time points 6: 0.58
# Average accuracy for numerosity 1 vs numerosity 5 in time points 6: 0.42
# Average accuracy for numerosity 1 vs numerosity 6 in time points 6: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 6: 0.58
# Average accuracy for numerosity 2 vs numerosity 4 in time points 6: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 6: 0.58
# Average accuracy for numerosity 2 vs numerosity 6 in time points 6: 0.55
# Average accuracy for numerosity 3 vs numerosity 4 in time points 6: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 6: 0.40
# Average accuracy for numerosity 3 vs numerosity 6 in time points 6: 0.46
# Average accuracy for numerosity 4 vs numerosity 5 in time points 6: 0.53
# Average accuracy for numerosity 4 vs numerosity 6 in time points 6: 0.59
# Average accuracy for numerosity 5 vs numerosity 6 in time points 6: 0.45
# Time point 6 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 7: 0.54
# Average accuracy for numerosity 1 vs numerosity 3 in time points 7: 0.35
# Average accuracy for numerosity 1 vs numerosity 4 in time points 7: 0.55
# Average accuracy for numerosity 1 vs numerosity 5 in time points 7: 0.42
# Average accuracy for numerosity 1 vs numerosity 6 in time points 7: 0.46
# Average accuracy for numerosity 2 vs numerosity 3 in time points 7: 0.58
# Average accuracy for numerosity 2 vs numerosity 4 in time points 7: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 7: 0.56
# Average accuracy for numerosity 2 vs numerosity 6 in time points 7: 0.57
# Average accuracy for numerosity 3 vs numerosity 4 in time points 7: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 7: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 7: 0.45
# Average accuracy for numerosity 4 vs numerosity 5 in time points 7: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 7: 0.58
# Average accuracy for numerosity 5 vs numerosity 6 in time points 7: 0.48
# Time point 7 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 8: 0.55
# Average accuracy for numerosity 1 vs numerosity 3 in time points 8: 0.32
# Average accuracy for numerosity 1 vs numerosity 4 in time points 8: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 8: 0.42
# Average accuracy for numerosity 1 vs numerosity 6 in time points 8: 0.46
# Average accuracy for numerosity 2 vs numerosity 3 in time points 8: 0.58
# Average accuracy for numerosity 2 vs numerosity 4 in time points 8: 0.56
# Average accuracy for numerosity 2 vs numerosity 5 in time points 8: 0.58
# Average accuracy for numerosity 2 vs numerosity 6 in time points 8: 0.56
# Average accuracy for numerosity 3 vs numerosity 4 in time points 8: 0.53
# Average accuracy for numerosity 3 vs numerosity 5 in time points 8: 0.43
# Average accuracy for numerosity 3 vs numerosity 6 in time points 8: 0.44
# Average accuracy for numerosity 4 vs numerosity 5 in time points 8: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 8: 0.57
# Average accuracy for numerosity 5 vs numerosity 6 in time points 8: 0.49
# Time point 8 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 9: 0.57
# Average accuracy for numerosity 1 vs numerosity 3 in time points 9: 0.31
# Average accuracy for numerosity 1 vs numerosity 4 in time points 9: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 9: 0.44
# Average accuracy for numerosity 1 vs numerosity 6 in time points 9: 0.49
# Average accuracy for numerosity 2 vs numerosity 3 in time points 9: 0.54
# Average accuracy for numerosity 2 vs numerosity 4 in time points 9: 0.55
# Average accuracy for numerosity 2 vs numerosity 5 in time points 9: 0.56
# Average accuracy for numerosity 2 vs numerosity 6 in time points 9: 0.55
# Average accuracy for numerosity 3 vs numerosity 4 in time points 9: 0.53
# Average accuracy for numerosity 3 vs numerosity 5 in time points 9: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 9: 0.44
# Average accuracy for numerosity 4 vs numerosity 5 in time points 9: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 9: 0.58
# Average accuracy for numerosity 5 vs numerosity 6 in time points 9: 0.49
# Time point 9 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 10: 0.58
# Average accuracy for numerosity 1 vs numerosity 3 in time points 10: 0.33
# Average accuracy for numerosity 1 vs numerosity 4 in time points 10: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 10: 0.47
# Average accuracy for numerosity 1 vs numerosity 6 in time points 10: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 10: 0.53
# Average accuracy for numerosity 2 vs numerosity 4 in time points 10: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 10: 0.57
# Average accuracy for numerosity 2 vs numerosity 6 in time points 10: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 10: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 10: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 10: 0.47
# Average accuracy for numerosity 4 vs numerosity 5 in time points 10: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 10: 0.57
# Average accuracy for numerosity 5 vs numerosity 6 in time points 10: 0.48
# Time point 10 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 11: 0.58
# Average accuracy for numerosity 1 vs numerosity 3 in time points 11: 0.36
# Average accuracy for numerosity 1 vs numerosity 4 in time points 11: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 11: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 11: 0.56
# Average accuracy for numerosity 2 vs numerosity 3 in time points 11: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 11: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 11: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 11: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 11: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 11: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 11: 0.48
# Average accuracy for numerosity 4 vs numerosity 5 in time points 11: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 11: 0.54
# Average accuracy for numerosity 5 vs numerosity 6 in time points 11: 0.45
# Time point 11 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 12: 0.60
# Average accuracy for numerosity 1 vs numerosity 3 in time points 12: 0.43
# Average accuracy for numerosity 1 vs numerosity 4 in time points 12: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 12: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 12: 0.55
# Average accuracy for numerosity 2 vs numerosity 3 in time points 12: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 12: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 12: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 12: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 12: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 12: 0.38
# Average accuracy for numerosity 3 vs numerosity 6 in time points 12: 0.46
# Average accuracy for numerosity 4 vs numerosity 5 in time points 12: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 12: 0.57
# Average accuracy for numerosity 5 vs numerosity 6 in time points 12: 0.46
# Time point 12 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 13: 0.64
# Average accuracy for numerosity 1 vs numerosity 3 in time points 13: 0.45
# Average accuracy for numerosity 1 vs numerosity 4 in time points 13: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 13: 0.53
# Average accuracy for numerosity 1 vs numerosity 6 in time points 13: 0.55
# Average accuracy for numerosity 2 vs numerosity 3 in time points 13: 0.53
# Average accuracy for numerosity 2 vs numerosity 4 in time points 13: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 13: 0.53
# Average accuracy for numerosity 2 vs numerosity 6 in time points 13: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 13: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 13: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 13: 0.47
# Average accuracy for numerosity 4 vs numerosity 5 in time points 13: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 13: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 13: 0.47
# Time point 13 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 14: 0.63
# Average accuracy for numerosity 1 vs numerosity 3 in time points 14: 0.48
# Average accuracy for numerosity 1 vs numerosity 4 in time points 14: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 14: 0.55
# Average accuracy for numerosity 1 vs numerosity 6 in time points 14: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 14: 0.53
# Average accuracy for numerosity 2 vs numerosity 4 in time points 14: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 14: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 14: 0.54
# Average accuracy for numerosity 3 vs numerosity 4 in time points 14: 0.45
# Average accuracy for numerosity 3 vs numerosity 5 in time points 14: 0.39
# Average accuracy for numerosity 3 vs numerosity 6 in time points 14: 0.46
# Average accuracy for numerosity 4 vs numerosity 5 in time points 14: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 14: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 14: 0.44
# Time point 14 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 15: 0.62
# Average accuracy for numerosity 1 vs numerosity 3 in time points 15: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 15: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 15: 0.55
# Average accuracy for numerosity 1 vs numerosity 6 in time points 15: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 15: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 15: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 15: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 15: 0.54
# Average accuracy for numerosity 3 vs numerosity 4 in time points 15: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 15: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 15: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 15: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 15: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 15: 0.46
# Time point 15 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 16: 0.61
# Average accuracy for numerosity 1 vs numerosity 3 in time points 16: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 16: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 16: 0.55
# Average accuracy for numerosity 1 vs numerosity 6 in time points 16: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 16: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 16: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 16: 0.48
# Average accuracy for numerosity 2 vs numerosity 6 in time points 16: 0.53
# Average accuracy for numerosity 3 vs numerosity 4 in time points 16: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 16: 0.42
# Average accuracy for numerosity 3 vs numerosity 6 in time points 16: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 16: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 16: 0.52
# Average accuracy for numerosity 5 vs numerosity 6 in time points 16: 0.49
# Time point 16 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 17: 0.60
# Average accuracy for numerosity 1 vs numerosity 3 in time points 17: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 17: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 17: 0.54
# Average accuracy for numerosity 1 vs numerosity 6 in time points 17: 0.49
# Average accuracy for numerosity 2 vs numerosity 3 in time points 17: 0.53
# Average accuracy for numerosity 2 vs numerosity 4 in time points 17: 0.54
# Average accuracy for numerosity 2 vs numerosity 5 in time points 17: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 17: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 17: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 17: 0.39
# Average accuracy for numerosity 3 vs numerosity 6 in time points 17: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 17: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 17: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 17: 0.47
# Time point 17 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 18: 0.60
# Average accuracy for numerosity 1 vs numerosity 3 in time points 18: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 18: 0.58
# Average accuracy for numerosity 1 vs numerosity 5 in time points 18: 0.54
# Average accuracy for numerosity 1 vs numerosity 6 in time points 18: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 18: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 18: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 18: 0.53
# Average accuracy for numerosity 2 vs numerosity 6 in time points 18: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 18: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 18: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 18: 0.54
# Average accuracy for numerosity 4 vs numerosity 5 in time points 18: 0.47
# Average accuracy for numerosity 4 vs numerosity 6 in time points 18: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 18: 0.47
# Time point 18 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 19: 0.60
# Average accuracy for numerosity 1 vs numerosity 3 in time points 19: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 19: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 19: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 19: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 19: 0.48
# Average accuracy for numerosity 2 vs numerosity 4 in time points 19: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 19: 0.54
# Average accuracy for numerosity 2 vs numerosity 6 in time points 19: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 19: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 19: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 19: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 19: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 19: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 19: 0.46
# Time point 19 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 20: 0.59
# Average accuracy for numerosity 1 vs numerosity 3 in time points 20: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 20: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 20: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 20: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 20: 0.43
# Average accuracy for numerosity 2 vs numerosity 4 in time points 20: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 20: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 20: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 20: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 20: 0.44
# Average accuracy for numerosity 3 vs numerosity 6 in time points 20: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 20: 0.44
# Average accuracy for numerosity 4 vs numerosity 6 in time points 20: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 20: 0.44
# Time point 20 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 21: 0.57
# Average accuracy for numerosity 1 vs numerosity 3 in time points 21: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 21: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 21: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 21: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 21: 0.43
# Average accuracy for numerosity 2 vs numerosity 4 in time points 21: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 21: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 21: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 21: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 21: 0.44
# Average accuracy for numerosity 3 vs numerosity 6 in time points 21: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 21: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 21: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 21: 0.45
# Time point 21 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 22: 0.55
# Average accuracy for numerosity 1 vs numerosity 3 in time points 22: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 22: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 22: 0.49
# Average accuracy for numerosity 1 vs numerosity 6 in time points 22: 0.55
# Average accuracy for numerosity 2 vs numerosity 3 in time points 22: 0.42
# Average accuracy for numerosity 2 vs numerosity 4 in time points 22: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 22: 0.46
# Average accuracy for numerosity 2 vs numerosity 6 in time points 22: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 22: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 22: 0.42
# Average accuracy for numerosity 3 vs numerosity 6 in time points 22: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 22: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 22: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 22: 0.47
# Time point 22 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 23: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 23: 0.49
# Average accuracy for numerosity 1 vs numerosity 4 in time points 23: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 23: 0.49
# Average accuracy for numerosity 1 vs numerosity 6 in time points 23: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 23: 0.42
# Average accuracy for numerosity 2 vs numerosity 4 in time points 23: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 23: 0.46
# Average accuracy for numerosity 2 vs numerosity 6 in time points 23: 0.44
# Average accuracy for numerosity 3 vs numerosity 4 in time points 23: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 23: 0.45
# Average accuracy for numerosity 3 vs numerosity 6 in time points 23: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 23: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 23: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 23: 0.47
# Time point 23 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 24: 0.47
# Average accuracy for numerosity 1 vs numerosity 3 in time points 24: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 24: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 24: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 24: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 24: 0.44
# Average accuracy for numerosity 2 vs numerosity 4 in time points 24: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 24: 0.46
# Average accuracy for numerosity 2 vs numerosity 6 in time points 24: 0.44
# Average accuracy for numerosity 3 vs numerosity 4 in time points 24: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 24: 0.44
# Average accuracy for numerosity 3 vs numerosity 6 in time points 24: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 24: 0.46
# Average accuracy for numerosity 4 vs numerosity 6 in time points 24: 0.52
# Average accuracy for numerosity 5 vs numerosity 6 in time points 24: 0.47
# Time point 24 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 25: 0.43
# Average accuracy for numerosity 1 vs numerosity 3 in time points 25: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 25: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 25: 0.45
# Average accuracy for numerosity 1 vs numerosity 6 in time points 25: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 25: 0.47
# Average accuracy for numerosity 2 vs numerosity 4 in time points 25: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 25: 0.48
# Average accuracy for numerosity 2 vs numerosity 6 in time points 25: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 25: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 25: 0.43
# Average accuracy for numerosity 3 vs numerosity 6 in time points 25: 0.54
# Average accuracy for numerosity 4 vs numerosity 5 in time points 25: 0.42
# Average accuracy for numerosity 4 vs numerosity 6 in time points 25: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 25: 0.46
# Time point 25 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 26: 0.42
# Average accuracy for numerosity 1 vs numerosity 3 in time points 26: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 26: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 26: 0.46
# Average accuracy for numerosity 1 vs numerosity 6 in time points 26: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 26: 0.47
# Average accuracy for numerosity 2 vs numerosity 4 in time points 26: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 26: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 26: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 26: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 26: 0.46
# Average accuracy for numerosity 3 vs numerosity 6 in time points 26: 0.57
# Average accuracy for numerosity 4 vs numerosity 5 in time points 26: 0.47
# Average accuracy for numerosity 4 vs numerosity 6 in time points 26: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 26: 0.40
# Time point 26 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 27: 0.38
# Average accuracy for numerosity 1 vs numerosity 3 in time points 27: 0.48
# Average accuracy for numerosity 1 vs numerosity 4 in time points 27: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 27: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 27: 0.47
# Average accuracy for numerosity 2 vs numerosity 3 in time points 27: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 27: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 27: 0.54
# Average accuracy for numerosity 2 vs numerosity 6 in time points 27: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 27: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 27: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 27: 0.55
# Average accuracy for numerosity 4 vs numerosity 5 in time points 27: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 27: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 27: 0.40
# Time point 27 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 28: 0.39
# Average accuracy for numerosity 1 vs numerosity 3 in time points 28: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 28: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 28: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 28: 0.43
# Average accuracy for numerosity 2 vs numerosity 3 in time points 28: 0.54
# Average accuracy for numerosity 2 vs numerosity 4 in time points 28: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 28: 0.54
# Average accuracy for numerosity 2 vs numerosity 6 in time points 28: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 28: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 28: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 28: 0.54
# Average accuracy for numerosity 4 vs numerosity 5 in time points 28: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 28: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 28: 0.44
# Time point 28 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 29: 0.39
# Average accuracy for numerosity 1 vs numerosity 3 in time points 29: 0.48
# Average accuracy for numerosity 1 vs numerosity 4 in time points 29: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 29: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 29: 0.45
# Average accuracy for numerosity 2 vs numerosity 3 in time points 29: 0.57
# Average accuracy for numerosity 2 vs numerosity 4 in time points 29: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 29: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 29: 0.45
# Average accuracy for numerosity 3 vs numerosity 4 in time points 29: 0.54
# Average accuracy for numerosity 3 vs numerosity 5 in time points 29: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 29: 0.56
# Average accuracy for numerosity 4 vs numerosity 5 in time points 29: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 29: 0.58
# Average accuracy for numerosity 5 vs numerosity 6 in time points 29: 0.46
# Time point 29 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 30: 0.42
# Average accuracy for numerosity 1 vs numerosity 3 in time points 30: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 30: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 30: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 30: 0.42
# Average accuracy for numerosity 2 vs numerosity 3 in time points 30: 0.56
# Average accuracy for numerosity 2 vs numerosity 4 in time points 30: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 30: 0.54
# Average accuracy for numerosity 2 vs numerosity 6 in time points 30: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 30: 0.54
# Average accuracy for numerosity 3 vs numerosity 5 in time points 30: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 30: 0.56
# Average accuracy for numerosity 4 vs numerosity 5 in time points 30: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 30: 0.58
# Average accuracy for numerosity 5 vs numerosity 6 in time points 30: 0.47
# Time point 30 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 31: 0.45
# Average accuracy for numerosity 1 vs numerosity 3 in time points 31: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 31: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 31: 0.48
# Average accuracy for numerosity 1 vs numerosity 6 in time points 31: 0.41
# Average accuracy for numerosity 2 vs numerosity 3 in time points 31: 0.57
# Average accuracy for numerosity 2 vs numerosity 4 in time points 31: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 31: 0.54
# Average accuracy for numerosity 2 vs numerosity 6 in time points 31: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 31: 0.55
# Average accuracy for numerosity 3 vs numerosity 5 in time points 31: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 31: 0.54
# Average accuracy for numerosity 4 vs numerosity 5 in time points 31: 0.53
# Average accuracy for numerosity 4 vs numerosity 6 in time points 31: 0.56
# Average accuracy for numerosity 5 vs numerosity 6 in time points 31: 0.45
# Time point 31 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 32: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 32: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 32: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 32: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 32: 0.41
# Average accuracy for numerosity 2 vs numerosity 3 in time points 32: 0.57
# Average accuracy for numerosity 2 vs numerosity 4 in time points 32: 0.55
# Average accuracy for numerosity 2 vs numerosity 5 in time points 32: 0.56
# Average accuracy for numerosity 2 vs numerosity 6 in time points 32: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 32: 0.58
# Average accuracy for numerosity 3 vs numerosity 5 in time points 32: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 32: 0.53
# Average accuracy for numerosity 4 vs numerosity 5 in time points 32: 0.55
# Average accuracy for numerosity 4 vs numerosity 6 in time points 32: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 32: 0.47
# Time point 32 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 33: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 33: 0.42
# Average accuracy for numerosity 1 vs numerosity 4 in time points 33: 0.46
# Average accuracy for numerosity 1 vs numerosity 5 in time points 33: 0.48
# Average accuracy for numerosity 1 vs numerosity 6 in time points 33: 0.45
# Average accuracy for numerosity 2 vs numerosity 3 in time points 33: 0.55
# Average accuracy for numerosity 2 vs numerosity 4 in time points 33: 0.54
# Average accuracy for numerosity 2 vs numerosity 5 in time points 33: 0.58
# Average accuracy for numerosity 2 vs numerosity 6 in time points 33: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 33: 0.53
# Average accuracy for numerosity 3 vs numerosity 5 in time points 33: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 33: 0.53
# Average accuracy for numerosity 4 vs numerosity 5 in time points 33: 0.53
# Average accuracy for numerosity 4 vs numerosity 6 in time points 33: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 33: 0.44
# Time point 33 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 34: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 34: 0.45
# Average accuracy for numerosity 1 vs numerosity 4 in time points 34: 0.45
# Average accuracy for numerosity 1 vs numerosity 5 in time points 34: 0.47
# Average accuracy for numerosity 1 vs numerosity 6 in time points 34: 0.46
# Average accuracy for numerosity 2 vs numerosity 3 in time points 34: 0.57
# Average accuracy for numerosity 2 vs numerosity 4 in time points 34: 0.54
# Average accuracy for numerosity 2 vs numerosity 5 in time points 34: 0.56
# Average accuracy for numerosity 2 vs numerosity 6 in time points 34: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 34: 0.55
# Average accuracy for numerosity 3 vs numerosity 5 in time points 34: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 34: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 34: 0.55
# Average accuracy for numerosity 4 vs numerosity 6 in time points 34: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 34: 0.45
# Time point 34 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 35: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 35: 0.45
# Average accuracy for numerosity 1 vs numerosity 4 in time points 35: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 35: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 35: 0.46
# Average accuracy for numerosity 2 vs numerosity 3 in time points 35: 0.56
# Average accuracy for numerosity 2 vs numerosity 4 in time points 35: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 35: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 35: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 35: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 35: 0.41
# Average accuracy for numerosity 3 vs numerosity 6 in time points 35: 0.45
# Average accuracy for numerosity 4 vs numerosity 5 in time points 35: 0.55
# Average accuracy for numerosity 4 vs numerosity 6 in time points 35: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 35: 0.43
# Time point 35 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 36: 0.56
# Average accuracy for numerosity 1 vs numerosity 3 in time points 36: 0.47
# Average accuracy for numerosity 1 vs numerosity 4 in time points 36: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 36: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 36: 0.47
# Average accuracy for numerosity 2 vs numerosity 3 in time points 36: 0.54
# Average accuracy for numerosity 2 vs numerosity 4 in time points 36: 0.55
# Average accuracy for numerosity 2 vs numerosity 5 in time points 36: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 36: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 36: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 36: 0.44
# Average accuracy for numerosity 3 vs numerosity 6 in time points 36: 0.44
# Average accuracy for numerosity 4 vs numerosity 5 in time points 36: 0.55
# Average accuracy for numerosity 4 vs numerosity 6 in time points 36: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 36: 0.39
# Time point 36 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 37: 0.59
# Average accuracy for numerosity 1 vs numerosity 3 in time points 37: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 37: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 37: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 37: 0.43
# Average accuracy for numerosity 2 vs numerosity 3 in time points 37: 0.54
# Average accuracy for numerosity 2 vs numerosity 4 in time points 37: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 37: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 37: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 37: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 37: 0.44
# Average accuracy for numerosity 3 vs numerosity 6 in time points 37: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 37: 0.54
# Average accuracy for numerosity 4 vs numerosity 6 in time points 37: 0.48
# Average accuracy for numerosity 5 vs numerosity 6 in time points 37: 0.41
# Time point 37 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 38: 0.62
# Average accuracy for numerosity 1 vs numerosity 3 in time points 38: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 38: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 38: 0.48
# Average accuracy for numerosity 1 vs numerosity 6 in time points 38: 0.43
# Average accuracy for numerosity 2 vs numerosity 3 in time points 38: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 38: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 38: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 38: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 38: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 38: 0.42
# Average accuracy for numerosity 3 vs numerosity 6 in time points 38: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 38: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 38: 0.47
# Average accuracy for numerosity 5 vs numerosity 6 in time points 38: 0.41
# Time point 38 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 39: 0.58
# Average accuracy for numerosity 1 vs numerosity 3 in time points 39: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 39: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 39: 0.47
# Average accuracy for numerosity 1 vs numerosity 6 in time points 39: 0.45
# Average accuracy for numerosity 2 vs numerosity 3 in time points 39: 0.54
# Average accuracy for numerosity 2 vs numerosity 4 in time points 39: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 39: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 39: 0.53
# Average accuracy for numerosity 3 vs numerosity 4 in time points 39: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 39: 0.43
# Average accuracy for numerosity 3 vs numerosity 6 in time points 39: 0.54
# Average accuracy for numerosity 4 vs numerosity 5 in time points 39: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 39: 0.47
# Average accuracy for numerosity 5 vs numerosity 6 in time points 39: 0.38
# Time point 39 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 40: 0.57
# Average accuracy for numerosity 1 vs numerosity 3 in time points 40: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 40: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 40: 0.44
# Average accuracy for numerosity 1 vs numerosity 6 in time points 40: 0.47
# Average accuracy for numerosity 2 vs numerosity 3 in time points 40: 0.55
# Average accuracy for numerosity 2 vs numerosity 4 in time points 40: 0.47
# Average accuracy for numerosity 2 vs numerosity 5 in time points 40: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 40: 0.54
# Average accuracy for numerosity 3 vs numerosity 4 in time points 40: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 40: 0.44
# Average accuracy for numerosity 3 vs numerosity 6 in time points 40: 0.54
# Average accuracy for numerosity 4 vs numerosity 5 in time points 40: 0.44
# Average accuracy for numerosity 4 vs numerosity 6 in time points 40: 0.46
# Average accuracy for numerosity 5 vs numerosity 6 in time points 40: 0.37
# Time point 40 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 41: 0.57
# Average accuracy for numerosity 1 vs numerosity 3 in time points 41: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 41: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 41: 0.46
# Average accuracy for numerosity 1 vs numerosity 6 in time points 41: 0.42
# Average accuracy for numerosity 2 vs numerosity 3 in time points 41: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 41: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 41: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 41: 0.54
# Average accuracy for numerosity 3 vs numerosity 4 in time points 41: 0.47
# Average accuracy for numerosity 3 vs numerosity 5 in time points 41: 0.46
# Average accuracy for numerosity 3 vs numerosity 6 in time points 41: 0.53
# Average accuracy for numerosity 4 vs numerosity 5 in time points 41: 0.42
# Average accuracy for numerosity 4 vs numerosity 6 in time points 41: 0.45
# Average accuracy for numerosity 5 vs numerosity 6 in time points 41: 0.38
# Time point 41 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 42: 0.54
# Average accuracy for numerosity 1 vs numerosity 3 in time points 42: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 42: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 42: 0.45
# Average accuracy for numerosity 1 vs numerosity 6 in time points 42: 0.44
# Average accuracy for numerosity 2 vs numerosity 3 in time points 42: 0.54
# Average accuracy for numerosity 2 vs numerosity 4 in time points 42: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 42: 0.50
# ...
# Average accuracy for numerosity 1 vs numerosity 3 in time points 537: 0.63
# Average accuracy for numerosity 1 vs numerosity 4 in time points 537: 0.63
# Average accuracy for numerosity 1 vs numerosity 5 in time points 537: 0.66
# Average accuracy for numerosity 1 vs numerosity 6 in time points 537: 0.64
# Average accuracy for numerosity 2 vs numerosity 3 in time points 537: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 537: 0.54
# Average accuracy for numerosity 2 vs numerosity 5 in time points 537: 0.44
# Average accuracy for numerosity 2 vs numerosity 6 in time points 537: 0.59
# Average accuracy for numerosity 3 vs numerosity 4 in time points 537: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 537: 0.46
# Average accuracy for numerosity 3 vs numerosity 6 in time points 537: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 537: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 537: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 537: 0.59
# Time point 537 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 538: 0.56
# Average accuracy for numerosity 1 vs numerosity 3 in time points 538: 0.62
# Average accuracy for numerosity 1 vs numerosity 4 in time points 538: 0.63
# Average accuracy for numerosity 1 vs numerosity 5 in time points 538: 0.64
# Average accuracy for numerosity 1 vs numerosity 6 in time points 538: 0.63
# Average accuracy for numerosity 2 vs numerosity 3 in time points 538: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 538: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 538: 0.45
# Average accuracy for numerosity 2 vs numerosity 6 in time points 538: 0.56
# Average accuracy for numerosity 3 vs numerosity 4 in time points 538: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 538: 0.46
# Average accuracy for numerosity 3 vs numerosity 6 in time points 538: 0.47
# Average accuracy for numerosity 4 vs numerosity 5 in time points 538: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 538: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 538: 0.59
# Time point 538 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 539: 0.56
# Average accuracy for numerosity 1 vs numerosity 3 in time points 539: 0.60
# Average accuracy for numerosity 1 vs numerosity 4 in time points 539: 0.61
# Average accuracy for numerosity 1 vs numerosity 5 in time points 539: 0.63
# Average accuracy for numerosity 1 vs numerosity 6 in time points 539: 0.64
# Average accuracy for numerosity 2 vs numerosity 3 in time points 539: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 539: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 539: 0.44
# Average accuracy for numerosity 2 vs numerosity 6 in time points 539: 0.57
# Average accuracy for numerosity 3 vs numerosity 4 in time points 539: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 539: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 539: 0.46
# Average accuracy for numerosity 4 vs numerosity 5 in time points 539: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 539: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 539: 0.56
# Time point 539 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 540: 0.55
# Average accuracy for numerosity 1 vs numerosity 3 in time points 540: 0.58
# Average accuracy for numerosity 1 vs numerosity 4 in time points 540: 0.62
# Average accuracy for numerosity 1 vs numerosity 5 in time points 540: 0.63
# Average accuracy for numerosity 1 vs numerosity 6 in time points 540: 0.62
# Average accuracy for numerosity 2 vs numerosity 3 in time points 540: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 540: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 540: 0.44
# Average accuracy for numerosity 2 vs numerosity 6 in time points 540: 0.57
# Average accuracy for numerosity 3 vs numerosity 4 in time points 540: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 540: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 540: 0.47
# Average accuracy for numerosity 4 vs numerosity 5 in time points 540: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 540: 0.52
# Average accuracy for numerosity 5 vs numerosity 6 in time points 540: 0.57
# Time point 540 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 541: 0.54
# Average accuracy for numerosity 1 vs numerosity 3 in time points 541: 0.56
# Average accuracy for numerosity 1 vs numerosity 4 in time points 541: 0.60
# Average accuracy for numerosity 1 vs numerosity 5 in time points 541: 0.66
# Average accuracy for numerosity 1 vs numerosity 6 in time points 541: 0.61
# Average accuracy for numerosity 2 vs numerosity 3 in time points 541: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 541: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 541: 0.45
# Average accuracy for numerosity 2 vs numerosity 6 in time points 541: 0.56
# Average accuracy for numerosity 3 vs numerosity 4 in time points 541: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 541: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 541: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 541: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 541: 0.52
# Average accuracy for numerosity 5 vs numerosity 6 in time points 541: 0.57
# Time point 541 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 542: 0.54
# Average accuracy for numerosity 1 vs numerosity 3 in time points 542: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 542: 0.58
# Average accuracy for numerosity 1 vs numerosity 5 in time points 542: 0.66
# Average accuracy for numerosity 1 vs numerosity 6 in time points 542: 0.62
# Average accuracy for numerosity 2 vs numerosity 3 in time points 542: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 542: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 542: 0.45
# Average accuracy for numerosity 2 vs numerosity 6 in time points 542: 0.55
# Average accuracy for numerosity 3 vs numerosity 4 in time points 542: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 542: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 542: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 542: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 542: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 542: 0.56
# Time point 542 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 543: 0.54
# Average accuracy for numerosity 1 vs numerosity 3 in time points 543: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 543: 0.59
# Average accuracy for numerosity 1 vs numerosity 5 in time points 543: 0.68
# Average accuracy for numerosity 1 vs numerosity 6 in time points 543: 0.62
# Average accuracy for numerosity 2 vs numerosity 3 in time points 543: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 543: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 543: 0.47
# Average accuracy for numerosity 2 vs numerosity 6 in time points 543: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 543: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 543: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 543: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 543: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 543: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 543: 0.56
# Time point 543 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 544: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 544: 0.56
# Average accuracy for numerosity 1 vs numerosity 4 in time points 544: 0.58
# Average accuracy for numerosity 1 vs numerosity 5 in time points 544: 0.68
# Average accuracy for numerosity 1 vs numerosity 6 in time points 544: 0.62
# Average accuracy for numerosity 2 vs numerosity 3 in time points 544: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 544: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 544: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 544: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 544: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 544: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 544: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 544: 0.53
# Average accuracy for numerosity 4 vs numerosity 6 in time points 544: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 544: 0.54
# Time point 544 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 545: 0.54
# Average accuracy for numerosity 1 vs numerosity 3 in time points 545: 0.56
# Average accuracy for numerosity 1 vs numerosity 4 in time points 545: 0.55
# Average accuracy for numerosity 1 vs numerosity 5 in time points 545: 0.65
# Average accuracy for numerosity 1 vs numerosity 6 in time points 545: 0.61
# Average accuracy for numerosity 2 vs numerosity 3 in time points 545: 0.46
# Average accuracy for numerosity 2 vs numerosity 4 in time points 545: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 545: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 545: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 545: 0.53
# Average accuracy for numerosity 3 vs numerosity 5 in time points 545: 0.46
# Average accuracy for numerosity 3 vs numerosity 6 in time points 545: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 545: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 545: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 545: 0.54
# Time point 545 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 546: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 546: 0.57
# Average accuracy for numerosity 1 vs numerosity 4 in time points 546: 0.55
# Average accuracy for numerosity 1 vs numerosity 5 in time points 546: 0.66
# Average accuracy for numerosity 1 vs numerosity 6 in time points 546: 0.58
# Average accuracy for numerosity 2 vs numerosity 3 in time points 546: 0.48
# Average accuracy for numerosity 2 vs numerosity 4 in time points 546: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 546: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 546: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 546: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 546: 0.46
# Average accuracy for numerosity 3 vs numerosity 6 in time points 546: 0.47
# Average accuracy for numerosity 4 vs numerosity 5 in time points 546: 0.53
# Average accuracy for numerosity 4 vs numerosity 6 in time points 546: 0.54
# Average accuracy for numerosity 5 vs numerosity 6 in time points 546: 0.56
# Time point 546 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 547: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 547: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 547: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 547: 0.65
# Average accuracy for numerosity 1 vs numerosity 6 in time points 547: 0.58
# Average accuracy for numerosity 2 vs numerosity 3 in time points 547: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 547: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 547: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 547: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 547: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 547: 0.47
# Average accuracy for numerosity 3 vs numerosity 6 in time points 547: 0.46
# Average accuracy for numerosity 4 vs numerosity 5 in time points 547: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 547: 0.54
# Average accuracy for numerosity 5 vs numerosity 6 in time points 547: 0.57
# Time point 547 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 548: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 548: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 548: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 548: 0.66
# Average accuracy for numerosity 1 vs numerosity 6 in time points 548: 0.58
# Average accuracy for numerosity 2 vs numerosity 3 in time points 548: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 548: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 548: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 548: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 548: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 548: 0.46
# Average accuracy for numerosity 3 vs numerosity 6 in time points 548: 0.44
# Average accuracy for numerosity 4 vs numerosity 5 in time points 548: 0.53
# Average accuracy for numerosity 4 vs numerosity 6 in time points 548: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 548: 0.57
# Time point 548 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 549: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 549: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 549: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 549: 0.66
# Average accuracy for numerosity 1 vs numerosity 6 in time points 549: 0.58
# Average accuracy for numerosity 2 vs numerosity 3 in time points 549: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 549: 0.54
# Average accuracy for numerosity 2 vs numerosity 5 in time points 549: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 549: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 549: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 549: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 549: 0.46
# Average accuracy for numerosity 4 vs numerosity 5 in time points 549: 0.56
# Average accuracy for numerosity 4 vs numerosity 6 in time points 549: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 549: 0.54
# Time point 549 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 550: 0.49
# Average accuracy for numerosity 1 vs numerosity 3 in time points 550: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 550: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 550: 0.66
# Average accuracy for numerosity 1 vs numerosity 6 in time points 550: 0.58
# Average accuracy for numerosity 2 vs numerosity 3 in time points 550: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 550: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 550: 0.53
# Average accuracy for numerosity 2 vs numerosity 6 in time points 550: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 550: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 550: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 550: 0.47
# Average accuracy for numerosity 4 vs numerosity 5 in time points 550: 0.56
# Average accuracy for numerosity 4 vs numerosity 6 in time points 550: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 550: 0.56
# Time point 550 is done

# %%
# ~~~~~~~~~~~~~~~~ Save the decoding accuracy
save_folder = f"/u/kazma/MINT/data/{group}/processed/{modality}/{subject}"
save_path = os.path.join(save_folder, "accuracy_pairwise.pkl") #  a pickle file
with open(save_path, "wb") as f:
    pickle.dump(all_decoding_accuracy, f)
print(f"{subject}: saved in 'accuracy_pairwise.pkl'")
# ~~~~~~~~~~~~~~~~ Save the decoding accuracy ~~~~~~~~~~~~~~~~
# Out:
# sub-02: saved in 'accuracy_pairwise.pkl'

# %%
# ~~~~~~~~~~~~~~~~ Generate Accuracy matrix

all_accuracy_matrices = [] # List to store the resulting accuracy matrices


# ~~~~~~~~~~~~~~~~  CONDITION_LOOP
for idx, x in enumerate(all_decoding_accuracy):
    # Extract all unique conditions
    conditions = sorted(set(key[0] for key in x.keys()).union(set(key[1] for key in x.keys())))
    n_conditions = len(conditions)

    # Create a dictionary to map conditions to matrix indices
    condition_idx = {condition: idx for idx, condition in enumerate(conditions)}

    # Initialize a square matrix with NaN values (for easier filling)
    accuracy_matrix = np.full((n_conditions, n_conditions), np.nan)

    # Fill the matrix with accuracies
    for (cond1, cond2), accuracy in x.items(): # e.g., 'cond1' = 'numerosity 1' and 'cond2' = 'numerosity 2'
        i, j = condition_idx[cond1], condition_idx[cond2]
        accuracy_matrix[i, j] = accuracy
        accuracy_matrix[j, i] = accuracy  # Ensuring symmetry

    # Convert to DataFrame for readability
    accuracy_df = pd.DataFrame(accuracy_matrix, index=conditions, columns=conditions)
    
    # Store the DataFrame in the list
    all_accuracy_matrices.append(accuracy_df)

    # Optionally print each matrix to verify (can remove if not needed)
    print(f"Decoding Accuracy Matrix for entry {idx + 1}:")
    print(accuracy_df)
    print("\n")
# Out:
# Decoding Accuracy Matrix for entry 1:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.520000      0.474725      0.577500
# numerosity 2      0.520000           NaN      0.548571      0.487132
# numerosity 3      0.474725      0.548571           NaN      0.534167
# numerosity 4      0.577500      0.487132      0.534167           NaN
# numerosity 5      0.403297      0.549048      0.414286      0.553750
# numerosity 6      0.553297      0.500000      0.525275      0.512500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.403297      0.553297
# numerosity 2      0.549048      0.500000
# numerosity 3      0.414286      0.525275
# numerosity 4      0.553750      0.512500
# numerosity 5           NaN      0.498352
# numerosity 6      0.498352           NaN
#
#
# Decoding Accuracy Matrix for entry 2:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.513810      0.453297      0.595833
# numerosity 2      0.513810           NaN      0.562381      0.486765
# numerosity 3      0.453297      0.562381           NaN      0.540417
# numerosity 4      0.595833      0.486765      0.540417           NaN
# numerosity 5      0.396154      0.542381      0.385714      0.540833
# numerosity 6      0.553846      0.500000      0.495055      0.518750
#
#               numerosity 5  numerosity 6
# numerosity 1      0.396154      0.553846
# numerosity 2      0.542381      0.500000
# numerosity 3      0.385714      0.495055
# numerosity 4      0.540833      0.518750
# numerosity 5           NaN      0.506044
# numerosity 6      0.506044           NaN
#
#
# Decoding Accuracy Matrix for entry 3:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.527143      0.439011      0.570417
# numerosity 2      0.527143           NaN      0.575714      0.492279
# numerosity 3      0.439011      0.575714           NaN      0.552917
# numerosity 4      0.570417      0.492279      0.552917           NaN
# numerosity 5      0.418132      0.549524      0.371429      0.521667
# numerosity 6      0.546703      0.521429      0.480220      0.518333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.418132      0.546703
# numerosity 2      0.549524      0.521429
# numerosity 3      0.371429      0.480220
# numerosity 4      0.521667      0.518333
# numerosity 5           NaN      0.482967
# numerosity 6      0.482967           NaN
#
#
# Decoding Accuracy Matrix for entry 4:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.534286      0.439560      0.570833
# numerosity 2      0.534286           NaN      0.569048      0.480515
# numerosity 3      0.439560      0.569048           NaN      0.553333
# numerosity 4      0.570833      0.480515      0.553333           NaN
# numerosity 5      0.389560      0.557143      0.385714      0.509167
# numerosity 6      0.546703      0.514286      0.480769      0.531667
#
#               numerosity 5  numerosity 6
# numerosity 1      0.389560      0.546703
# numerosity 2      0.557143      0.514286
# numerosity 3      0.385714      0.480769
# numerosity 4      0.509167      0.531667
# numerosity 5           NaN      0.483516
# numerosity 6      0.483516           NaN
#
#
# Decoding Accuracy Matrix for entry 5:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.541429      0.425275      0.582917
# numerosity 2      0.541429           NaN      0.589524      0.463235
# numerosity 3      0.425275      0.589524           NaN      0.578333
# numerosity 4      0.582917      0.463235      0.578333           NaN
# numerosity 5      0.403846      0.550952      0.400000      0.508750
# numerosity 6      0.508791      0.514286      0.443956      0.538333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.403846      0.508791
# numerosity 2      0.550952      0.514286
# numerosity 3      0.400000      0.443956
# numerosity 4      0.508750      0.538333
# numerosity 5           NaN      0.484066
# numerosity 6      0.484066           NaN
#
#
# Decoding Accuracy Matrix for entry 6:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.534762      0.396703      0.588750
# numerosity 2      0.534762           NaN      0.597619      0.493382
# numerosity 3      0.396703      0.597619           NaN      0.546667
# numerosity 4      0.588750      0.493382      0.546667           NaN
# numerosity 5      0.417582      0.564762      0.414286      0.515000
# numerosity 6      0.478571      0.528571      0.421978      0.557917
#
#               numerosity 5  numerosity 6
# numerosity 1      0.417582      0.478571
# numerosity 2      0.564762      0.528571
# numerosity 3      0.414286      0.421978
# numerosity 4      0.515000      0.557917
# numerosity 5           NaN      0.446703
# numerosity 6      0.446703           NaN
#
#
# Decoding Accuracy Matrix for entry 7:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.513810      0.382418      0.582917
# numerosity 2      0.513810           NaN      0.576667      0.518015
# numerosity 3      0.382418      0.576667           NaN      0.515000
# numerosity 4      0.582917      0.518015      0.515000           NaN
# numerosity 5      0.418132      0.584762      0.400000      0.527917
# numerosity 6      0.478022      0.550000      0.459890      0.590833
#
#               numerosity 5  numerosity 6
# numerosity 1      0.418132      0.478022
# numerosity 2      0.584762      0.550000
# numerosity 3      0.400000      0.459890
# numerosity 4      0.527917      0.590833
# numerosity 5           NaN      0.454396
# numerosity 6      0.454396           NaN
#
#
# Decoding Accuracy Matrix for entry 8:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.540952      0.346154      0.550417
# numerosity 2      0.540952           NaN      0.584762      0.523897
# numerosity 3      0.346154      0.584762           NaN      0.515000
# numerosity 4      0.550417      0.523897      0.515000           NaN
# numerosity 5      0.424176      0.563810      0.414286      0.521250
# numerosity 6      0.463187      0.571429      0.451648      0.584167
#
#               numerosity 5  numerosity 6
# numerosity 1      0.424176      0.463187
# numerosity 2      0.563810      0.571429
# numerosity 3      0.414286      0.451648
# numerosity 4      0.521250      0.584167
# numerosity 5           NaN      0.484066
# numerosity 6      0.484066           NaN
#
#
# Decoding Accuracy Matrix for entry 9:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.554762      0.324176      0.524167
# numerosity 2      0.554762           NaN      0.578571      0.560294
# numerosity 3      0.324176      0.578571           NaN      0.533750
# numerosity 4      0.524167      0.560294      0.533750           NaN
# numerosity 5      0.424176      0.584286      0.428571      0.503333
# numerosity 6      0.455495      0.557143      0.443407      0.571667
#
#               numerosity 5  numerosity 6
# numerosity 1      0.424176      0.455495
# numerosity 2      0.584286      0.557143
# numerosity 3      0.428571      0.443407
# numerosity 4      0.503333      0.571667
# numerosity 5           NaN      0.491758
# numerosity 6      0.491758           NaN
#
#
# Decoding Accuracy Matrix for entry 10:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.574762      0.308791      0.530417
# numerosity 2      0.574762           NaN      0.537619      0.553309
# numerosity 3      0.308791      0.537619           NaN      0.533750
# numerosity 4      0.530417      0.553309      0.533750           NaN
# numerosity 5      0.437912      0.563810      0.414286      0.509583
# numerosity 6      0.492308      0.550000      0.443956      0.577917
#
#               numerosity 5  numerosity 6
# numerosity 1      0.437912      0.492308
# numerosity 2      0.563810      0.550000
# numerosity 3      0.414286      0.443956
# numerosity 4      0.509583      0.577917
# numerosity 5           NaN      0.492308
# numerosity 6      0.492308           NaN
#
#
# Decoding Accuracy Matrix for entry 11:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.581429      0.330220      0.537083
# numerosity 2      0.581429           NaN      0.530476      0.529779
# numerosity 3      0.330220      0.530476           NaN      0.502917
# numerosity 4      0.537083      0.529779      0.502917           NaN
# numerosity 5      0.473626      0.570952      0.407143      0.509583
# numerosity 6      0.523077      0.514286      0.474725      0.565417
#
#               numerosity 5  numerosity 6
# numerosity 1      0.473626      0.523077
# numerosity 2      0.570952      0.514286
# numerosity 3      0.407143      0.474725
# numerosity 4      0.509583      0.565417
# numerosity 5           NaN      0.482418
# numerosity 6      0.482418           NaN
#
#
# Decoding Accuracy Matrix for entry 12:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.580952      0.359341      0.524167
# numerosity 2      0.580952           NaN      0.510000      0.524265
# numerosity 3      0.359341      0.510000           NaN      0.490000
# numerosity 4      0.524167      0.524265      0.490000           NaN
# numerosity 5      0.495055      0.551429      0.407143      0.503333
# numerosity 6      0.560989      0.500000      0.481868      0.538750
#
#               numerosity 5  numerosity 6
# numerosity 1      0.495055      0.560989
# numerosity 2      0.551429      0.500000
# numerosity 3      0.407143      0.481868
# numerosity 4      0.503333      0.538750
# numerosity 5           NaN      0.451648
# numerosity 6      0.451648           NaN
#
#
# Decoding Accuracy Matrix for entry 13:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.601905      0.431868      0.512500
# numerosity 2      0.601905           NaN      0.523333      0.518750
# numerosity 3      0.431868      0.523333           NaN      0.483750
# numerosity 4      0.512500      0.518750      0.483750           NaN
# numerosity 5      0.517033      0.545238      0.378571      0.515833
# numerosity 6      0.551648      0.514286      0.459341      0.572500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.517033      0.551648
# numerosity 2      0.545238      0.514286
# numerosity 3      0.378571      0.459341
# numerosity 4      0.515833      0.572500
# numerosity 5           NaN      0.458791
# numerosity 6      0.458791           NaN
#
#
# Decoding Accuracy Matrix for entry 14:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.635714      0.453297      0.512083
# numerosity 2      0.635714           NaN      0.530000      0.506985
# numerosity 3      0.453297      0.530000           NaN      0.484167
# numerosity 4      0.512083      0.506985      0.484167           NaN
# numerosity 5      0.531868      0.529524      0.414286      0.510000
# numerosity 6      0.552198      0.521429      0.474176      0.546250
#
#               numerosity 5  numerosity 6
# numerosity 1      0.531868      0.552198
# numerosity 2      0.529524      0.521429
# numerosity 3      0.414286      0.474176
# numerosity 4      0.510000      0.546250
# numerosity 5           NaN      0.465385
# numerosity 6      0.465385           NaN
#
#
# Decoding Accuracy Matrix for entry 15:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.628571      0.481319      0.518333
# numerosity 2      0.628571           NaN      0.530952      0.489338
# numerosity 3      0.481319      0.530952           NaN      0.452917
# numerosity 4      0.518333      0.489338      0.452917           NaN
# numerosity 5      0.552747      0.515714      0.392857      0.497500
# numerosity 6      0.523077      0.542857      0.458242      0.546250
#
#               numerosity 5  numerosity 6
# numerosity 1      0.552747      0.523077
# numerosity 2      0.515714      0.542857
# numerosity 3      0.392857      0.458242
# numerosity 4      0.497500      0.546250
# numerosity 5           NaN      0.442857
# numerosity 6      0.442857           NaN
#
#
# Decoding Accuracy Matrix for entry 16:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.615714      0.502747      0.524167
# numerosity 2      0.615714           NaN      0.505238      0.495588
# numerosity 3      0.502747      0.505238           NaN      0.484583
# numerosity 4      0.524167      0.495588      0.484583           NaN
# numerosity 5      0.552198      0.523333      0.407143      0.497917
# numerosity 6      0.499451      0.535714      0.518681      0.526667
#
#               numerosity 5  numerosity 6
# numerosity 1      0.552198      0.499451
# numerosity 2      0.523333      0.535714
# numerosity 3      0.407143      0.518681
# numerosity 4      0.497917      0.526667
# numerosity 5           NaN      0.457692
# numerosity 6      0.457692           NaN
#
#
# Decoding Accuracy Matrix for entry 17:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.609524      0.539011      0.524583
# numerosity 2      0.609524           NaN      0.512381      0.513603
# numerosity 3      0.539011      0.512381           NaN      0.515833
# numerosity 4      0.524583      0.513603      0.515833           NaN
# numerosity 5      0.545055      0.483333      0.421429      0.497917
# numerosity 6      0.500000      0.528571      0.519231      0.520000
#
#               numerosity 5  numerosity 6
# numerosity 1      0.545055      0.500000
# numerosity 2      0.483333      0.528571
# numerosity 3      0.421429      0.519231
# numerosity 4      0.497917      0.520000
# numerosity 5           NaN      0.488462
# numerosity 6      0.488462           NaN
#
#
# Decoding Accuracy Matrix for entry 18:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.595714      0.554396      0.538750
# numerosity 2      0.595714           NaN      0.525714      0.537132
# numerosity 3      0.554396      0.525714           NaN      0.502917
# numerosity 4      0.538750      0.537132      0.502917           NaN
# numerosity 5      0.537912      0.503810      0.385714      0.491250
# numerosity 6      0.491209      0.514286      0.503846      0.547083
#
#               numerosity 5  numerosity 6
# numerosity 1      0.537912      0.491209
# numerosity 2      0.503810      0.514286
# numerosity 3      0.385714      0.503846
# numerosity 4      0.491250      0.547083
# numerosity 5           NaN      0.473626
# numerosity 6      0.473626           NaN
#
#
# Decoding Accuracy Matrix for entry 19:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.596190      0.532967      0.576667
# numerosity 2      0.596190           NaN      0.512381      0.518382
# numerosity 3      0.532967      0.512381           NaN      0.496667
# numerosity 4      0.576667      0.518382      0.496667           NaN
# numerosity 5      0.538462      0.531905      0.407143      0.465833
# numerosity 6      0.507143      0.478571      0.541758      0.526250
#
#               numerosity 5  numerosity 6
# numerosity 1      0.538462      0.507143
# numerosity 2      0.531905      0.478571
# numerosity 3      0.407143      0.541758
# numerosity 4      0.465833      0.526250
# numerosity 5           NaN      0.465934
# numerosity 6      0.465934           NaN
#
#
# Decoding Accuracy Matrix for entry 20:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.603333      0.518681      0.538333
# numerosity 2      0.603333           NaN      0.476667      0.518382
# numerosity 3      0.518681      0.476667           NaN      0.509167
# numerosity 4      0.538333      0.518382      0.509167           NaN
# numerosity 5      0.509890      0.544762      0.407143      0.484583
# numerosity 6      0.514835      0.485714      0.518132      0.500417
#
#               numerosity 5  numerosity 6
# numerosity 1      0.509890      0.514835
# numerosity 2      0.544762      0.485714
# numerosity 3      0.407143      0.518132
# numerosity 4      0.484583      0.500417
# numerosity 5           NaN      0.458242
# numerosity 6      0.458242           NaN
#
#
# Decoding Accuracy Matrix for entry 21:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.590000      0.540110      0.525833
# numerosity 2      0.590000           NaN      0.434286      0.518750
# numerosity 3      0.540110      0.434286           NaN      0.484583
# numerosity 4      0.525833      0.518750      0.484583           NaN
# numerosity 5      0.509890      0.524286      0.442857      0.440417
# numerosity 6      0.530769      0.485714      0.495055      0.500000
#
#               numerosity 5  numerosity 6
# numerosity 1      0.509890      0.530769
# numerosity 2      0.524286      0.485714
# numerosity 3      0.442857      0.495055
# numerosity 4      0.440417      0.500000
# numerosity 5           NaN      0.443956
# numerosity 6      0.443956           NaN
#
#
# Decoding Accuracy Matrix for entry 22:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.568095      0.510440      0.513750
# numerosity 2      0.568095           NaN      0.428095      0.487500
# numerosity 3      0.510440      0.428095           NaN      0.478333
# numerosity 4      0.513750      0.487500      0.478333           NaN
# numerosity 5      0.503297      0.489524      0.442857      0.503333
# numerosity 6      0.530220      0.471429      0.497253      0.486250
#
#               numerosity 5  numerosity 6
# numerosity 1      0.503297      0.530220
# numerosity 2      0.489524      0.471429
# numerosity 3      0.442857      0.497253
# numerosity 4      0.503333      0.486250
# numerosity 5           NaN      0.451099
# numerosity 6      0.451099           NaN
#
#
# Decoding Accuracy Matrix for entry 23:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.547619      0.503297      0.501667
# numerosity 2      0.547619           NaN      0.421905      0.511765
# numerosity 3      0.503297      0.421905           NaN      0.503750
# numerosity 4      0.501667      0.511765      0.503750           NaN
# numerosity 5      0.490110      0.455238      0.421429      0.485000
# numerosity 6      0.545604      0.478571      0.497802      0.505417
#
#               numerosity 5  numerosity 6
# numerosity 1      0.490110      0.545604
# numerosity 2      0.455238      0.478571
# numerosity 3      0.421429      0.497802
# numerosity 4      0.485000      0.505417
# numerosity 5           NaN      0.474176
# numerosity 6      0.474176           NaN
#
#
# Decoding Accuracy Matrix for entry 24:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.500476      0.488462      0.508333
# numerosity 2      0.500476           NaN      0.421429      0.517647
# numerosity 3      0.488462      0.421429           NaN      0.478333
# numerosity 4      0.508333      0.517647      0.478333           NaN
# numerosity 5      0.490110      0.456667      0.450000      0.477917
# numerosity 6      0.544505      0.442857      0.520330      0.499167
#
#               numerosity 5  numerosity 6
# numerosity 1      0.490110      0.544505
# numerosity 2      0.456667      0.442857
# numerosity 3      0.450000      0.520330
# numerosity 4      0.477917      0.499167
# numerosity 5           NaN      0.474725
# numerosity 6      0.474725           NaN
#
#
# Decoding Accuracy Matrix for entry 25:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.472857      0.509890      0.521250
# numerosity 2      0.472857           NaN      0.440000      0.517647
# numerosity 3      0.509890      0.440000           NaN      0.503333
# numerosity 4      0.521250      0.517647      0.503333           NaN
# numerosity 5      0.497802      0.456667      0.435714      0.459167
# numerosity 6      0.537363      0.435714      0.519231      0.518750
#
#               numerosity 5  numerosity 6
# numerosity 1      0.497802      0.537363
# numerosity 2      0.456667      0.435714
# numerosity 3      0.435714      0.519231
# numerosity 4      0.459167      0.518750
# numerosity 5           NaN      0.473626
# numerosity 6      0.473626           NaN
#
#
# Decoding Accuracy Matrix for entry 26:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.431905      0.517033      0.502083
# numerosity 2      0.431905           NaN      0.467619      0.530515
# numerosity 3      0.517033      0.467619           NaN      0.490000
# numerosity 4      0.502083      0.530515      0.490000           NaN
# numerosity 5      0.454945      0.475714      0.428571      0.421250
# numerosity 6      0.514835      0.478571      0.542308      0.532500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.454945      0.514835
# numerosity 2      0.475714      0.478571
# numerosity 3      0.428571      0.542308
# numerosity 4      0.421250      0.532500
# numerosity 5           NaN      0.458242
# numerosity 6      0.458242           NaN
#
#
# Decoding Accuracy Matrix for entry 27:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.417619      0.503297      0.488750
# numerosity 2      0.417619           NaN      0.474286      0.494118
# numerosity 3      0.503297      0.474286           NaN      0.509167
# numerosity 4      0.488750      0.494118      0.509167           NaN
# numerosity 5      0.462088      0.488095      0.464286      0.465833
# numerosity 6      0.484066      0.485714      0.571429      0.552083
#
#               numerosity 5  numerosity 6
# numerosity 1      0.462088      0.484066
# numerosity 2      0.488095      0.485714
# numerosity 3      0.464286      0.571429
# numerosity 4      0.465833      0.552083
# numerosity 5           NaN      0.396703
# numerosity 6      0.396703           NaN
#
#
# Decoding Accuracy Matrix for entry 28:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.381905      0.481868      0.494167
# numerosity 2      0.381905           NaN      0.514762      0.494485
# numerosity 3      0.481868      0.514762           NaN      0.515833
# numerosity 4      0.494167      0.494485      0.515833           NaN
# numerosity 5      0.505495      0.535238      0.500000      0.490000
# numerosity 6      0.468681      0.478571      0.548901      0.551667
#
#               numerosity 5  numerosity 6
# numerosity 1      0.505495      0.468681
# numerosity 2      0.535238      0.478571
# numerosity 3      0.500000      0.548901
# numerosity 4      0.490000      0.551667
# numerosity 5           NaN      0.404945
# numerosity 6      0.404945           NaN
#
#
# Decoding Accuracy Matrix for entry 29:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.388571      0.496154      0.481250
# numerosity 2      0.388571           NaN      0.536190      0.512500
# numerosity 3      0.496154      0.536190           NaN      0.515833
# numerosity 4      0.481250      0.512500      0.515833           NaN
# numerosity 5      0.519231      0.535714      0.514286      0.508750
# numerosity 6      0.431319      0.485714      0.541758      0.545417
#
#               numerosity 5  numerosity 6
# numerosity 1      0.519231      0.431319
# numerosity 2      0.535714      0.485714
# numerosity 3      0.514286      0.541758
# numerosity 4      0.508750      0.545417
# numerosity 5           NaN      0.435165
# numerosity 6      0.435165           NaN
#
#
# Decoding Accuracy Matrix for entry 30:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.388571      0.481319      0.474583
# numerosity 2      0.388571           NaN      0.569524      0.518382
# numerosity 3      0.481319      0.569524           NaN      0.541250
# numerosity 4      0.474583      0.518382      0.541250           NaN
# numerosity 5      0.510989      0.549048      0.500000      0.515833
# numerosity 6      0.447253      0.450000      0.556044      0.578333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.510989      0.447253
# numerosity 2      0.549048      0.450000
# numerosity 3      0.500000      0.556044
# numerosity 4      0.515833      0.578333
# numerosity 5           NaN      0.457143
# numerosity 6      0.457143           NaN
#
#
# Decoding Accuracy Matrix for entry 31:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.422857      0.495604      0.481667
# numerosity 2      0.422857           NaN      0.563333      0.529779
# numerosity 3      0.495604      0.563333           NaN      0.541250
# numerosity 4      0.481667      0.529779      0.541250           NaN
# numerosity 5      0.510440      0.535714      0.514286      0.503750
# numerosity 6      0.415385      0.471429      0.564286      0.584583
#
#               numerosity 5  numerosity 6
# numerosity 1      0.510440      0.415385
# numerosity 2      0.535714      0.471429
# numerosity 3      0.514286      0.564286
# numerosity 4      0.503750      0.584583
# numerosity 5           NaN      0.467033
# numerosity 6      0.467033           NaN
#
#
# Decoding Accuracy Matrix for entry 32:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.451429      0.496154      0.475417
# numerosity 2      0.451429           NaN      0.571429      0.506618
# numerosity 3      0.496154      0.571429           NaN      0.553750
# numerosity 4      0.475417      0.506618      0.553750           NaN
# numerosity 5      0.481868      0.543333      0.507143      0.528750
# numerosity 6      0.408242      0.471429      0.541758      0.558750
#
#               numerosity 5  numerosity 6
# numerosity 1      0.481868      0.408242
# numerosity 2      0.543333      0.471429
# numerosity 3      0.507143      0.541758
# numerosity 4      0.528750      0.558750
# numerosity 5           NaN      0.452198
# numerosity 6      0.452198           NaN
#
#
# Decoding Accuracy Matrix for entry 33:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.506667      0.496154      0.475417
# numerosity 2      0.506667           NaN      0.565238      0.554412
# numerosity 3      0.496154      0.565238           NaN      0.585000
# numerosity 4      0.475417      0.554412      0.585000           NaN
# numerosity 5      0.510440      0.563333      0.485714      0.547500
# numerosity 6      0.407692      0.464286      0.527473      0.545833
#
#               numerosity 5  numerosity 6
# numerosity 1      0.510440      0.407692
# numerosity 2      0.563333      0.464286
# numerosity 3      0.485714      0.527473
# numerosity 4      0.547500      0.545833
# numerosity 5           NaN      0.467033
# numerosity 6      0.467033           NaN
#
#
# Decoding Accuracy Matrix for entry 34:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.513333      0.424176      0.456250
# numerosity 2      0.513333           NaN      0.551429      0.542647
# numerosity 3      0.424176      0.551429           NaN      0.535000
# numerosity 4      0.456250      0.542647      0.535000           NaN
# numerosity 5      0.481868      0.584762      0.414286      0.535000
# numerosity 6      0.446154      0.500000      0.534066      0.547083
#
#               numerosity 5  numerosity 6
# numerosity 1      0.481868      0.446154
# numerosity 2      0.584762      0.500000
# numerosity 3      0.414286      0.534066
# numerosity 4      0.535000      0.547083
# numerosity 5           NaN      0.436813
# numerosity 6      0.436813           NaN
#
#
# Decoding Accuracy Matrix for entry 35:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.526667      0.452747      0.450000
# numerosity 2      0.526667           NaN      0.565238      0.542647
# numerosity 3      0.452747      0.565238           NaN      0.547083
# numerosity 4      0.450000      0.542647      0.547083           NaN
# numerosity 5      0.467582      0.558095      0.414286      0.547500
# numerosity 6      0.460989      0.492857      0.496154      0.533333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.467582      0.460989
# numerosity 2      0.558095      0.492857
# numerosity 3      0.414286      0.496154
# numerosity 4      0.547500      0.533333
# numerosity 5           NaN      0.445055
# numerosity 6      0.445055           NaN
#
#
# Decoding Accuracy Matrix for entry 36:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.527143      0.452747      0.481250
# numerosity 2      0.527143           NaN      0.558095      0.525368
# numerosity 3      0.452747      0.558095           NaN      0.508333
# numerosity 4      0.481250      0.525368      0.508333           NaN
# numerosity 5      0.503297      0.551429      0.414286      0.547500
# numerosity 6      0.462088      0.507143      0.451648      0.532917
#
#               numerosity 5  numerosity 6
# numerosity 1      0.503297      0.462088
# numerosity 2      0.551429      0.507143
# numerosity 3      0.414286      0.451648
# numerosity 4      0.547500      0.532917
# numerosity 5           NaN      0.430220
# numerosity 6      0.430220           NaN
#
#
# Decoding Accuracy Matrix for entry 37:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.560476      0.468132      0.518750
# numerosity 2      0.560476           NaN      0.536667      0.548897
# numerosity 3      0.468132      0.536667           NaN      0.508750
# numerosity 4      0.518750      0.548897      0.508750           NaN
# numerosity 5      0.502747      0.545238      0.442857      0.547500
# numerosity 6      0.470330      0.507143      0.443956      0.507083
#
#               numerosity 5  numerosity 6
# numerosity 1      0.502747      0.470330
# numerosity 2      0.545238      0.507143
# numerosity 3      0.442857      0.443956
# numerosity 4      0.547500      0.507083
# numerosity 5           NaN      0.391758
# numerosity 6      0.391758           NaN
#
#
# Decoding Accuracy Matrix for entry 38:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.588571      0.517582      0.511667
# numerosity 2      0.588571           NaN      0.536190      0.530147
# numerosity 3      0.517582      0.536190           NaN      0.508750
# numerosity 4      0.511667      0.530147      0.508750           NaN
# numerosity 5      0.495055      0.551905      0.435714      0.540833
# numerosity 6      0.431868      0.500000      0.511538      0.480417
#
#               numerosity 5  numerosity 6
# numerosity 1      0.495055      0.431868
# numerosity 2      0.551905      0.500000
# numerosity 3      0.435714      0.511538
# numerosity 4      0.540833      0.480417
# numerosity 5           NaN      0.407143
# numerosity 6      0.407143           NaN
#
#
# Decoding Accuracy Matrix for entry 39:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.622857      0.554396      0.525000
# numerosity 2      0.622857           NaN      0.509048      0.518382
# numerosity 3      0.554396      0.509048           NaN      0.508333
# numerosity 4      0.525000      0.518382      0.508333           NaN
# numerosity 5      0.480220      0.545714      0.421429      0.515833
# numerosity 6      0.431868      0.492857      0.511538      0.473750
#
#               numerosity 5  numerosity 6
# numerosity 1      0.480220      0.431868
# numerosity 2      0.545714      0.492857
# numerosity 3      0.421429      0.511538
# numerosity 4      0.515833      0.473750
# numerosity 5           NaN      0.407692
# numerosity 6      0.407692           NaN
#
#
# Decoding Accuracy Matrix for entry 40:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.581429      0.539560      0.506250
# numerosity 2      0.581429           NaN      0.536667      0.523897
# numerosity 3      0.539560      0.536667           NaN      0.502083
# numerosity 4      0.506250      0.523897      0.502083           NaN
# numerosity 5      0.473077      0.545714      0.428571      0.478333
# numerosity 6      0.454396      0.528571      0.541758      0.473333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.473077      0.454396
# numerosity 2      0.545714      0.528571
# numerosity 3      0.428571      0.541758
# numerosity 4      0.478333      0.473333
# numerosity 5           NaN      0.383516
# numerosity 6      0.383516           NaN
#
#
# Decoding Accuracy Matrix for entry 41:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.574286      0.517582      0.512917
# numerosity 2      0.574286           NaN      0.550000      0.469853
# numerosity 3      0.517582      0.550000           NaN      0.476250
# numerosity 4      0.512917      0.469853      0.476250           NaN
# numerosity 5      0.444505      0.503810      0.435714      0.440417
# numerosity 6      0.469780      0.542857      0.542857      0.460417
#
#               numerosity 5  numerosity 6
# numerosity 1      0.444505      0.469780
# numerosity 2      0.503810      0.542857
# numerosity 3      0.435714      0.542857
# numerosity 4      0.440417      0.460417
# numerosity 5           NaN      0.368681
# numerosity 6      0.368681           NaN
#
#
# Decoding Accuracy Matrix for entry 42:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.574286      0.531319      0.487917
# numerosity 2      0.574286           NaN      0.523333      0.488235
# numerosity 3      0.531319      0.523333           NaN      0.470000
# numerosity 4      0.487917      0.488235      0.470000           NaN
# numerosity 5      0.459890      0.510000      0.457143      0.421667
# numerosity 6      0.417033      0.535714      0.528022      0.454167
#
#               numerosity 5  numerosity 6
# numerosity 1      0.459890      0.417033
# numerosity 2      0.510000      0.535714
# numerosity 3      0.457143      0.528022
# numerosity 4      0.421667      0.454167
# numerosity 5           NaN      0.375824
# numerosity 6      0.375824           NaN
#
#
# Decoding Accuracy Matrix for entry 43:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.540000      0.517582      0.544583
# numerosity 2      0.540000           NaN      0.537619      0.476471
# numerosity 3      0.517582      0.537619           NaN      0.483333
# numerosity 4      0.544583      0.476471      0.483333           NaN
# numerosity 5      0.452747      0.503333      0.435714      0.422500
# numerosity 6      0.439560      0.514286      0.543407      0.466250
#
#               numerosity 5  numerosity 6
# numerosity 1      0.452747      0.439560
# numerosity 2      0.503333      0.514286
# numerosity 3      0.435714      0.543407
# numerosity 4      0.422500      0.466250
# numerosity 5           NaN      0.428022
# numerosity 6      0.428022           NaN
#
#
# Decoding Accuracy Matrix for entry 44:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.545714      0.474725      0.582500
# numerosity 2      0.545714           NaN      0.523810      0.458088
# numerosity 3      0.474725      0.523810           NaN      0.514583
# numerosity 4      0.582500      0.458088      0.514583           NaN
# numerosity 5      0.438462      0.530476      0.414286      0.460000
# numerosity 6      0.484066      0.528571      0.528022      0.492083
#
#               numerosity 5  numerosity 6
# numerosity 1      0.438462      0.484066
# numerosity 2      0.530476      0.528571
# numerosity 3      0.414286      0.528022
# numerosity 4      0.460000      0.492083
# numerosity 5           NaN      0.421429
# numerosity 6      0.421429           NaN
#
#
# Decoding Accuracy Matrix for entry 45:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.512857      0.503846      0.570417
# numerosity 2      0.512857           NaN      0.510476      0.458088
# numerosity 3      0.503846      0.510476           NaN      0.509167
# numerosity 4      0.570417      0.458088      0.509167           NaN
# numerosity 5      0.438462      0.482381      0.421429      0.485833
# numerosity 6      0.530769      0.514286      0.535165      0.492500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.438462      0.530769
# numerosity 2      0.482381      0.514286
# numerosity 3      0.421429      0.535165
# numerosity 4      0.485833      0.492500
# numerosity 5           NaN      0.398352
# numerosity 6      0.398352           NaN
#
#
# Decoding Accuracy Matrix for entry 46:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.492857      0.503297      0.558333
# numerosity 2      0.492857           NaN      0.496190      0.499632
# numerosity 3      0.503297      0.496190           NaN      0.565833
# numerosity 4      0.558333      0.499632      0.565833           NaN
# numerosity 5      0.495604      0.454762      0.407143      0.517083
# numerosity 6      0.546703      0.507143      0.504396      0.492500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.495604      0.546703
# numerosity 2      0.454762      0.507143
# numerosity 3      0.407143      0.504396
# numerosity 4      0.517083      0.492500
# numerosity 5           NaN      0.420879
# numerosity 6      0.420879           NaN
#
#
# Decoding Accuracy Matrix for entry 47:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.505714      0.503297      0.577917
# numerosity 2      0.505714           NaN      0.481905      0.487500
# numerosity 3      0.503297      0.481905           NaN      0.565833
# numerosity 4      0.577917      0.487500      0.565833           NaN
# numerosity 5      0.474176      0.474762      0.407143      0.529583
# numerosity 6      0.568681      0.507143      0.481319      0.512083
#
#               numerosity 5  numerosity 6
# numerosity 1      0.474176      0.568681
# numerosity 2      0.474762      0.507143
# numerosity 3      0.407143      0.481319
# numerosity 4      0.529583      0.512083
# numerosity 5           NaN      0.428022
# numerosity 6      0.428022           NaN
#
#
# Decoding Accuracy Matrix for entry 48:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.505714      0.496154      0.583750
# numerosity 2      0.505714           NaN      0.475714      0.481618
# numerosity 3      0.496154      0.475714           NaN      0.565833
# numerosity 4      0.583750      0.481618      0.565833           NaN
# numerosity 5      0.467033      0.488095      0.400000      0.542500
# numerosity 6      0.562088      0.485714      0.481319      0.532083
#
#               numerosity 5  numerosity 6
# numerosity 1      0.467033      0.562088
# numerosity 2      0.488095      0.485714
# numerosity 3      0.400000      0.481319
# numerosity 4      0.542500      0.532083
# numerosity 5           NaN      0.419231
# numerosity 6      0.419231           NaN
#
#
# Decoding Accuracy Matrix for entry 49:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.484762      0.467582      0.590000
# numerosity 2      0.484762           NaN      0.460476      0.498897
# numerosity 3      0.467582      0.460476           NaN      0.584583
# numerosity 4      0.590000      0.498897      0.584583           NaN
# numerosity 5      0.489011      0.480952      0.371429      0.541667
# numerosity 6      0.562088      0.485714      0.480769      0.538333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.489011      0.562088
# numerosity 2      0.480952      0.485714
# numerosity 3      0.371429      0.480769
# numerosity 4      0.541667      0.538333
# numerosity 5           NaN      0.456044
# numerosity 6      0.456044           NaN
#
#
# Decoding Accuracy Matrix for entry 50:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.486190      0.489011      0.602083
# numerosity 2      0.486190           NaN      0.454286      0.523529
# numerosity 3      0.489011      0.454286           NaN      0.558750
# numerosity 4      0.602083      0.523529      0.558750           NaN
# numerosity 5      0.474725      0.487619      0.392857      0.535417
# numerosity 6      0.615934      0.464286      0.488462      0.538333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.474725      0.615934
# numerosity 2      0.487619      0.464286
# numerosity 3      0.392857      0.488462
# numerosity 4      0.535417      0.538333
# numerosity 5           NaN      0.441209
# numerosity 6      0.441209           NaN
#
#
# Decoding Accuracy Matrix for entry 51:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.506667      0.524176      0.589583
# numerosity 2      0.506667           NaN      0.454286      0.523529
# numerosity 3      0.524176      0.454286           NaN      0.558750
# numerosity 4      0.589583      0.523529      0.558750           NaN
# numerosity 5      0.445604      0.487619      0.407143      0.566667
# numerosity 6      0.621429      0.478571      0.480220      0.556667
#
#               numerosity 5  numerosity 6
# numerosity 1      0.445604      0.621429
# numerosity 2      0.487619      0.478571
# numerosity 3      0.407143      0.480220
# numerosity 4      0.566667      0.556667
# numerosity 5           NaN      0.456593
# numerosity 6      0.456593           NaN
#
#
# Decoding Accuracy Matrix for entry 52:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.486667      0.517033      0.570417
# numerosity 2      0.486667           NaN      0.440952      0.505515
# numerosity 3      0.517033      0.440952           NaN      0.584167
# numerosity 4      0.570417      0.505515      0.584167           NaN
# numerosity 5      0.488462      0.461429      0.407143      0.572917
# numerosity 6      0.598901      0.471429      0.471978      0.536667
#
#               numerosity 5  numerosity 6
# numerosity 1      0.488462      0.598901
# numerosity 2      0.461429      0.471429
# numerosity 3      0.407143      0.471978
# numerosity 4      0.572917      0.536667
# numerosity 5           NaN      0.463736
# numerosity 6      0.463736           NaN
#
#
# Decoding Accuracy Matrix for entry 53:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.480000      0.517033      0.595833
# numerosity 2      0.480000           NaN      0.440000      0.529412
# numerosity 3      0.517033      0.440000           NaN      0.590000
# numerosity 4      0.595833      0.529412      0.590000           NaN
# numerosity 5      0.502747      0.441429      0.414286      0.560417
# numerosity 6      0.576374      0.507143      0.457143      0.543333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.502747      0.576374
# numerosity 2      0.441429      0.507143
# numerosity 3      0.414286      0.457143
# numerosity 4      0.560417      0.543333
# numerosity 5           NaN      0.480220
# numerosity 6      0.480220           NaN
#
#
# Decoding Accuracy Matrix for entry 54:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.535238      0.524176      0.590000
# numerosity 2      0.535238           NaN      0.426667      0.559926
# numerosity 3      0.524176      0.426667           NaN      0.571250
# numerosity 4      0.590000      0.559926      0.571250           NaN
# numerosity 5      0.509890      0.462381      0.400000      0.528750
# numerosity 6      0.591209      0.514286      0.464835      0.549583
#
#               numerosity 5  numerosity 6
# numerosity 1      0.509890      0.591209
# numerosity 2      0.462381      0.514286
# numerosity 3      0.400000      0.464835
# numerosity 4      0.528750      0.549583
# numerosity 5           NaN      0.510440
# numerosity 6      0.510440           NaN
#
#
# Decoding Accuracy Matrix for entry 55:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.529048      0.517033      0.621250
# numerosity 2      0.529048           NaN      0.426667      0.553676
# numerosity 3      0.517033      0.426667           NaN      0.558750
# numerosity 4      0.621250      0.553676      0.558750           NaN
# numerosity 5      0.517033      0.455714      0.435714      0.509583
# numerosity 6      0.591209      0.514286      0.495055      0.530000
#
#               numerosity 5  numerosity 6
# numerosity 1      0.517033      0.591209
# numerosity 2      0.455714      0.514286
# numerosity 3      0.435714      0.495055
# numerosity 4      0.509583      0.530000
# numerosity 5           NaN      0.517582
# numerosity 6      0.517582           NaN
#
#
# Decoding Accuracy Matrix for entry 56:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.521429      0.502747      0.620833
# numerosity 2      0.521429           NaN      0.399524      0.541544
# numerosity 3      0.502747      0.399524           NaN      0.565000
# numerosity 4      0.620833      0.541544      0.565000           NaN
# numerosity 5      0.517033      0.448571      0.450000      0.522083
# numerosity 6      0.591209      0.507143      0.510989      0.517500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.517033      0.591209
# numerosity 2      0.448571      0.507143
# numerosity 3      0.450000      0.510989
# numerosity 4      0.522083      0.517500
# numerosity 5           NaN      0.525275
# numerosity 6      0.525275           NaN
#
#
# Decoding Accuracy Matrix for entry 57:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.535238      0.517033      0.607917
# numerosity 2      0.535238           NaN      0.412857      0.535662
# numerosity 3      0.517033      0.412857           NaN      0.546250
# numerosity 4      0.607917      0.535662      0.546250           NaN
# numerosity 5      0.531319      0.461905      0.457143      0.528333
# numerosity 6      0.606593      0.528571      0.526374      0.510833
#
# ...
# numerosity 1           NaN      0.597619      0.632967      0.582500
# numerosity 2      0.597619           NaN      0.500000      0.541176
# numerosity 3      0.632967      0.500000           NaN      0.490417
# numerosity 4      0.582500      0.541176      0.490417           NaN
# numerosity 5      0.619231      0.441429      0.471429      0.534583
# numerosity 6      0.629670      0.564286      0.512637      0.546250
#
#               numerosity 5  numerosity 6
# numerosity 1      0.619231      0.629670
# numerosity 2      0.441429      0.564286
# numerosity 3      0.471429      0.512637
# numerosity 4      0.534583      0.546250
# numerosity 5           NaN      0.586264
# numerosity 6      0.586264           NaN
#
#
# Decoding Accuracy Matrix for entry 534:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.596190      0.618681      0.588333
# numerosity 2      0.596190           NaN      0.500000      0.529412
# numerosity 3      0.618681      0.500000           NaN      0.490417
# numerosity 4      0.588333      0.529412      0.490417           NaN
# numerosity 5      0.626374      0.441429      0.485714      0.522083
# numerosity 6      0.659890      0.578571      0.497802      0.559583
#
#               numerosity 5  numerosity 6
# numerosity 1      0.626374      0.659890
# numerosity 2      0.441429      0.578571
# numerosity 3      0.485714      0.497802
# numerosity 4      0.522083      0.559583
# numerosity 5           NaN      0.617033
# numerosity 6      0.617033           NaN
#
#
# Decoding Accuracy Matrix for entry 535:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.582857      0.597253      0.613750
# numerosity 2      0.582857           NaN      0.499524      0.535662
# numerosity 3      0.597253      0.499524           NaN      0.496667
# numerosity 4      0.613750      0.535662      0.496667           NaN
# numerosity 5      0.634066      0.434286      0.485714      0.522083
# numerosity 6      0.644505      0.578571      0.497802      0.566250
#
#               numerosity 5  numerosity 6
# numerosity 1      0.634066      0.644505
# numerosity 2      0.434286      0.578571
# numerosity 3      0.485714      0.497802
# numerosity 4      0.522083      0.566250
# numerosity 5           NaN      0.609341
# numerosity 6      0.609341           NaN
#
#
# Decoding Accuracy Matrix for entry 536:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.590000      0.626923      0.626667
# numerosity 2      0.590000           NaN      0.499524      0.511765
# numerosity 3      0.626923      0.499524           NaN      0.483750
# numerosity 4      0.626667      0.511765      0.483750           NaN
# numerosity 5      0.619780      0.440000      0.478571      0.541250
# numerosity 6      0.667582      0.592857      0.512088      0.546250
#
#               numerosity 5  numerosity 6
# numerosity 1      0.619780      0.667582
# numerosity 2      0.440000      0.592857
# numerosity 3      0.478571      0.512088
# numerosity 4      0.541250      0.546250
# numerosity 5           NaN      0.609890
# numerosity 6      0.609890           NaN
#
#
# Decoding Accuracy Matrix for entry 537:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.582857      0.619780      0.626667
# numerosity 2      0.582857           NaN      0.486190      0.523897
# numerosity 3      0.619780      0.486190           NaN      0.477500
# numerosity 4      0.626667      0.523897      0.477500           NaN
# numerosity 5      0.634066      0.440000      0.485714      0.541250
# numerosity 6      0.667582      0.585714      0.489560      0.532917
#
#               numerosity 5  numerosity 6
# numerosity 1      0.634066      0.667582
# numerosity 2      0.440000      0.585714
# numerosity 3      0.485714      0.489560
# numerosity 4      0.541250      0.532917
# numerosity 5           NaN      0.609890
# numerosity 6      0.609890           NaN
#
#
# Decoding Accuracy Matrix for entry 538:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.575714      0.626923      0.626667
# numerosity 2      0.575714           NaN      0.486667      0.536029
# numerosity 3      0.626923      0.486667           NaN      0.496250
# numerosity 4      0.626667      0.536029      0.496250           NaN
# numerosity 5      0.662637      0.439524      0.464286      0.522500
# numerosity 6      0.637363      0.585714      0.489560      0.532500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.662637      0.637363
# numerosity 2      0.439524      0.585714
# numerosity 3      0.464286      0.489560
# numerosity 4      0.522500      0.532500
# numerosity 5           NaN      0.594505
# numerosity 6      0.594505           NaN
#
#
# Decoding Accuracy Matrix for entry 539:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.561905      0.619780      0.627083
# numerosity 2      0.561905           NaN      0.487143      0.518015
# numerosity 3      0.619780      0.487143           NaN      0.515833
# numerosity 4      0.627083      0.518015      0.515833           NaN
# numerosity 5      0.641209      0.453810      0.464286      0.522083
# numerosity 6      0.630220      0.564286      0.474176      0.532500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.641209      0.630220
# numerosity 2      0.453810      0.564286
# numerosity 3      0.464286      0.474176
# numerosity 4      0.522083      0.532500
# numerosity 5           NaN      0.586813
# numerosity 6      0.586813           NaN
#
#
# Decoding Accuracy Matrix for entry 540:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.562381      0.598352      0.615000
# numerosity 2      0.562381           NaN      0.508095      0.517647
# numerosity 3      0.598352      0.508095           NaN      0.503333
# numerosity 4      0.615000      0.517647      0.503333           NaN
# numerosity 5      0.634066      0.440952      0.478571      0.496250
# numerosity 6      0.636813      0.571429      0.458791      0.532500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.634066      0.636813
# numerosity 2      0.440952      0.571429
# numerosity 3      0.478571      0.458791
# numerosity 4      0.496250      0.532500
# numerosity 5           NaN      0.564286
# numerosity 6      0.564286           NaN
#
#
# Decoding Accuracy Matrix for entry 541:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.549524      0.576923      0.621667
# numerosity 2      0.549524           NaN      0.501429      0.517647
# numerosity 3      0.576923      0.501429           NaN      0.522083
# numerosity 4      0.621667      0.517647      0.522083           NaN
# numerosity 5      0.633516      0.440952      0.478571      0.515000
# numerosity 6      0.621429      0.571429      0.473077      0.519583
#
#               numerosity 5  numerosity 6
# numerosity 1      0.633516      0.621429
# numerosity 2      0.440952      0.571429
# numerosity 3      0.478571      0.473077
# numerosity 4      0.515000      0.519583
# numerosity 5           NaN      0.571429
# numerosity 6      0.571429           NaN
#
#
# Decoding Accuracy Matrix for entry 542:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.543333      0.562088      0.596667
# numerosity 2      0.543333           NaN      0.508571      0.523897
# numerosity 3      0.562088      0.508571           NaN      0.522083
# numerosity 4      0.596667      0.523897      0.522083           NaN
# numerosity 5      0.655495      0.454286      0.500000      0.508750
# numerosity 6      0.606044      0.564286      0.495604      0.519583
#
#               numerosity 5  numerosity 6
# numerosity 1      0.655495      0.606044
# numerosity 2      0.454286      0.564286
# numerosity 3      0.500000      0.495604
# numerosity 4      0.508750      0.519583
# numerosity 5           NaN      0.570879
# numerosity 6      0.570879           NaN
#
#
# Decoding Accuracy Matrix for entry 543:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.542857      0.518132      0.577917
# numerosity 2      0.542857           NaN      0.494762      0.523897
# numerosity 3      0.518132      0.494762           NaN      0.510000
# numerosity 4      0.577917      0.523897      0.510000           NaN
# numerosity 5      0.663187      0.454286      0.478571      0.502500
# numerosity 6      0.621429      0.550000      0.510440      0.512917
#
#               numerosity 5  numerosity 6
# numerosity 1      0.663187      0.621429
# numerosity 2      0.454286      0.550000
# numerosity 3      0.478571      0.510440
# numerosity 4      0.502500      0.512917
# numerosity 5           NaN      0.563187
# numerosity 6      0.563187           NaN
#
#
# Decoding Accuracy Matrix for entry 544:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.541905      0.554945      0.590833
# numerosity 2      0.541905           NaN      0.501905      0.518015
# numerosity 3      0.554945      0.501905           NaN      0.509583
# numerosity 4      0.590833      0.518015      0.509583           NaN
# numerosity 5      0.677473      0.474762      0.478571      0.502500
# numerosity 6      0.621429      0.521429      0.503297      0.532500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.677473      0.621429
# numerosity 2      0.474762      0.521429
# numerosity 3      0.478571      0.503297
# numerosity 4      0.502500      0.532500
# numerosity 5           NaN      0.563187
# numerosity 6      0.563187           NaN
#
#
# Decoding Accuracy Matrix for entry 545:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.528095      0.562088      0.577500
# numerosity 2      0.528095           NaN      0.494762      0.529779
# numerosity 3      0.562088      0.494762           NaN      0.509583
# numerosity 4      0.577500      0.529779      0.509583           NaN
# numerosity 5      0.677473      0.489048      0.500000      0.527500
# numerosity 6      0.621429      0.521429      0.517582      0.532500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.677473      0.621429
# numerosity 2      0.489048      0.521429
# numerosity 3      0.500000      0.517582
# numerosity 4      0.527500      0.532500
# numerosity 5           NaN      0.541758
# numerosity 6      0.541758           NaN
#
#
# Decoding Accuracy Matrix for entry 546:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.541905      0.562088      0.552500
# numerosity 2      0.541905           NaN      0.461429      0.523529
# numerosity 3      0.562088      0.461429           NaN      0.528333
# numerosity 4      0.552500      0.523529      0.528333           NaN
# numerosity 5      0.648901      0.495714      0.457143      0.520833
# numerosity 6      0.606593      0.514286      0.487363      0.532500
#
#               numerosity 5  numerosity 6
# numerosity 1      0.648901      0.606593
# numerosity 2      0.495714      0.514286
# numerosity 3      0.457143      0.487363
# numerosity 4      0.520833      0.532500
# numerosity 5           NaN      0.542308
# numerosity 6      0.542308           NaN
#
#
# Decoding Accuracy Matrix for entry 547:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.513333      0.569231      0.552917
# numerosity 2      0.513333           NaN      0.481905      0.517279
# numerosity 3      0.569231      0.481905           NaN      0.522083
# numerosity 4      0.552917      0.517279      0.522083           NaN
# numerosity 5      0.655495      0.503333      0.457143      0.527083
# numerosity 6      0.583516      0.485714      0.473626      0.538333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.655495      0.583516
# numerosity 2      0.503333      0.485714
# numerosity 3      0.457143      0.473626
# numerosity 4      0.527083      0.538333
# numerosity 5           NaN      0.558242
# numerosity 6      0.558242           NaN
#
#
# Decoding Accuracy Matrix for entry 548:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.520000      0.554945      0.533333
# numerosity 2      0.520000           NaN      0.502381      0.522794
# numerosity 3      0.554945      0.502381           NaN      0.515833
# numerosity 4      0.533333      0.522794      0.515833           NaN
# numerosity 5      0.648352      0.516190      0.471429      0.514583
# numerosity 6      0.575824      0.492857      0.458791      0.538333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.648352      0.575824
# numerosity 2      0.516190      0.492857
# numerosity 3      0.471429      0.458791
# numerosity 4      0.514583      0.538333
# numerosity 5           NaN      0.573077
# numerosity 6      0.573077           NaN
#
#
# Decoding Accuracy Matrix for entry 549:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.534286      0.546703      0.513750
# numerosity 2      0.534286           NaN      0.502381      0.528676
# numerosity 3      0.546703      0.502381           NaN      0.515833
# numerosity 4      0.513750      0.528676      0.515833           NaN
# numerosity 5      0.662637      0.502381      0.457143      0.527083
# numerosity 6      0.575824      0.485714      0.436264      0.532083
#
#               numerosity 5  numerosity 6
# numerosity 1      0.662637      0.575824
# numerosity 2      0.502381      0.485714
# numerosity 3      0.457143      0.436264
# numerosity 4      0.527083      0.532083
# numerosity 5           NaN      0.565934
# numerosity 6      0.565934           NaN
#
#
# Decoding Accuracy Matrix for entry 550:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.520000      0.518132      0.526250
# numerosity 2      0.520000           NaN      0.509524      0.540809
# numerosity 3      0.518132      0.509524           NaN      0.515833
# numerosity 4      0.526250      0.540809      0.515833           NaN
# numerosity 5      0.662637      0.516190      0.500000      0.559167
# numerosity 6      0.582967      0.507143      0.459341      0.551667
#
#               numerosity 5  numerosity 6
# numerosity 1      0.662637      0.582967
# numerosity 2      0.516190      0.507143
# numerosity 3      0.500000      0.459341
# numerosity 4      0.559167      0.551667
# numerosity 5           NaN      0.535165
# numerosity 6      0.535165           NaN
#
#
# Decoding Accuracy Matrix for entry 551:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.492857      0.510989      0.532500
# numerosity 2      0.492857           NaN      0.502857      0.527941
# numerosity 3      0.510989      0.502857           NaN      0.503333
# numerosity 4      0.532500      0.527941      0.503333           NaN
# numerosity 5      0.655495      0.530000      0.514286      0.559583
# numerosity 6      0.582418      0.514286      0.473626      0.551667
#
#               numerosity 5  numerosity 6
# numerosity 1      0.655495      0.582418
# numerosity 2      0.530000      0.514286
# numerosity 3      0.514286      0.473626
# numerosity 4      0.559583      0.551667
# numerosity 5           NaN      0.558242
# numerosity 6      0.558242           NaN

# %%
# ~~~~~~~~~~~~~~~~ Save the list of accuracy matrices
save_folder = f"/u/kazma/MINT/data/{group}/processed/{modality}/{subject}"
save_path = os.path.join(save_folder, "accuracy_matrices.pkl") #  a pickle file
with open(save_path, "wb") as f:
    pickle.dump(all_accuracy_matrices, f)
print(f"{subject}: matrices saved in 'accuracy_matrices.pkl'")
# ~~~~~~~~~~~~~~~~ Save the list of accuracy matrices ~~~~~~~~~~~~~~~~
# Out:
# sub-02: matrices saved in 'accuracy_matrices.pkl'
