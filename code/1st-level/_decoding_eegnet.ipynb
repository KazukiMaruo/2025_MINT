# %%
# ~~~~~~~~~~~~~~ Libraries
import sys, os
import mne # Python package for processing and analyzing electrophysiological data
import numpy as np
from glob import glob # look for all the pathnames matching a specified pattern according to the rules
import matplotlib.pyplot as plt
from mne.preprocessing import ICA # ICA (Independent Component Analysis) algorithm, which is for artifact removal
from autoreject import AutoReject # Python package for automatically rejecting bad epochs in EEG/MEG data
import json
import owncloud
import pandas as pd

# %%
# ~~~~~~~~~~~~~~ Environment

# open parent folder of this script
os.chdir('/u/kazma/MINT/code')

with open("config.json") as f: # The file object is referenced as f during the block.
    config = json.load(f) 
globals().update(config)
sys.path.append(BASE_DIR) # import custom python packages

# import cusom functions
from EEGModels import EEGNet
# Out:
# 2025-01-14 09:20:39.130923: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-01-14 09:20:39.130955: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Traceback (most recent call last):
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
# /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/framework/dtypes.py:511: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# Unexpected exception formatting exception. Falling back to standard exception
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 12
#       9 sys.path.append(BASE_DIR) # import custom python packages
#      11 # import cusom functions
# ---> 12 from EEGModels import EEGNet
#
# File /viper/u/kazma/MINT/code/EEGModels.py:43
#       1 """
#       2  ARL_EEGModels - A collection of Convolutional Neural Network models for EEG
#       3  Signal Processing and Classification, using Keras and Tensorflow
#    (...)
#      40  distribution.
#      41 """
# ---> 43 from tensorflow.keras.models import Model
#      44 from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
#      45 from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/__init__.py:46
#      41 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      43 # pylint: enable=wildcard-import
#      44
#      45 # Bring in subpackages.
# ---> 46 from tensorflow.python import data
#      47 from tensorflow.python import distribute
#      48 from tensorflow.python import keras
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/data/__init__.py:25
#      22 from __future__ import print_function
#      24 # pylint: disable=unused-import
# ---> 25 from tensorflow.python.data import experimental
#      26 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      27 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/data/experimental/__init__.py:99
#      96 from __future__ import print_function
#      98 # pylint: disable=unused-import
# ---> 99 from tensorflow.python.data.experimental import service
#     100 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#     101 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/data/experimental/service/__init__.py:140
#     137 from __future__ import division
#     138 from __future__ import print_function
# --> 140 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     141 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     142 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py:25
#      22 import six
#      24 from tensorflow.python import tf2
# ---> 25 from tensorflow.python.data.experimental.ops import compression_ops
#      26 from tensorflow.python.data.experimental.ops.distribute_options import AutoShardPolicy
#      27 from tensorflow.python.data.experimental.ops.distribute_options import ExternalStatePolicy
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/data/experimental/ops/compression_ops.py:20
#      17 from __future__ import division
#      18 from __future__ import print_function
# ---> 20 from tensorflow.python.data.util import structure
#      21 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      24 def compress(element):
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/data/util/structure.py:26
#      23 import six
#      24 import wrapt
# ---> 26 from tensorflow.python.data.util import nest
#      27 from tensorflow.python.framework import composite_tensor
#      28 from tensorflow.python.framework import ops
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/data/util/nest.py:40
#      36 from __future__ import print_function
#      38 import six as _six
# ---> 40 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      41 from tensorflow.python.util import _pywrap_utils
#      42 from tensorflow.python.util import nest
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/framework/sparse_tensor.py:28
#      26 from tensorflow.python import tf2
#      27 from tensorflow.python.framework import composite_tensor
# ---> 28 from tensorflow.python.framework import constant_op
#      29 from tensorflow.python.framework import dtypes
#      30 from tensorflow.python.framework import ops
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:29
#      27 from tensorflow.core.framework import types_pb2
#      28 from tensorflow.python.eager import context
# ---> 29 from tensorflow.python.eager import execute
#      30 from tensorflow.python.framework import dtypes
#      31 from tensorflow.python.framework import op_callbacks
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:27
#      25 from tensorflow.python import pywrap_tfe
#      26 from tensorflow.python.eager import core
# ---> 27 from tensorflow.python.framework import dtypes
#      28 from tensorflow.python.framework import ops
#      29 from tensorflow.python.framework import tensor_shape
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/tensorflow/python/framework/dtypes.py:511
#     480     _NP_TO_TF[pdt] = next(
#     481         _NP_TO_TF[dt] for dt in _NP_TO_TF if dt == pdt().dtype)
#     484 TF_VALUE_DTYPES = set(_NP_TO_TF.values())
#     487 _TF_TO_NP = {
#     488     types_pb2.DT_HALF:
#     489         np.float16,
#     490     types_pb2.DT_FLOAT:
#     491         np.float32,
#     492     types_pb2.DT_DOUBLE:
#     493         np.float64,
#     494     types_pb2.DT_INT32:
#     495         np.int32,
#     496     types_pb2.DT_UINT8:
#     497         np.uint8,
#     498     types_pb2.DT_UINT16:
#     499         np.uint16,
#     500     types_pb2.DT_UINT32:
#     501         np.uint32,
#     502     types_pb2.DT_UINT64:
#     503         np.uint64,
#     504     types_pb2.DT_INT16:
#     505         np.int16,
#     506     types_pb2.DT_INT8:
#     507         np.int8,
#     508     # NOTE(touts): For strings we use np.object as it supports variable length
#     509     # strings.
#     510     types_pb2.DT_STRING:
# --> 511         np.object,
#     512     types_pb2.DT_COMPLEX64:
#     513         np.complex64,
#     514     types_pb2.DT_COMPLEX128:
#     515         np.complex128,
#     516     types_pb2.DT_INT64:
#     517         np.int64,
#     518     types_pb2.DT_BOOL:
#     519         np.bool_,
#     520     types_pb2.DT_QINT8:
#     521         _np_qint8,
#     522     types_pb2.DT_QUINT8:
#     523         _np_quint8,
#     524     types_pb2.DT_QINT16:
#     525         _np_qint16,
#     526     types_pb2.DT_QUINT16:
#     527         _np_quint16,
#     528     types_pb2.DT_QINT32:
#     529         _np_qint32,
#     530     types_pb2.DT_BFLOAT16:
#     531         _np_bfloat16,
#     532
#     533     # Ref types
#     534     types_pb2.DT_HALF_REF:
#     535         np.float16,
#     536     types_pb2.DT_FLOAT_REF:
#     537         np.float32,
#     538     types_pb2.DT_DOUBLE_REF:
#     539         np.float64,
#     540     types_pb2.DT_INT32_REF:
#     541         np.int32,
#     542     types_pb2.DT_UINT32_REF:
#     543         np.uint32,
#     544     types_pb2.DT_UINT8_REF:
#     545         np.uint8,
#     546     types_pb2.DT_UINT16_REF:
#     547         np.uint16,
#     548     types_pb2.DT_INT16_REF:
#     549         np.int16,
#     550     types_pb2.DT_INT8_REF:
#     551         np.int8,
#     552     types_pb2.DT_STRING_REF:
#     553         np.object,
#     554     types_pb2.DT_COMPLEX64_REF:
#     555         np.complex64,
#     556     types_pb2.DT_COMPLEX128_REF:
#     557         np.complex128,
#     558     types_pb2.DT_INT64_REF:
#     559         np.int64,
#     560     types_pb2.DT_UINT64_REF:
#     561         np.uint64,
#     562     types_pb2.DT_BOOL_REF:
#     563         np.bool,
#     564     types_pb2.DT_QINT8_REF:
#     565         _np_qint8,
#     566     types_pb2.DT_QUINT8_REF:
#     567         _np_quint8,
#     568     types_pb2.DT_QINT16_REF:
#     569         _np_qint16,
#     570     types_pb2.DT_QUINT16_REF:
#     571         _np_quint16,
#     572     types_pb2.DT_QINT32_REF:
#     573         _np_qint32,
#     574     types_pb2.DT_BFLOAT16_REF:
#     575         _np_bfloat16,
#     576 }
#     578 _QUANTIZED_DTYPES_NO_REF = frozenset([qint8, quint8, qint16, quint16, qint32])
#     579 _QUANTIZED_DTYPES_REF = frozenset(
#     580     [qint8_ref, quint8_ref, qint16_ref, quint16_ref, qint32_ref])
#
# File /viper/u/kazma/miniforge3/envs/MINT/lib/python3.9/site-packages/numpy/__init__.py:324, in __getattr__(attr)
#     322     kernel_version = os.uname().release.split(".")[:2]
#     323     kernel_version = tuple(int(v) for v in kernel_version)
# --> 324     if kernel_version < (4, 6):
#     325         use_hugepage = 0
#     326 except ValueError:
#
# AttributeError: module 'numpy' has no attribute 'object'.
# `np.object` was a deprecated alias for the builtin `object`. To avoid this error in existing code, use `object` by itself. Doing this will not modify any behavior and is safe.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
