# %%
# %reset -f

# %%
# ~~~~~~~~~~~~~~ Libraries
import sys, os
import mne # Python package for processing and analyzing electrophysiological data
import numpy as np
from glob import glob # look for all the pathnames matching a specified pattern according to the rules
import matplotlib.pyplot as plt
from mne.preprocessing import ICA # ICA (Independent Component Analysis) algorithm, which is for artifact removal
import json
import re

from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from scipy.stats import permutation_test
import matplotlib.pyplot as plt
from itertools import combinations

import pandas as pd
import seaborn as sns
import pickle

# %% [markdown]
# # Average time series for one channel

# %%
# Set the working directory
path = "/u/kazma/MINT/data/interim/visual"
csv_path = "/u/kazma/MINT/data/raw/visual"
sub_folders = [f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]
sub_folders_sorted = sorted(sub_folders, key=lambda x: int(re.search(r'\d+', x).group())) # Sort the folders based on the numeric part after "sub-"



for sub_loop in sub_folders_sorted:

    # subject folder 
    sub_filename = os.path.join(path, sub_loop, 'epochs-epo.fif')

    # Load epochs
    epochs = mne.read_epochs(sub_filename, preload=True)
    print(f"{sub_loop} is analyzed")

    # Drop the trials that infant didn't pay attention
    csv_directory = os.path.join(csv_path, sub_loop)
    csv_file = [file for file in os.listdir(csv_directory) if file.endswith('.csv')]
    # Ensure there's at least one CSV file
    if len(csv_file) == 0:
        raise FileNotFoundError(f"No CSV files found in {csv_directory}")
    # Read the CSV file
    csv_file_path = os.path.join(csv_directory, csv_file[0])
    csv_df = pd.read_csv(csv_file_path)

    # get the index for trials not paied attention
    trials_to_drop = csv_df.index[csv_df['Attention'] == 0].tolist()
    epochs.drop(trials_to_drop)


    eeg_channels = epochs.pick_types(eeg=True).ch_names
    print("EEG Channels:", eeg_channels)
    print("Number of EEG Channels:", len(eeg_channels))
    
    # Get the condition names
    condition_names = list(epochs.event_id.keys())
    evoked_list = []

    # Compute the averaged epoch for each condition and each channel
    for condition in condition_names:
        evoked = epochs[condition].average()  # Average the epochs for the condition
        evoked_list.append(evoked)

    # Store 6 vectors, representing averaged vector for each condition
    averaged_data = {}

    # Specify the channel to plot (e.g., channel name 'Cz')
    channel_name = 'CP5'  # Replace with the channel of your choice

    # Figure
    plt.figure(figsize=(8, 4))

    # Define colors for the conditions
    colors = plt.cm.tab10(np.linspace(0, 1, 6))

    for i, evoked in enumerate(evoked_list):
        # Extract data for the specified channel
        channel_index = evoked.ch_names.index(channel_name)  # Get index of the channel
        channel_data = evoked.data[channel_index]  # Get the data for the specific channel
        times = evoked.times * 1000  # Convert time to milliseconds

        # Store the data
        averaged_data[condition_names[i]] = channel_data
        
        # Plot the channel data
        plt.plot(times, channel_data, color=colors[i], linewidth=3, alpha=0.5) 
        plt.plot(times, channel_data, label=condition_names[i], color=colors[i], linewidth=2)  # Plot time series

    # Customize the plot
    plt.title('Average Time Series for Channel: ' + channel_name)
    plt.xlabel('Time (ms)')
    plt.ylabel('Amplitude (µV)')
    plt.axhline(0, color='black', linestyle='--', linewidth=0.5)  # Add a horizontal line at y=0
    plt.axvline(0, color='black', linestyle='-', linewidth=1)  # Add a vertical line at t=0
    plt.xlim(-20, 900)  # Set x-axis limits
    # plt.ylim(-2.0e-8, 2.0e-8)  # Set y-axis limits
    plt.legend(ncol=3, loc='lower left', framealpha=1)

    # Set the box line color to gray
    ax = plt.gca()
    ax.spines['top'].set_color('gray')
    ax.spines['right'].set_color('gray')
    ax.spines['bottom'].set_color('gray')
    ax.spines['left'].set_color('gray')

    plt.tight_layout()
    plt.show()
# Out:
# Reading /u/kazma/MINT/data/interim/visual/sub-01_ses-01/epochs-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1260 matching events found
# No baseline correction applied
# 0 projection items activated
# sub-01_ses-01 is analyzed
# Dropped 413 epochs: 154, 155, 201, 202, 269, 316, 322, 323, 337, 338, 339, 340, 381, 382, 383, 384, 385, 386, 389, 390, 391, 392, 393, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 442, 443, 444, 448, 449, 450, 451, 452, 453, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 508, 509, 510, 543, 547, 548, 549, 550, 551, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 607, 608, 609, 610, 612, 613, 617, 618, 621, 622, 623, 624, 625, 626, 627, 628, 629, 633, 634, 635, 636, 637, 638, 671, 672, 673, 675, 676, 677, 678, 680, 681, 682, 683, 696, 697, 698, 699, 700, 701, 727, 728, 729, 730, 731, 735, 736, 737, 747, 748, 749, 750, 767, 768, 769, 770, 771, 772, 773, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 827, 828, 829, 830, 831, 832, 833, 834, 836, 837, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 868, 869, 870, 879, 880, 881, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 904, 905, 906, 907, 908, 909, 910, 911, 912, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1066, 1067, 1068, 1069, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG Channels: ['Fz', 'F3', 'F7', 'F9', 'FC5', 'POz', 'C3', 'T7', 'TP9', 'CP5', 'P7', 'P3', 'Pz', 'O1', 'O2', 'P8', 'P4', 'CP6', 'TP10', 'T8', 'C4', 'Oz', 'FC6', 'F10', 'F8', 'F4', 'FC4', 'CP4', 'FC3', 'CP3']
# Number of EEG Channels: 30

# %%
# Get list of EEG channel names
eeg_channels = epochs.pick_types(eeg=True).ch_names
print("EEG Channels:", eeg_channels)
print("Number of EEG Channels:", len(eeg_channels))
# Plot the sensor locations for the EEG channels
# epochs.plot_sensors(kind='topomap', show_names=True)
print(epochs.get_data().shape[1])
# Out:
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG Channels: ['Fz', 'F3', 'F7', 'F9', 'FC5', 'POz', 'C3', 'T7', 'TP9', 'CP5', 'P7', 'P3', 'Pz', 'O1', 'O2', 'P8', 'P4', 'CP6', 'TP10', 'T8', 'C4', 'Oz', 'FC6', 'F10', 'F8', 'F4', 'FC4', 'CP4', 'FC3', 'CP3']
# Number of EEG Channels: 30
# 30

# %% [markdown]
# # Cross-validation schema (LOOCV)

# %%
# Set the working directory
path = "/u/kazma/MINT/data/interim/visual"
csv_path = "/u/kazma/MINT/data/raw/visual"
sub_folders = [f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]
sub_folders_sorted = sorted(sub_folders, key=lambda x: int(re.search(r'\d+', x).group())) # Sort the folders based on the numeric part after "sub-"


# SUB_LOOP
for subject in sub_folders_sorted:

    # subject folder 
    sub_filename = os.path.join(path, subject, 'epochs-epo.fif')

    # Load epochs
    epochs = mne.read_epochs(sub_filename, preload=True)


    # Get the information about the data
    conditions = list(epochs.event_id.keys())
    n_conditions = len(conditions)
    n_channels = epochs.get_data().shape[1]
    n_samples = epochs.get_data().shape[2]
    min_time = epochs.times[0]*1000   # First time point in milli seconds
    max_time = epochs.times[-1]*1000    # Last time point in milli seconds

    # Drop the trials that infant didn't pay attention
    csv_directory = os.path.join(csv_path, subject)
    csv_file = [file for file in os.listdir(csv_directory) if file.endswith('.csv')]
    # Ensure there's at least one CSV file
    if len(csv_file) == 0:
        raise FileNotFoundError(f"No CSV files found in {csv_directory}")
    # Read the CSV file
    csv_file_path = os.path.join(csv_directory, csv_file[0])
    csv_df = pd.read_csv(csv_file_path)

    # get the index for trials not paied attention
    trials_to_drop = csv_df.index[csv_df['Attention'] == 0].tolist()
    epochs.drop(trials_to_drop)

    # list for avg accuracy for each time window
    all_decoding_accuracy = [] 

    # number of samples for each window
    window_size = 5 # 1 sample = 2ms, 5 samples = 10 ms
    n_splits = 7 # number of folds

    # Window loop start
    for start in range(0, n_samples, window_size): # Loop over the epoch in steps of `window_size` to extract each 5-sample window
        # Check if there are enough samples left for a full window
        if start + window_size <= n_samples:

            # Initialize the decoding dictionary with each condition containing a list of flattened sample windows
            decoding_dict = {}

            for condition in conditions:
                x = epochs[condition] 
                x = x.get_data() # the shape: (n_trials, n_channels, n_times)
                x = x[:,:,start:start + window_size] # 5 sample is a window size
                x = x.reshape(x.shape[0], -1)
                decoding_dict[condition] = x


            # Dictionary to store decoding results for each pair
            pairwise_decoding_accuracies = {}

            for i in range(n_conditions):
                for j in range(i + 1, n_conditions):

                    cond1 = conditions[i]
                    cond2 = conditions[j]
                        
                    # Classification
                    data_cond1 = decoding_dict[cond1]
                    data_cond2 = decoding_dict[cond2]
                    data = np.vstack((data_cond1, data_cond2))
                    labels = np.hstack((np.zeros(len(data_cond1)), np.ones(len(data_cond2))))

                    # Set cross-validation
                    cv = StratifiedKFold(n_splits=n_splits) # StratifiedKFold ensures that each fold has a proportional representation of both classes, so each fold maintains a 50:50 balance of numerosity 1 and numerosity 2 trials.

                    # Time-resolved decoding storage
                    decoding_accuracies = []

                    # Cross-validation for this time point
                    for train_idx, test_idx in cv.split(data, labels):
                        X_train, X_test = data[train_idx], data[test_idx] # the EEG data for training and testing.
                        y_train, y_test = labels[train_idx], labels[test_idx] # corresponding labels for the training and testing data.
                        
                        clf = SVC(kernel='linear') # initializes a support vector machine (SVM) classifier with a linear kernel.
                        clf.fit(X_train, y_train) # trains the classifier on the training data (X_train) with labels (y_train).
                        y_pred = clf.predict(X_test) 
                        decoding_accuracies.append(accuracy_score(y_test, y_pred)) # calculates the classification accuracy by comparing the true labels (y_test) with the predicted labels (y_pred).

                    avg_accuracy = np.mean(decoding_accuracies)
                    # Store the average accuracy for the condition pair
                    pairwise_decoding_accuracies[(cond1, cond2)] = avg_accuracy

                    print(f"Average accuracy for {cond1} vs {cond2} in time points {start + window_size}: {avg_accuracy:.2f}")


        # Average accuracy for this time point across CV folds
        all_decoding_accuracy.append(pairwise_decoding_accuracies)
        print(f"Time point {start + window_size} is done")



# ~~~~~~~~~~~~~~~~ Accuracy matrix

    # List to store the resulting accuracy matrices
    all_accuracy_matrices = []

    # Iterate through each dictionary in 'all_decoding_accuracy'
    for idx, x in enumerate(all_decoding_accuracy):
        # Extract all unique conditions
        conditions = sorted(set(key[0] for key in x.keys()).union(set(key[1] for key in x.keys())))
        n_conditions = len(conditions)

        # Create a dictionary to map conditions to matrix indices
        condition_idx = {condition: idx for idx, condition in enumerate(conditions)}

        # Initialize a square matrix with NaN values (for easier filling)
        accuracy_matrix = np.full((n_conditions, n_conditions), np.nan)

        # Fill the matrix with accuracies
        for (cond1, cond2), accuracy in x.items(): # e.g., 'cond1' = 'numerosity 1' and 'cond2' = 'numerosity 2'
            i, j = condition_idx[cond1], condition_idx[cond2]
            accuracy_matrix[i, j] = accuracy
            accuracy_matrix[j, i] = accuracy  # Ensuring symmetry

        # Convert to DataFrame for readability
        accuracy_df = pd.DataFrame(accuracy_matrix, index=conditions, columns=conditions)
        
        # Store the DataFrame in the list
        all_accuracy_matrices.append(accuracy_df)

        # Optionally print each matrix to verify (can remove if not needed)
        print(f"Decoding Accuracy Matrix for entry {idx + 1}:")
        print(accuracy_df)
        print("\n")

    # Now 'all_accuracy_matrices' contains 110 DataFrames, each corresponding to an accuracy matrix for a given dictionary.


    # Save the list of accuracy matrices to a pickle file
    save_folder = f"/u/kazma/MINT/data/processed/visual/{subject}"
    save_path = os.path.join(save_folder, "all_accuracy_matrices.pkl")
    with open(save_path, "wb") as f:
        pickle.dump(all_accuracy_matrices, f)
    print(f"{subject}: matrices saved in 'all_accuracy_matrices.pkl'")
# Out:
# Reading /u/kazma/MINT/data/interim/visual/sub-01_ses-01/epochs-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1260 matching events found
# No baseline correction applied
# 0 projection items activated
# Dropped 413 epochs: 154, 155, 201, 202, 269, 316, 322, 323, 337, 338, 339, 340, 381, 382, 383, 384, 385, 386, 389, 390, 391, 392, 393, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 442, 443, 444, 448, 449, 450, 451, 452, 453, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 508, 509, 510, 543, 547, 548, 549, 550, 551, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 607, 608, 609, 610, 612, 613, 617, 618, 621, 622, 623, 624, 625, 626, 627, 628, 629, 633, 634, 635, 636, 637, 638, 671, 672, 673, 675, 676, 677, 678, 680, 681, 682, 683, 696, 697, 698, 699, 700, 701, 727, 728, 729, 730, 731, 735, 736, 737, 747, 748, 749, 750, 767, 768, 769, 770, 771, 772, 773, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 827, 828, 829, 830, 831, 832, 833, 834, 836, 837, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 868, 869, 870, 879, 880, 881, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 904, 905, 906, 907, 908, 909, 910, 911, 912, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1066, 1067, 1068, 1069, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217
# Average accuracy for numerosity 1 vs numerosity 2 in time points 5: 0.47
# Average accuracy for numerosity 1 vs numerosity 3 in time points 5: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 5: 0.46
# Average accuracy for numerosity 1 vs numerosity 5 in time points 5: 0.47
# Average accuracy for numerosity 1 vs numerosity 6 in time points 5: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 5: 0.54
# Average accuracy for numerosity 2 vs numerosity 4 in time points 5: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 5: 0.48
# Average accuracy for numerosity 2 vs numerosity 6 in time points 5: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 5: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 5: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 5: 0.54
# Average accuracy for numerosity 4 vs numerosity 5 in time points 5: 0.55
# Average accuracy for numerosity 4 vs numerosity 6 in time points 5: 0.52
# Average accuracy for numerosity 5 vs numerosity 6 in time points 5: 0.51
# Time point 5 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 10: 0.56
# Average accuracy for numerosity 1 vs numerosity 3 in time points 10: 0.48
# Average accuracy for numerosity 1 vs numerosity 4 in time points 10: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 10: 0.48
# Average accuracy for numerosity 1 vs numerosity 6 in time points 10: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 10: 0.46
# Average accuracy for numerosity 2 vs numerosity 4 in time points 10: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 10: 0.45
# Average accuracy for numerosity 2 vs numerosity 6 in time points 10: 0.54
# Average accuracy for numerosity 3 vs numerosity 4 in time points 10: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 10: 0.47
# Average accuracy for numerosity 3 vs numerosity 6 in time points 10: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 10: 0.52
# Average accuracy for numerosity 4 vs numerosity 6 in time points 10: 0.54
# Average accuracy for numerosity 5 vs numerosity 6 in time points 10: 0.49
# Time point 10 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 15: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 15: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 15: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 15: 0.45
# Average accuracy for numerosity 1 vs numerosity 6 in time points 15: 0.45
# Average accuracy for numerosity 2 vs numerosity 3 in time points 15: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 15: 0.54
# Average accuracy for numerosity 2 vs numerosity 5 in time points 15: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 15: 0.45
# Average accuracy for numerosity 3 vs numerosity 4 in time points 15: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 15: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 15: 0.44
# Average accuracy for numerosity 4 vs numerosity 5 in time points 15: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 15: 0.55
# Average accuracy for numerosity 5 vs numerosity 6 in time points 15: 0.44
# Time point 15 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 20: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 20: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 20: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 20: 0.39
# Average accuracy for numerosity 1 vs numerosity 6 in time points 20: 0.46
# Average accuracy for numerosity 2 vs numerosity 3 in time points 20: 0.59
# Average accuracy for numerosity 2 vs numerosity 4 in time points 20: 0.54
# Average accuracy for numerosity 2 vs numerosity 5 in time points 20: 0.48
# Average accuracy for numerosity 2 vs numerosity 6 in time points 20: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 20: 0.55
# Average accuracy for numerosity 3 vs numerosity 5 in time points 20: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 20: 0.46
# Average accuracy for numerosity 4 vs numerosity 5 in time points 20: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 20: 0.56
# Average accuracy for numerosity 5 vs numerosity 6 in time points 20: 0.45
# Time point 20 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 25: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 25: 0.49
# Average accuracy for numerosity 1 vs numerosity 4 in time points 25: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 25: 0.47
# Average accuracy for numerosity 1 vs numerosity 6 in time points 25: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 25: 0.43
# Average accuracy for numerosity 2 vs numerosity 4 in time points 25: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 25: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 25: 0.41
# Average accuracy for numerosity 3 vs numerosity 4 in time points 25: 0.47
# Average accuracy for numerosity 3 vs numerosity 5 in time points 25: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 25: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 25: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 25: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 25: 0.50
# Time point 25 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 30: 0.48
# Average accuracy for numerosity 1 vs numerosity 3 in time points 30: 0.48
# Average accuracy for numerosity 1 vs numerosity 4 in time points 30: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 30: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 30: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 30: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 30: 0.42
# Average accuracy for numerosity 2 vs numerosity 5 in time points 30: 0.47
# Average accuracy for numerosity 2 vs numerosity 6 in time points 30: 0.53
# Average accuracy for numerosity 3 vs numerosity 4 in time points 30: 0.42
# Average accuracy for numerosity 3 vs numerosity 5 in time points 30: 0.52
# Average accuracy for numerosity 3 vs numerosity 6 in time points 30: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 30: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 30: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 30: 0.53
# Time point 30 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 35: 0.45
# Average accuracy for numerosity 1 vs numerosity 3 in time points 35: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 35: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 35: 0.44
# Average accuracy for numerosity 1 vs numerosity 6 in time points 35: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 35: 0.44
# Average accuracy for numerosity 2 vs numerosity 4 in time points 35: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 35: 0.47
# Average accuracy for numerosity 2 vs numerosity 6 in time points 35: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 35: 0.45
# Average accuracy for numerosity 3 vs numerosity 5 in time points 35: 0.45
# Average accuracy for numerosity 3 vs numerosity 6 in time points 35: 0.48
# Average accuracy for numerosity 4 vs numerosity 5 in time points 35: 0.41
# Average accuracy for numerosity 4 vs numerosity 6 in time points 35: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 35: 0.47
# Time point 35 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 40: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 40: 0.47
# Average accuracy for numerosity 1 vs numerosity 4 in time points 40: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 40: 0.45
# Average accuracy for numerosity 1 vs numerosity 6 in time points 40: 0.49
# Average accuracy for numerosity 2 vs numerosity 3 in time points 40: 0.56
# Average accuracy for numerosity 2 vs numerosity 4 in time points 40: 0.54
# Average accuracy for numerosity 2 vs numerosity 5 in time points 40: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 40: 0.54
# Average accuracy for numerosity 3 vs numerosity 4 in time points 40: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 40: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 40: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 40: 0.46
# Average accuracy for numerosity 4 vs numerosity 6 in time points 40: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 40: 0.52
# Time point 40 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 45: 0.54
# Average accuracy for numerosity 1 vs numerosity 3 in time points 45: 0.47
# Average accuracy for numerosity 1 vs numerosity 4 in time points 45: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 45: 0.48
# Average accuracy for numerosity 1 vs numerosity 6 in time points 45: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 45: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 45: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 45: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 45: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 45: 0.53
# Average accuracy for numerosity 3 vs numerosity 5 in time points 45: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 45: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 45: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 45: 0.53
# Average accuracy for numerosity 5 vs numerosity 6 in time points 45: 0.52
# Time point 45 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 50: 0.47
# Average accuracy for numerosity 1 vs numerosity 3 in time points 50: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 50: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 50: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 50: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 50: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 50: 0.53
# Average accuracy for numerosity 2 vs numerosity 5 in time points 50: 0.48
# Average accuracy for numerosity 2 vs numerosity 6 in time points 50: 0.44
# Average accuracy for numerosity 3 vs numerosity 4 in time points 50: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 50: 0.47
# Average accuracy for numerosity 3 vs numerosity 6 in time points 50: 0.47
# Average accuracy for numerosity 4 vs numerosity 5 in time points 50: 0.56
# Average accuracy for numerosity 4 vs numerosity 6 in time points 50: 0.54
# Average accuracy for numerosity 5 vs numerosity 6 in time points 50: 0.48
# Time point 50 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 55: 0.48
# Average accuracy for numerosity 1 vs numerosity 3 in time points 55: 0.48
# Average accuracy for numerosity 1 vs numerosity 4 in time points 55: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points

#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.436585      0.498171      0.480220
# numerosity 2      0.436585           NaN      0.522300      0.491202
# numerosity 3      0.498171      0.522300           NaN      0.535714
# numerosity 4      0.480220      0.491202      0.535714           NaN
# numerosity 5      0.471603      0.454007      0.462718      0.490941
# numerosity 6      0.484582      0.466812      0.503746      0.517596
#
#               numerosity 5  numerosity 6
# numerosity 1      0.471603      0.484582
# numerosity 2      0.454007      0.466812
# numerosity 3      0.462718      0.503746
# numerosity 4      0.490941      0.517596
# numerosity 5           NaN      0.540418
# numerosity 6      0.540418           NaN
#
#
# Decoding Accuracy Matrix for entry 96:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.443728      0.484059      0.501832
# numerosity 2      0.443728           NaN      0.469338      0.430575
# numerosity 3      0.484059      0.469338           NaN      0.500000
# numerosity 4      0.501832      0.430575      0.500000           NaN
# numerosity 5      0.492596      0.429791      0.518641      0.480226
# numerosity 6      0.469861      0.463676      0.506882      0.517770
#
#               numerosity 5  numerosity 6
# numerosity 1      0.492596      0.469861
# numerosity 2      0.429791      0.463676
# numerosity 3      0.518641      0.506882
# numerosity 4      0.480226      0.517770
# numerosity 5           NaN      0.539983
# numerosity 6      0.539983           NaN
#
#
# Decoding Accuracy Matrix for entry 97:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.439895      0.497997      0.494597
# numerosity 2      0.439895           NaN      0.487195      0.427178
# numerosity 3      0.497997      0.487195           NaN      0.507143
# numerosity 4      0.494597      0.427178      0.507143           NaN
# numerosity 5      0.500000      0.457666      0.530226      0.508624
# numerosity 6      0.470035      0.459930      0.542422      0.514286
#
#               numerosity 5  numerosity 6
# numerosity 1      0.500000      0.470035
# numerosity 2      0.457666      0.459930
# numerosity 3      0.530226      0.542422
# numerosity 4      0.508624      0.514286
# numerosity 5           NaN      0.519077
# numerosity 6      0.519077           NaN
#
#
# Decoding Accuracy Matrix for entry 98:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.492770      0.447909      0.498077
# numerosity 2      0.492770           NaN      0.473345      0.444948
# numerosity 3      0.447909      0.473345           NaN      0.503571
# numerosity 4      0.498077      0.444948      0.503571           NaN
# numerosity 5      0.475348      0.432840      0.512369      0.515679
# numerosity 6      0.469599      0.477526      0.542770      0.560279
#
#               numerosity 5  numerosity 6
# numerosity 1      0.475348      0.469599
# numerosity 2      0.432840      0.477526
# numerosity 3      0.512369      0.542770
# numerosity 4      0.515679      0.560279
# numerosity 5           NaN      0.484408
# numerosity 6      0.484408           NaN
#
#
# Decoding Accuracy Matrix for entry 99:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.468206      0.494774      0.465751
# numerosity 2      0.468206           NaN      0.480488      0.519251
# numerosity 3      0.494774      0.480488           NaN      0.514286
# numerosity 4      0.465751      0.519251      0.514286           NaN
# numerosity 5      0.500697      0.457491      0.504878      0.551307
# numerosity 6      0.512718      0.487805      0.560279      0.538676
#
#               numerosity 5  numerosity 6
# numerosity 1      0.500697      0.512718
# numerosity 2      0.457491      0.487805
# numerosity 3      0.504878      0.560279
# numerosity 4      0.551307      0.538676
# numerosity 5           NaN      0.508624
# numerosity 6      0.508624           NaN
#
#
# Decoding Accuracy Matrix for entry 100:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.539199      0.469338      0.502106
# numerosity 2      0.539199           NaN      0.505488      0.526481
# numerosity 3      0.469338      0.505488           NaN      0.485714
# numerosity 4      0.502106      0.526481      0.485714           NaN
# numerosity 5      0.489808      0.503397      0.561760      0.544338
# numerosity 6      0.494251      0.515767      0.549826      0.560453
#
#               numerosity 5  numerosity 6
# numerosity 1      0.489808      0.494251
# numerosity 2      0.503397      0.515767
# numerosity 3      0.561760      0.549826
# numerosity 4      0.544338      0.560453
# numerosity 5           NaN      0.543641
# numerosity 6      0.543641           NaN
#
#
# Decoding Accuracy Matrix for entry 101:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.549564      0.473345      0.509066
# numerosity 2      0.549564           NaN      0.491289      0.466463
# numerosity 3      0.473345      0.491289           NaN      0.467857
# numerosity 4      0.509066      0.466463      0.467857           NaN
# numerosity 5      0.489634      0.531533      0.554704      0.544251
# numerosity 6      0.494164      0.494686      0.535627      0.510714
#
#               numerosity 5  numerosity 6
# numerosity 1      0.489634      0.494164
# numerosity 2      0.531533      0.494686
# numerosity 3      0.554704      0.535627
# numerosity 4      0.544251      0.510714
# numerosity 5           NaN      0.456359
# numerosity 6      0.456359           NaN
#
#
# Decoding Accuracy Matrix for entry 102:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.528223      0.441463      0.555495
# numerosity 2      0.528223           NaN      0.494599      0.498432
# numerosity 3      0.441463      0.494599           NaN      0.503571
# numerosity 4      0.555495      0.498432      0.503571           NaN
# numerosity 5      0.507143      0.527787      0.497997      0.519338
# numerosity 6      0.498258      0.533798      0.521254      0.542596
#
#               numerosity 5  numerosity 6
# numerosity 1      0.507143      0.498258
# numerosity 2      0.527787      0.533798
# numerosity 3      0.497997      0.521254
# numerosity 4      0.519338      0.542596
# numerosity 5           NaN      0.483972
# numerosity 6      0.483972           NaN
#
#
# Decoding Accuracy Matrix for entry 103:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.485366      0.469948      0.551923
# numerosity 2      0.485366           NaN      0.490854      0.473258
# numerosity 3      0.469948      0.490854           NaN      0.482143
# numerosity 4      0.551923      0.473258      0.482143           NaN
# numerosity 5      0.492509      0.510279      0.463676      0.523258
# numerosity 6      0.512282      0.501481      0.489373      0.514111
#
#               numerosity 5  numerosity 6
# numerosity 1      0.492509      0.512282
# numerosity 2      0.510279      0.501481
# numerosity 3      0.463676      0.489373
# numerosity 4      0.523258      0.514111
# numerosity 5           NaN      0.523171
# numerosity 6      0.523171           NaN
#
#
# Decoding Accuracy Matrix for entry 104:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.499477      0.455488      0.527015
# numerosity 2      0.499477           NaN      0.480401      0.494425
# numerosity 3      0.455488      0.480401           NaN      0.471429
# numerosity 4      0.527015      0.494425      0.471429           NaN
# numerosity 5      0.513415      0.517073      0.466638      0.502003
# numerosity 6      0.497822      0.515418      0.538502      0.557056
#
#               numerosity 5  numerosity 6
# numerosity 1      0.513415      0.497822
# numerosity 2      0.517073      0.515418
# numerosity 3      0.466638      0.538502
# numerosity 4      0.502003      0.557056
# numerosity 5           NaN      0.505226
# numerosity 6      0.505226           NaN
#
#
# Decoding Accuracy Matrix for entry 105:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.520732      0.473345      0.537912
# numerosity 2      0.520732           NaN      0.473258      0.555052
# numerosity 3      0.473345      0.473258           NaN      0.435714
# numerosity 4      0.537912      0.555052      0.435714           NaN
# numerosity 5      0.474129      0.481707      0.509408      0.470035
# numerosity 6      0.518902      0.508101      0.553136      0.514286
#
#               numerosity 5  numerosity 6
# numerosity 1      0.474129      0.518902
# numerosity 2      0.481707      0.508101
# numerosity 3      0.509408      0.553136
# numerosity 4      0.470035      0.514286
# numerosity 5           NaN      0.551045
# numerosity 6      0.551045           NaN
#
#
# Decoding Accuracy Matrix for entry 106:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.517422      0.476829      0.508883
# numerosity 2      0.517422           NaN      0.540244      0.498258
# numerosity 3      0.476829      0.540244           NaN      0.510714
# numerosity 4      0.508883      0.498258      0.510714           NaN
# numerosity 5      0.466986      0.453920      0.491028      0.491376
# numerosity 6      0.448693      0.501829      0.471690      0.507143
#
#               numerosity 5  numerosity 6
# numerosity 1      0.466986      0.448693
# numerosity 2      0.453920      0.501829
# numerosity 3      0.491028      0.471690
# numerosity 4      0.491376      0.507143
# numerosity 5           NaN      0.529617
# numerosity 6      0.529617           NaN
#
#
# Decoding Accuracy Matrix for entry 107:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.531533      0.466028      0.487454
# numerosity 2      0.531533           NaN      0.469599      0.501742
# numerosity 3      0.466028      0.469599           NaN      0.482143
# numerosity 4      0.487454      0.501742      0.482143           NaN
# numerosity 5      0.509843      0.478659      0.487631      0.530575
# numerosity 6      0.469774      0.487369      0.489460      0.521603
#
#               numerosity 5  numerosity 6
# numerosity 1      0.509843      0.469774
# numerosity 2      0.478659      0.487369
# numerosity 3      0.487631      0.489460
# numerosity 4      0.530575      0.521603
# numerosity 5           NaN      0.522735
# numerosity 6      0.522735           NaN
#
#
# Decoding Accuracy Matrix for entry 108:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.535453      0.498345      0.516484
# numerosity 2      0.535453           NaN      0.445035      0.555226
# numerosity 3      0.498345      0.445035           NaN      0.539286
# numerosity 4      0.516484      0.555226      0.539286           NaN
# numerosity 5      0.485714      0.468206      0.494512      0.512718
# numerosity 6      0.480662      0.501481      0.478310      0.500436
#
#               numerosity 5  numerosity 6
# numerosity 1      0.485714      0.480662
# numerosity 2      0.468206      0.501481
# numerosity 3      0.494512      0.478310
# numerosity 4      0.512718      0.500436
# numerosity 5           NaN      0.498258
# numerosity 6      0.498258           NaN
#
#
# Decoding Accuracy Matrix for entry 109:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.517683      0.455488      0.494597
# numerosity 2      0.517683           NaN      0.423868      0.469774
# numerosity 3      0.455488      0.423868           NaN      0.532143
# numerosity 4      0.494597      0.469774      0.532143           NaN
# numerosity 5      0.471603      0.454443      0.476481      0.495122
# numerosity 6      0.516028      0.473258      0.405052      0.529094
#
#               numerosity 5  numerosity 6
# numerosity 1      0.471603      0.516028
# numerosity 2      0.454443      0.473258
# numerosity 3      0.476481      0.405052
# numerosity 4      0.495122      0.529094
# numerosity 5           NaN      0.490767
# numerosity 6      0.490767           NaN
#
#
# Decoding Accuracy Matrix for entry 110:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.535627      0.502178      0.505220
# numerosity 2      0.535627           NaN      0.413066      0.483885
# numerosity 3      0.502178      0.413066           NaN      0.478571
# numerosity 4      0.505220      0.483885      0.478571           NaN
# numerosity 5      0.482317      0.479617      0.480226      0.480836
# numerosity 6      0.455314      0.473345      0.492770      0.560627
#
#               numerosity 5  numerosity 6
# numerosity 1      0.482317      0.455314
# numerosity 2      0.479617      0.473345
# numerosity 3      0.480226      0.492770
# numerosity 4      0.480836      0.560627
# numerosity 5           NaN      0.487544
# numerosity 6      0.487544           NaN
#
#
# Decoding Accuracy Matrix for entry 111:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.535627      0.502178      0.505220
# numerosity 2      0.535627           NaN      0.413066      0.483885
# numerosity 3      0.502178      0.413066           NaN      0.478571
# numerosity 4      0.505220      0.483885      0.478571           NaN
# numerosity 5      0.482317      0.479617      0.480226      0.480836
# numerosity 6      0.455314      0.473345      0.492770      0.560627
#
#               numerosity 5  numerosity 6
# numerosity 1      0.482317      0.455314
# numerosity 2      0.479617      0.473345
# numerosity 3      0.480226      0.492770
# numerosity 4      0.480836      0.560627
# numerosity 5           NaN      0.487544
# numerosity 6      0.487544           NaN
#
#
# sub-01_ses-01: matrices saved in 'all_accuracy_matrices.pkl'

# %% [markdown]
# ### accuracy matrix visualization

# %%
# Select matrices to visualize (for example, the first 5 matrices)
num_matrices_to_plot = 5  # Adjust as needed
selected_matrices = all_accuracy_matrices[0:5]

# Plot each selected accuracy matrix
fig, axes = plt.subplots(1, num_matrices_to_plot, figsize=(5 * num_matrices_to_plot, 5))
for i, accuracy_df in enumerate(selected_matrices):
    mask = np.triu(np.ones_like(accuracy_df, dtype=bool))
    sns.heatmap(accuracy_df, ax=axes[i], annot=True, cmap="coolwarm", cbar=False, square=True,
                vmin=0, vmax=1, mask=mask)
    axes[i].set_title(f"Window {i + 1} (10ms)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### averaged matrix time series

# %%
# List to store average accuracy values for each matrix
average_accuracies = []

# Loop through each accuracy matrix in 'all_accuracy_matrices'
for accuracy_df in all_accuracy_matrices:
    # Convert the DataFrame to a NumPy array, ignore NaN values, and calculate the mean
    matrix_values = accuracy_df.to_numpy()
    avg_accuracy = np.nanmean(matrix_values)  # np.nanmean ignores NaN values
    average_accuracies.append(avg_accuracy)

# Display the average accuracies
print("Average accuracy for each matrix:", average_accuracies)

# Plot time-resolved decoding accuracy
# Figure
time_vector = np.arange(min_time, max_time+2, 2*window_size)

plt.figure(figsize=(8, 4))
plt.plot(time_vector, average_accuracies, color='darkmagenta', alpha = 0.1, linewidth=3)
plt.plot(time_vector, average_accuracies, color='darkmagenta', alpha = 1, linewidth=1)
plt.axhline(0.5, color='black', linestyle='--', linewidth=1)  # 50% chance line
plt.axvline(0, color='black', linestyle='-', linewidth=1)  # Add a vertical line at t=0
plt.xlabel("Time (ms)")
plt.ylabel("Decoding Accuracy")
plt.title("Time-Resolved Decoding")

plt.xlim(-50, 900)  # Set x-axis limits
plt.ylim(0.4, 0.7)  # Set x-axis limits

# Set the box line color to gray
ax = plt.gca()
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.spines['left'].set_color('gray')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Average accuracy for each matrix: [0.502989368355222, 0.49822225200273984, 0.4906046934095715, 0.4963999821316894, 0.4898091068822776, 0.490766699425236, 0.47502918490723367, 0.50420486018047, 0.5077164299115517, 0.5038958873105214, 0.4972126924565949, 0.5068486256291134, 0.5067071681705829, 0.5097501414574586, 0.5096401024449804, 0.5050402036987404, 0.5022237112481015, 0.5000701331189136, 0.5097379314452486, 0.5015329521427083, 0.4991229637571101, 0.4992504243723756, 0.49827541022662974, 0.4986877214925996, 0.4959821614699664, 0.4841697191697191, 0.4892452127817981, 0.4930779653950386, 0.4932699008308764, 0.49249173590637, 0.5010637600881503, 0.4989896959409155, 0.4998904076952858, 0.4960347240835045, 0.5058372792519134, 0.5031476518061885, 0.5078866255695524, 0.49460525923940557, 0.49354283927454656, 0.5005872718067841, 0.5031638821882723, 0.5106725929896662, 0.4999414812829447, 0.5136406682748146, 0.5080654575776526, 0.5070326692277911, 0.5155805711903273, 0.5065329521427083, 0.501590726346824, 0.5057896304237768, 0.5057080318055929, 0.5158721224574883, 0.5183582000655171, 0.5166450757914173, 0.524816403109086, 0.5039046725632093, 0.5166060633133804, 0.5156569582179338, 0.5094882218052951, 0.5171363054289884, 0.5214226153250544, 0.5285477530599483, 0.5259925846511212, 0.5259635486464754, 0.5167643467643468, 0.5153149289734656, 0.5094958158372793, 0.5167551148038952, 0.509989725721433, 0.5063932815152328, 0.49672980136394773, 0.5023099258465112, 0.5051107835254176, 0.5073392596563328, 0.5018282259745674, 0.5006484707704221, 0.5018410315971292, 0.48886804252657906, 0.5040832067661336, 0.5116493939664672, 0.5039960987521963, 0.5129101521784448, 0.4968764704130557, 0.4922884838738497, 0.49696328062181716, 0.497567229518449, 0.4944484648143185, 0.48438428779892195, 0.48350069984216326, 0.4796789660204294, 0.4767756633610292, 0.49423791655498966, 0.49927946037702137, 0.49901262693945625, 0.4904409005628517, 0.48326379582477147, 0.49041796956431105, 0.4887626194943268, 0.5043485511778194, 0.5194377438279878, 0.5046171714464397, 0.5102617707495756, 0.49890869293308326, 0.502759164954287, 0.5051174841418744, 0.49430879418684304, 0.49574317281634356, 0.5006749754310731, 0.48035989755501957, 0.4874095416778344, 0.4874095416778344]

# %% [markdown]
# # Concept response curve

# %%
# Define the data
categories = ['0%', '10%', '20%', '30%', '40%', '50%']
accuracies = [72, 65, 60, 55, 53, 50]  # Example accuracy values for each category

# Create the bar plot
plt.figure(figsize=(6, 4))
plt.plot(categories, accuracies, color='darkmagenta', alpha = 0.1, linewidth=4)
plt.plot(categories, accuracies, color='darkmagenta', alpha = 1, linewidth=2)

# Add circles at each data point
plt.scatter(categories, accuracies, color='darkmagenta', edgecolor='black', s=100, zorder=5)

# Add title and labels
plt.title('Concept response curve', size = 20)
plt.xlabel('Proprtions of incorrect labeling', size = 15)
plt.ylabel('Classification accuracy (%)', size = 15)
plt.axhline(50, color='black', linestyle='--', linewidth=1)  # 50% chance line
plt.ylim(46, 80)  # Setting y-axis limit to 0-1 for percentage scale

# Show the plot
plt.show()
