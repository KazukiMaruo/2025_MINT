# %%
# ~~~~~~~~~~~~~~ Libraries
import sys, os
import mne # Python package for processing and analyzing electrophysiological data
import numpy as np
from glob import glob # look for all the pathnames matching a specified pattern according to the rules
import matplotlib.pyplot as plt
from mne.preprocessing import ICA # ICA (Independent Component Analysis) algorithm, which is for artifact removal
import json
import re
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from scipy.stats import permutation_test
import matplotlib.pyplot as plt
from itertools import combinations
import pandas as pd
import seaborn as sns
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
# ~~~~~~~~~~~~~~ Libraries ~~~~~~~~~~~~~~

# %%
# ~~~~~~~~~~~~~~ Parameters
group = 'adult'
modality = 'visual' # 'visual' or 'audio'
subject = 'sub-04'

# ML parameters
window_size = 1 # 1 sample = 2ms, 5 samples = 10 ms
n_splits = 10
clf = LogisticRegression(max_iter=2000)

# Print out each parameter
print(f"{modality} data of {subject} is processed")
print("Machine learning parameters:")
print(f"  Window size: {window_size} samples ({window_size * 2} ms)")
print(f"  Classifier: {clf.__class__.__name__}")
# ~~~~~~~~~~~~~~ Parameters ~~~~~~~~~~~~~~
# Out:
# visual data of sub-04 is processed
# Machine learning parameters:
#   Window size: 1 samples (2 ms)
#   Classifier: LogisticRegression

# %%
# ~~~~~~~~~~~~~~ Set the working directory
path = f"/u/kazma/MINT/data/{group}/interim/{modality}"
sub_folders = [f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]
sub_folders_sorted = sorted(sub_folders, key=lambda x: int(re.search(r'\d+', x).group())) # Sort the folders based on the numeric part after "sub-"
# ~~~~~~~~~~~~~~ Set the working directory ~~~~~~~~~~~~~~

# %%
# ~~~~~~~~~~~~~~ Concatanating 3 sessions
each_sub_path = f"/u/kazma/MINT/data/{group}/interim/{modality}/{subject}"
each_sub_folders = [f for f in os.listdir(each_sub_path) if os.path.isdir(os.path.join(each_sub_path, f))]
each_sub_folders_sorted = sorted(each_sub_folders, key=lambda x: int(re.search(r'\d+', x).group()))

eegdata_dict = {}
for x,ses_loop in enumerate(each_sub_folders_sorted):
    sub_filename = os.path.join(path, subject, ses_loop, 'epochs-epo.fif') 
    epochs = mne.read_epochs(sub_filename, preload=True)
    eegdata_dict[ses_loop] = epochs

# concatanate all 3 sessions into 1 epoch
epochs = mne.concatenate_epochs([eegdata_dict['ses-01'], eegdata_dict['ses-02'], eegdata_dict['ses-03']])
# ~~~~~~~~~~~~~~ Concatanating 3 sessions ~~~~~~~~~~~~~~
# Out:
# Reading /u/kazma/MINT/data/adult/interim/visual/sub-04/ses-01/epochs-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1260 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /u/kazma/MINT/data/adult/interim/visual/sub-04/ses-02/epochs-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1260 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /u/kazma/MINT/data/adult/interim/visual/sub-04/ses-03/epochs-epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1260 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 3780 matching events found
# Applying baseline correction (mode: mean)
# /tmp/ipykernel_3051033/3591973489.py:12: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   epochs = mne.concatenate_epochs([eegdata_dict['ses-01'], eegdata_dict['ses-02'], eegdata_dict['ses-03']])

# %%
# Get the info about the data
conditions = list(epochs.event_id.keys()) # list of conditions
n_conditions = len(conditions) # number of conditions
n_trials = len(epochs) # number of trials
n_samples = epochs.get_data().shape[2]
min_time = epochs.times[0]*1000   # First time point in milli seconds
max_time = epochs.times[-1]*1000    # Last time point in milli seconds

# list for avg accuracy for each time window
all_decoding_accuracy = []

# %%
# ~~~~~~~~~~~~~~ Time point loop
for timepoint in range(n_samples): # Loop over the each time point

    # Initialize the decoding dictionary with each condition containing a list of flattened sample windows
    decoding_dict = {}

    for condition in conditions:
        x = epochs[condition] 
        x = x.get_data() # the shape: (n_trials, n_channels, n_times)
        x = x[:,:,timepoint] # extract one time point = 31 (channels) * 210 (trials)
        decoding_dict[condition] = x

    # Dictionary to store decoding results for each pair
    pairwise_decoding_accuracies = {}

    for i in range(n_conditions):
        for j in range(i + 1, n_conditions):

            cond1 = conditions[i]
            cond2 = conditions[j]
                
            # Prepare data
            data_cond1 = decoding_dict[cond1]
            data_cond2 = decoding_dict[cond2]
            data = np.vstack((data_cond1, data_cond2))
            labels = np.hstack((np.zeros(len(data_cond1)), np.ones(len(data_cond2))))

            # Set cross-validation
            cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42) # StratifiedKFold ensures that each fold has a proportional representation of both classes, so each fold maintains a 50:50 balance of numerosity 1 and numerosity 2 trials.

            # Time-resolved decoding storage
            decoding_accuracies = []

            # Cross-validation
            for train_idx, test_idx in cv.split(data, labels):
                X_train, X_test = data[train_idx], data[test_idx] # the EEG data for training and testing.
                y_train, y_test = labels[train_idx], labels[test_idx] # corresponding labels for the training and testing data.

                # standardization
                scaler = StandardScaler()
                X_train = scaler.fit_transform(X_train) # get mean and standard deviation from this
                X_test = scaler.transform(X_test) # get mean and standard deviation from this

                # Train logistic regression
                clf = LogisticRegression(max_iter=2000)
                clf.fit(X_train, y_train) # trains the classifier on the training data (X_train) with labels (y_train).
                accuracy = clf.score(X_test, y_test)
                decoding_accuracies.append(accuracy) # calculates the classification accuracy by comparing the true labels (y_test) with the predicted labels (y_pred).

            # average the accuracy within a time point
            avg_accuracy = np.mean(decoding_accuracies)

            # Store the average accuracy for the condition pair
            pairwise_decoding_accuracies[(cond1, cond2)] = avg_accuracy

            print(f"Average accuracy for {cond1} vs {cond2} in time points {timepoint}: {avg_accuracy:.2f}")

    # Average accuracy for this time point across CV folds
    all_decoding_accuracy.append(pairwise_decoding_accuracies)
    print(f"Time point {timepoint} is done")
# ~~~~~~~~~~~~~~ WINDOW_LOOP
# Out:
# Average accuracy for numerosity 1 vs numerosity 2 in time points 0: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 0: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 0: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 0: 0.48
# Average accuracy for numerosity 1 vs numerosity 6 in time points 0: 0.47
# Average accuracy for numerosity 2 vs numerosity 3 in time points 0: 0.47
# Average accuracy for numerosity 2 vs numerosity 4 in time points 0: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 0: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 0: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 0: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 0: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 0: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 0: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 0: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 0: 0.50
# Time point 0 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 1: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 1: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 1: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 1: 0.48
# Average accuracy for numerosity 1 vs numerosity 6 in time points 1: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 1: 0.48
# Average accuracy for numerosity 2 vs numerosity 4 in time points 1: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 1: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 1: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 1: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 1: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 1: 0.47
# Average accuracy for numerosity 4 vs numerosity 5 in time points 1: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 1: 0.48
# Average accuracy for numerosity 5 vs numerosity 6 in time points 1: 0.50
# Time point 1 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 2: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 2: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 2: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 2: 0.49
# Average accuracy for numerosity 1 vs numerosity 6 in time points 2: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 2: 0.48
# Average accuracy for numerosity 2 vs numerosity 4 in time points 2: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 2: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 2: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 2: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 2: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 2: 0.48
# Average accuracy for numerosity 4 vs numerosity 5 in time points 2: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 2: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 2: 0.50
# Time point 2 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 3: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 3: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 3: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 3: 0.49
# Average accuracy for numerosity 1 vs numerosity 6 in time points 3: 0.47
# Average accuracy for numerosity 2 vs numerosity 3 in time points 3: 0.48
# Average accuracy for numerosity 2 vs numerosity 4 in time points 3: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 3: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 3: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 3: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 3: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 3: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 3: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 3: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 3: 0.49
# Time point 3 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 4: 0.49
# Average accuracy for numerosity 1 vs numerosity 3 in time points 4: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 4: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 4: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 4: 0.46
# Average accuracy for numerosity 2 vs numerosity 3 in time points 4: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 4: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 4: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 4: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 4: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 4: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 4: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 4: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 4: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 4: 0.49
# Time point 4 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 5: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 5: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 5: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 5: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 5: 0.47
# Average accuracy for numerosity 2 vs numerosity 3 in time points 5: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 5: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 5: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 5: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 5: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 5: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 5: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 5: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 5: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 5: 0.48
# Time point 5 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 6: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 6: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 6: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 6: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 6: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 6: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 6: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 6: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 6: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 6: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 6: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 6: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 6: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 6: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 6: 0.48
# Time point 6 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 7: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 7: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 7: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 7: 0.53
# Average accuracy for numerosity 1 vs numerosity 6 in time points 7: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 7: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 7: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 7: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 7: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 7: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 7: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 7: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 7: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 7: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 7: 0.49
# Time point 7 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 8: 0.48
# Average accuracy for numerosity 1 vs numerosity 3 in time points 8: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 8: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 8: 0.53
# Average accuracy for numerosity 1 vs numerosity 6 in time points 8: 0.49
# Average accuracy for numerosity 2 vs numerosity 3 in time points 8: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 8: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 8: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 8: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 8: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 8: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 8: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 8: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 8: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 8: 0.49
# Time point 8 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 9: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 9: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 9: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 9: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 9: 0.48
# Average accuracy for numerosity 2 vs numerosity 3 in time points 9: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 9: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 9: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 9: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 9: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 9: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 9: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 9: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 9: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 9: 0.49
# Time point 9 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 10: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 10: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 10: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 10: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 10: 0.49
# Average accuracy for numerosity 2 vs numerosity 3 in time points 10: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 10: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 10: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 10: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 10: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 10: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 10: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 10: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 10: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 10: 0.50
# Time point 10 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 11: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 11: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 11: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 11: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 11: 0.49
# Average accuracy for numerosity 2 vs numerosity 3 in time points 11: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 11: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 11: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 11: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 11: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 11: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 11: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 11: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 11: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 11: 0.51
# Time point 11 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 12: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 12: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 12: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 12: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 12: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 12: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 12: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 12: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 12: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 12: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 12: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 12: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 12: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 12: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 12: 0.51
# Time point 12 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 13: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 13: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 13: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 13: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 13: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 13: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 13: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 13: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 13: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 13: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 13: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 13: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 13: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 13: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 13: 0.52
# Time point 13 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 14: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 14: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 14: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 14: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 14: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 14: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 14: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 14: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 14: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 14: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 14: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 14: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 14: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 14: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 14: 0.52
# Time point 14 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 15: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 15: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 15: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 15: 0.53
# Average accuracy for numerosity 1 vs numerosity 6 in time points 15: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 15: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 15: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 15: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 15: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 15: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 15: 0.52
# Average accuracy for numerosity 3 vs numerosity 6 in time points 15: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 15: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 15: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 15: 0.51
# Time point 15 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 16: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 16: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 16: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 16: 0.53
# Average accuracy for numerosity 1 vs numerosity 6 in time points 16: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 16: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 16: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 16: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 16: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 16: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 16: 0.52
# Average accuracy for numerosity 3 vs numerosity 6 in time points 16: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 16: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 16: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 16: 0.51
# Time point 16 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 17: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 17: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 17: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 17: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 17: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 17: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 17: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 17: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 17: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 17: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 17: 0.52
# Average accuracy for numerosity 3 vs numerosity 6 in time points 17: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 17: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 17: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 17: 0.52
# Time point 17 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 18: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 18: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 18: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 18: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 18: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 18: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 18: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 18: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 18: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 18: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 18: 0.52
# Average accuracy for numerosity 3 vs numerosity 6 in time points 18: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 18: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 18: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 18: 0.53
# Time point 18 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 19: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 19: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 19: 0.51
# Average accuracy for numerosity 1 vs numerosity 5 in time points 19: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 19: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 19: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 19: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 19: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 19: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 19: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 19: 0.53
# Average accuracy for numerosity 3 vs numerosity 6 in time points 19: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 19: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 19: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 19: 0.53
# Time point 19 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 20: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 20: 0.49
# Average accuracy for numerosity 1 vs numerosity 4 in time points 20: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 20: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 20: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 20: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 20: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 20: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 20: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 20: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 20: 0.52
# Average accuracy for numerosity 3 vs numerosity 6 in time points 20: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 20: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 20: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 20: 0.54
# Time point 20 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 21: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 21: 0.49
# Average accuracy for numerosity 1 vs numerosity 4 in time points 21: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 21: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 21: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 21: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 21: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 21: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 21: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 21: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 21: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 21: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 21: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 21: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 21: 0.53
# Time point 21 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 22: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 22: 0.49
# Average accuracy for numerosity 1 vs numerosity 4 in time points 22: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 22: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 22: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 22: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 22: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 22: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 22: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 22: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 22: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 22: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 22: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 22: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 22: 0.52
# Time point 22 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 23: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 23: 0.50
# Average accuracy for numerosity 1 vs numerosity 4 in time points 23: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 23: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 23: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 23: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 23: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 23: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 23: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 23: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 23: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 23: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 23: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 23: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 23: 0.52
# Time point 23 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 24: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 24: 0.51
# Average accuracy for numerosity 1 vs numerosity 4 in time points 24: 0.50
# Average accuracy for numerosity 1 vs numerosity 5 in time points 24: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 24: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 24: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 24: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 24: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 24: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 24: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 24: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 24: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 24: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 24: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 24: 0.51
# Time point 24 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 25: 0.49
# Average accuracy for numerosity 1 vs numerosity 3 in time points 25: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 25: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 25: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 25: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 25: 0.48
# Average accuracy for numerosity 2 vs numerosity 4 in time points 25: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 25: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 25: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 25: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 25: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 25: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 25: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 25: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 25: 0.50
# Time point 25 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 26: 0.48
# Average accuracy for numerosity 1 vs numerosity 3 in time points 26: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 26: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 26: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 26: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 26: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 26: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 26: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 26: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 26: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 26: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 26: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 26: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 26: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 26: 0.50
# Time point 26 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 27: 0.48
# Average accuracy for numerosity 1 vs numerosity 3 in time points 27: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 27: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 27: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 27: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 27: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 27: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 27: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 27: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 27: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 27: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 27: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 27: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 27: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 27: 0.51
# Time point 27 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 28: 0.47
# Average accuracy for numerosity 1 vs numerosity 3 in time points 28: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 28: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 28: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 28: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 28: 0.48
# Average accuracy for numerosity 2 vs numerosity 4 in time points 28: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 28: 0.48
# Average accuracy for numerosity 2 vs numerosity 6 in time points 28: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 28: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 28: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 28: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 28: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 28: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 28: 0.51
# Time point 28 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 29: 0.47
# Average accuracy for numerosity 1 vs numerosity 3 in time points 29: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 29: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 29: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 29: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 29: 0.48
# Average accuracy for numerosity 2 vs numerosity 4 in time points 29: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 29: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 29: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 29: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 29: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 29: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 29: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 29: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 29: 0.51
# Time point 29 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 30: 0.48
# Average accuracy for numerosity 1 vs numerosity 3 in time points 30: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 30: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 30: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 30: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 30: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 30: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 30: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 30: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 30: 0.52
# Average accuracy for numerosity 3 vs numerosity 5 in time points 30: 0.48
# Average accuracy for numerosity 3 vs numerosity 6 in time points 30: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 30: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 30: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 30: 0.51
# Time point 30 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 31: 0.49
# Average accuracy for numerosity 1 vs numerosity 3 in time points 31: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 31: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 31: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 31: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 31: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 31: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 31: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 31: 0.46
# Average accuracy for numerosity 3 vs numerosity 4 in time points 31: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 31: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 31: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 31: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 31: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 31: 0.50
# Time point 31 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 32: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 32: 0.56
# Average accuracy for numerosity 1 vs numerosity 4 in time points 32: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 32: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 32: 0.51
# Average accuracy for numerosity 2 vs numerosity 3 in time points 32: 0.49
# Average accuracy for numerosity 2 vs numerosity 4 in time points 32: 0.48
# Average accuracy for numerosity 2 vs numerosity 5 in time points 32: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 32: 0.45
# Average accuracy for numerosity 3 vs numerosity 4 in time points 32: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 32: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 32: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 32: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 32: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 32: 0.49
# Time point 32 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 33: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 33: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 33: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 33: 0.52
# Average accuracy for numerosity 1 vs numerosity 6 in time points 33: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 33: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 33: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 33: 0.52
# Average accuracy for numerosity 2 vs numerosity 6 in time points 33: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 33: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 33: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 33: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 33: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 33: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 33: 0.48
# Time point 33 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 34: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 34: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 34: 0.49
# Average accuracy for numerosity 1 vs numerosity 5 in time points 34: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 34: 0.50
# Average accuracy for numerosity 2 vs numerosity 3 in time points 34: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 34: 0.49
# Average accuracy for numerosity 2 vs numerosity 5 in time points 34: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 34: 0.47
# Average accuracy for numerosity 3 vs numerosity 4 in time points 34: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 34: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 34: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 34: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 34: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 34: 0.48
# Time point 34 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 35: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 35: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 35: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 35: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 35: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 35: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 35: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 35: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 35: 0.48
# Average accuracy for numerosity 3 vs numerosity 4 in time points 35: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 35: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 35: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 35: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 35: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 35: 0.49
# Time point 35 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 36: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 36: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 36: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 36: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 36: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 36: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 36: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 36: 0.51
# Average accuracy for numerosity 2 vs numerosity 6 in time points 36: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 36: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 36: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 36: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 36: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 36: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 36: 0.49
# Time point 36 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 37: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 37: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 37: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 37: 0.51
# Average accuracy for numerosity 1 vs numerosity 6 in time points 37: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 37: 0.50
# Average accuracy for numerosity 2 vs numerosity 4 in time points 37: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 37: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 37: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 37: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 37: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 37: 0.49
# Average accuracy for numerosity 4 vs numerosity 5 in time points 37: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 37: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 37: 0.49
# Time point 37 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 38: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 38: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 38: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 38: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 38: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 38: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 38: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 38: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 38: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 38: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 38: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 38: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 38: 0.47
# Average accuracy for numerosity 4 vs numerosity 6 in time points 38: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 38: 0.51
# Time point 38 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 39: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 39: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 39: 0.47
# Average accuracy for numerosity 1 vs numerosity 5 in time points 39: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 39: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 39: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 39: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 39: 0.50
# Average accuracy for numerosity 2 vs numerosity 6 in time points 39: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 39: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 39: 0.51
# Average accuracy for numerosity 3 vs numerosity 6 in time points 39: 0.50
# Average accuracy for numerosity 4 vs numerosity 5 in time points 39: 0.48
# Average accuracy for numerosity 4 vs numerosity 6 in time points 39: 0.51
# Average accuracy for numerosity 5 vs numerosity 6 in time points 39: 0.51
# Time point 39 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 40: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 40: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 40: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 40: 0.50
# Average accuracy for numerosity 1 vs numerosity 6 in time points 40: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 40: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 40: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 40: 0.48
# Average accuracy for numerosity 2 vs numerosity 6 in time points 40: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 40: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 40: 0.50
# Average accuracy for numerosity 3 vs numerosity 6 in time points 40: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 40: 0.47
# Average accuracy for numerosity 4 vs numerosity 6 in time points 40: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 40: 0.51
# Time point 40 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 41: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 41: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 41: 0.48
# Average accuracy for numerosity 1 vs numerosity 5 in time points 41: 0.49
# Average accuracy for numerosity 1 vs numerosity 6 in time points 41: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 41: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 41: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 41: 0.49
# Average accuracy for numerosity 2 vs numerosity 6 in time points 41: 0.49
# Average accuracy for numerosity 3 vs numerosity 4 in time points 41: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 41: 0.49
# Average accuracy for numerosity 3 vs numerosity 6 in time points 41: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 41: 0.47
# Average accuracy for numerosity 4 vs numerosity 6 in time points 41: 0.50
# Average accuracy for numerosity 5 vs numerosity 6 in time points 41: 0.51
# Time point 41 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 42: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 42: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 42: 0.46
# Average accuracy for numerosity 1 vs numerosity 5 in time points 42: 0.48
# Average accuracy for numerosity 1 vs numerosity 6 in time points 42: 0.52
# Average accuracy for numerosity 2 vs numerosity 3 in time points 42: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 42: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 42: 0.49
# ...
# Average accuracy for numerosity 1 vs numerosity 3 in time points 537: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 537: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 537: 0.56
# Average accuracy for numerosity 1 vs numerosity 6 in time points 537: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 537: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 537: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 537: 0.53
# Average accuracy for numerosity 2 vs numerosity 6 in time points 537: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 537: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 537: 0.54
# Average accuracy for numerosity 3 vs numerosity 6 in time points 537: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 537: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 537: 0.46
# Average accuracy for numerosity 5 vs numerosity 6 in time points 537: 0.50
# Time point 537 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 538: 0.49
# Average accuracy for numerosity 1 vs numerosity 3 in time points 538: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 538: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 538: 0.56
# Average accuracy for numerosity 1 vs numerosity 6 in time points 538: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 538: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 538: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 538: 0.54
# Average accuracy for numerosity 2 vs numerosity 6 in time points 538: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 538: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 538: 0.53
# Average accuracy for numerosity 3 vs numerosity 6 in time points 538: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 538: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 538: 0.46
# Average accuracy for numerosity 5 vs numerosity 6 in time points 538: 0.50
# Time point 538 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 539: 0.50
# Average accuracy for numerosity 1 vs numerosity 3 in time points 539: 0.52
# Average accuracy for numerosity 1 vs numerosity 4 in time points 539: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 539: 0.56
# Average accuracy for numerosity 1 vs numerosity 6 in time points 539: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 539: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 539: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 539: 0.54
# Average accuracy for numerosity 2 vs numerosity 6 in time points 539: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 539: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 539: 0.53
# Average accuracy for numerosity 3 vs numerosity 6 in time points 539: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 539: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 539: 0.46
# Average accuracy for numerosity 5 vs numerosity 6 in time points 539: 0.50
# Time point 539 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 540: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 540: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 540: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 540: 0.57
# Average accuracy for numerosity 1 vs numerosity 6 in time points 540: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 540: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 540: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 540: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 540: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 540: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 540: 0.54
# Average accuracy for numerosity 3 vs numerosity 6 in time points 540: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 540: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 540: 0.46
# Average accuracy for numerosity 5 vs numerosity 6 in time points 540: 0.50
# Time point 540 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 541: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 541: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 541: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 541: 0.57
# Average accuracy for numerosity 1 vs numerosity 6 in time points 541: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 541: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 541: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 541: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 541: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 541: 0.48
# Average accuracy for numerosity 3 vs numerosity 5 in time points 541: 0.54
# Average accuracy for numerosity 3 vs numerosity 6 in time points 541: 0.53
# Average accuracy for numerosity 4 vs numerosity 5 in time points 541: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 541: 0.47
# Average accuracy for numerosity 5 vs numerosity 6 in time points 541: 0.50
# Time point 541 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 542: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 542: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 542: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 542: 0.57
# Average accuracy for numerosity 1 vs numerosity 6 in time points 542: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 542: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 542: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 542: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 542: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 542: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 542: 0.54
# Average accuracy for numerosity 3 vs numerosity 6 in time points 542: 0.53
# Average accuracy for numerosity 4 vs numerosity 5 in time points 542: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 542: 0.47
# Average accuracy for numerosity 5 vs numerosity 6 in time points 542: 0.50
# Time point 542 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 543: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 543: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 543: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 543: 0.57
# Average accuracy for numerosity 1 vs numerosity 6 in time points 543: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 543: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 543: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 543: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 543: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 543: 0.49
# Average accuracy for numerosity 3 vs numerosity 5 in time points 543: 0.53
# Average accuracy for numerosity 3 vs numerosity 6 in time points 543: 0.53
# Average accuracy for numerosity 4 vs numerosity 5 in time points 543: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 543: 0.48
# Average accuracy for numerosity 5 vs numerosity 6 in time points 543: 0.50
# Time point 543 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 544: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 544: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 544: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 544: 0.56
# Average accuracy for numerosity 1 vs numerosity 6 in time points 544: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 544: 0.53
# Average accuracy for numerosity 2 vs numerosity 4 in time points 544: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 544: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 544: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 544: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 544: 0.54
# Average accuracy for numerosity 3 vs numerosity 6 in time points 544: 0.53
# Average accuracy for numerosity 4 vs numerosity 5 in time points 544: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 544: 0.47
# Average accuracy for numerosity 5 vs numerosity 6 in time points 544: 0.50
# Time point 544 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 545: 0.51
# Average accuracy for numerosity 1 vs numerosity 3 in time points 545: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 545: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 545: 0.57
# Average accuracy for numerosity 1 vs numerosity 6 in time points 545: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 545: 0.53
# Average accuracy for numerosity 2 vs numerosity 4 in time points 545: 0.52
# Average accuracy for numerosity 2 vs numerosity 5 in time points 545: 0.56
# Average accuracy for numerosity 2 vs numerosity 6 in time points 545: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 545: 0.50
# Average accuracy for numerosity 3 vs numerosity 5 in time points 545: 0.54
# Average accuracy for numerosity 3 vs numerosity 6 in time points 545: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 545: 0.49
# Average accuracy for numerosity 4 vs numerosity 6 in time points 545: 0.48
# Average accuracy for numerosity 5 vs numerosity 6 in time points 545: 0.50
# Time point 545 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 546: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 546: 0.53
# Average accuracy for numerosity 1 vs numerosity 4 in time points 546: 0.54
# Average accuracy for numerosity 1 vs numerosity 5 in time points 546: 0.57
# Average accuracy for numerosity 1 vs numerosity 6 in time points 546: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 546: 0.53
# Average accuracy for numerosity 2 vs numerosity 4 in time points 546: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 546: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 546: 0.53
# Average accuracy for numerosity 3 vs numerosity 4 in time points 546: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 546: 0.55
# Average accuracy for numerosity 3 vs numerosity 6 in time points 546: 0.51
# Average accuracy for numerosity 4 vs numerosity 5 in time points 546: 0.50
# Average accuracy for numerosity 4 vs numerosity 6 in time points 546: 0.48
# Average accuracy for numerosity 5 vs numerosity 6 in time points 546: 0.51
# Time point 546 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 547: 0.52
# Average accuracy for numerosity 1 vs numerosity 3 in time points 547: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 547: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 547: 0.56
# Average accuracy for numerosity 1 vs numerosity 6 in time points 547: 0.54
# Average accuracy for numerosity 2 vs numerosity 3 in time points 547: 0.53
# Average accuracy for numerosity 2 vs numerosity 4 in time points 547: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 547: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 547: 0.52
# Average accuracy for numerosity 3 vs numerosity 4 in time points 547: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 547: 0.53
# Average accuracy for numerosity 3 vs numerosity 6 in time points 547: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 547: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 547: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 547: 0.51
# Time point 547 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 548: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 548: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 548: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 548: 0.56
# Average accuracy for numerosity 1 vs numerosity 6 in time points 548: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 548: 0.51
# Average accuracy for numerosity 2 vs numerosity 4 in time points 548: 0.51
# Average accuracy for numerosity 2 vs numerosity 5 in time points 548: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 548: 0.51
# Average accuracy for numerosity 3 vs numerosity 4 in time points 548: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 548: 0.53
# Average accuracy for numerosity 3 vs numerosity 6 in time points 548: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 548: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 548: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 548: 0.51
# Time point 548 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 549: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 549: 0.55
# Average accuracy for numerosity 1 vs numerosity 4 in time points 549: 0.53
# Average accuracy for numerosity 1 vs numerosity 5 in time points 549: 0.56
# Average accuracy for numerosity 1 vs numerosity 6 in time points 549: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 549: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 549: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 549: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 549: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 549: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 549: 0.53
# Average accuracy for numerosity 3 vs numerosity 6 in time points 549: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 549: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 549: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 549: 0.52
# Time point 549 is done
# Average accuracy for numerosity 1 vs numerosity 2 in time points 550: 0.53
# Average accuracy for numerosity 1 vs numerosity 3 in time points 550: 0.54
# Average accuracy for numerosity 1 vs numerosity 4 in time points 550: 0.52
# Average accuracy for numerosity 1 vs numerosity 5 in time points 550: 0.56
# Average accuracy for numerosity 1 vs numerosity 6 in time points 550: 0.53
# Average accuracy for numerosity 2 vs numerosity 3 in time points 550: 0.52
# Average accuracy for numerosity 2 vs numerosity 4 in time points 550: 0.50
# Average accuracy for numerosity 2 vs numerosity 5 in time points 550: 0.55
# Average accuracy for numerosity 2 vs numerosity 6 in time points 550: 0.50
# Average accuracy for numerosity 3 vs numerosity 4 in time points 550: 0.51
# Average accuracy for numerosity 3 vs numerosity 5 in time points 550: 0.53
# Average accuracy for numerosity 3 vs numerosity 6 in time points 550: 0.52
# Average accuracy for numerosity 4 vs numerosity 5 in time points 550: 0.51
# Average accuracy for numerosity 4 vs numerosity 6 in time points 550: 0.49
# Average accuracy for numerosity 5 vs numerosity 6 in time points 550: 0.52
# Time point 550 is done

# %%
# ~~~~~~~~~~~~~~~~ Save the decoding accuracy
save_folder = f"/u/kazma/MINT/data/{group}/processed/{modality}/{subject}"
save_path = os.path.join(save_folder, "accuracy_pairwise.pkl") #  a pickle file
with open(save_path, "wb") as f:
    pickle.dump(all_decoding_accuracy, f)
print(f"{subject}: saved in 'accuracy_pairwise.pkl'")
# ~~~~~~~~~~~~~~~~ Save the decoding accuracy ~~~~~~~~~~~~~~~~
# Out:
# sub-04: saved in 'accuracy_pairwise.pkl'

# %%
# ~~~~~~~~~~~~~~~~ Generate Accuracy matrix

all_accuracy_matrices = [] # List to store the resulting accuracy matrices


# ~~~~~~~~~~~~~~~~  CONDITION_LOOP
for idx, x in enumerate(all_decoding_accuracy):
    # Extract all unique conditions
    conditions = sorted(set(key[0] for key in x.keys()).union(set(key[1] for key in x.keys())))
    n_conditions = len(conditions)

    # Create a dictionary to map conditions to matrix indices
    condition_idx = {condition: idx for idx, condition in enumerate(conditions)}

    # Initialize a square matrix with NaN values (for easier filling)
    accuracy_matrix = np.full((n_conditions, n_conditions), np.nan)

    # Fill the matrix with accuracies
    for (cond1, cond2), accuracy in x.items(): # e.g., 'cond1' = 'numerosity 1' and 'cond2' = 'numerosity 2'
        i, j = condition_idx[cond1], condition_idx[cond2]
        accuracy_matrix[i, j] = accuracy
        accuracy_matrix[j, i] = accuracy  # Ensuring symmetry

    # Convert to DataFrame for readability
    accuracy_df = pd.DataFrame(accuracy_matrix, index=conditions, columns=conditions)
    
    # Store the DataFrame in the list
    all_accuracy_matrices.append(accuracy_df)

    # Optionally print each matrix to verify (can remove if not needed)
    print(f"Decoding Accuracy Matrix for entry {idx + 1}:")
    print(accuracy_df)
    print("\n")
# Out:
# Decoding Accuracy Matrix for entry 1:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.496825      0.515079      0.496825
# numerosity 2      0.496825           NaN      0.474603      0.480159
# numerosity 3      0.515079      0.474603           NaN      0.511905
# numerosity 4      0.496825      0.480159      0.511905           NaN
# numerosity 5      0.482540      0.519841      0.498413      0.493651
# numerosity 6      0.473016      0.496825      0.487302      0.487302
#
#               numerosity 5  numerosity 6
# numerosity 1      0.482540      0.473016
# numerosity 2      0.519841      0.496825
# numerosity 3      0.498413      0.487302
# numerosity 4      0.493651      0.487302
# numerosity 5           NaN      0.500000
# numerosity 6      0.500000           NaN
#
#
# Decoding Accuracy Matrix for entry 2:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.497619      0.519841      0.489683
# numerosity 2      0.497619           NaN      0.475397      0.486508
# numerosity 3      0.519841      0.475397           NaN      0.514286
# numerosity 4      0.489683      0.486508      0.514286           NaN
# numerosity 5      0.479365      0.518254      0.496825      0.496825
# numerosity 6      0.480159      0.483333      0.472222      0.480159
#
#               numerosity 5  numerosity 6
# numerosity 1      0.479365      0.480159
# numerosity 2      0.518254      0.483333
# numerosity 3      0.496825      0.472222
# numerosity 4      0.496825      0.480159
# numerosity 5           NaN      0.501587
# numerosity 6      0.501587           NaN
#
#
# Decoding Accuracy Matrix for entry 3:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.497619      0.513492      0.488095
# numerosity 2      0.497619           NaN      0.478571      0.489683
# numerosity 3      0.513492      0.478571           NaN      0.508730
# numerosity 4      0.488095      0.489683      0.508730           NaN
# numerosity 5      0.487302      0.519841      0.493651      0.490476
# numerosity 6      0.476984      0.483333      0.478571      0.496032
#
#               numerosity 5  numerosity 6
# numerosity 1      0.487302      0.476984
# numerosity 2      0.519841      0.483333
# numerosity 3      0.493651      0.478571
# numerosity 4      0.490476      0.496032
# numerosity 5           NaN      0.500000
# numerosity 6      0.500000           NaN
#
#
# Decoding Accuracy Matrix for entry 4:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.496825      0.515873      0.488095
# numerosity 2      0.496825           NaN      0.483333      0.489683
# numerosity 3      0.515873      0.483333           NaN      0.507143
# numerosity 4      0.488095      0.489683      0.507143           NaN
# numerosity 5      0.489683      0.510317      0.492063      0.480159
# numerosity 6      0.471429      0.475397      0.491270      0.494444
#
#               numerosity 5  numerosity 6
# numerosity 1      0.489683      0.471429
# numerosity 2      0.510317      0.475397
# numerosity 3      0.492063      0.491270
# numerosity 4      0.480159      0.494444
# numerosity 5           NaN      0.490476
# numerosity 6      0.490476           NaN
#
#
# Decoding Accuracy Matrix for entry 5:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.491270      0.511111      0.484921
# numerosity 2      0.491270           NaN      0.487302      0.492063
# numerosity 3      0.511111      0.487302           NaN      0.505556
# numerosity 4      0.484921      0.492063      0.505556           NaN
# numerosity 5      0.496825      0.496032      0.484127      0.483333
# numerosity 6      0.463492      0.465873      0.495238      0.497619
#
#               numerosity 5  numerosity 6
# numerosity 1      0.496825      0.463492
# numerosity 2      0.496032      0.465873
# numerosity 3      0.484127      0.495238
# numerosity 4      0.483333      0.497619
# numerosity 5           NaN      0.489683
# numerosity 6      0.489683           NaN
#
#
# Decoding Accuracy Matrix for entry 6:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.497619      0.526190      0.498413
# numerosity 2      0.497619           NaN      0.490476      0.490476
# numerosity 3      0.526190      0.490476           NaN      0.510317
# numerosity 4      0.498413      0.490476      0.510317           NaN
# numerosity 5      0.500794      0.504762      0.479365      0.487302
# numerosity 6      0.466667      0.459524      0.504762      0.490476
#
#               numerosity 5  numerosity 6
# numerosity 1      0.500794      0.466667
# numerosity 2      0.504762      0.459524
# numerosity 3      0.479365      0.504762
# numerosity 4      0.487302      0.490476
# numerosity 5           NaN      0.482540
# numerosity 6      0.482540           NaN
#
#
# Decoding Accuracy Matrix for entry 7:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.495238      0.524603      0.491270
# numerosity 2      0.495238           NaN      0.492063      0.486508
# numerosity 3      0.524603      0.492063           NaN      0.511905
# numerosity 4      0.491270      0.486508      0.511905           NaN
# numerosity 5      0.517460      0.492857      0.484921      0.496032
# numerosity 6      0.484127      0.455556      0.507143      0.492063
#
#               numerosity 5  numerosity 6
# numerosity 1      0.517460      0.484127
# numerosity 2      0.492857      0.455556
# numerosity 3      0.484921      0.507143
# numerosity 4      0.496032      0.492063
# numerosity 5           NaN      0.482540
# numerosity 6      0.482540           NaN
#
#
# Decoding Accuracy Matrix for entry 8:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.495238      0.523016      0.483333
# numerosity 2      0.495238           NaN      0.494444      0.483333
# numerosity 3      0.523016      0.494444           NaN      0.508730
# numerosity 4      0.483333      0.483333      0.508730           NaN
# numerosity 5      0.530159      0.489683      0.489683      0.496032
# numerosity 6      0.483333      0.465079      0.501587      0.485714
#
#               numerosity 5  numerosity 6
# numerosity 1      0.530159      0.483333
# numerosity 2      0.489683      0.465079
# numerosity 3      0.489683      0.501587
# numerosity 4      0.496032      0.485714
# numerosity 5           NaN      0.487302
# numerosity 6      0.487302           NaN
#
#
# Decoding Accuracy Matrix for entry 9:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.484921      0.531746      0.483333
# numerosity 2      0.484921           NaN      0.505556      0.481746
# numerosity 3      0.531746      0.505556           NaN      0.507143
# numerosity 4      0.483333      0.481746      0.507143           NaN
# numerosity 5      0.525397      0.495238      0.488889      0.490476
# numerosity 6      0.487302      0.462698      0.499206      0.489683
#
#               numerosity 5  numerosity 6
# numerosity 1      0.525397      0.487302
# numerosity 2      0.495238      0.462698
# numerosity 3      0.488889      0.499206
# numerosity 4      0.490476      0.489683
# numerosity 5           NaN      0.492063
# numerosity 6      0.492063           NaN
#
#
# Decoding Accuracy Matrix for entry 10:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.505556      0.540476      0.484127
# numerosity 2      0.505556           NaN      0.506349      0.487302
# numerosity 3      0.540476      0.506349           NaN      0.510317
# numerosity 4      0.484127      0.487302      0.510317           NaN
# numerosity 5      0.523016      0.500794      0.499206      0.478571
# numerosity 6      0.480952      0.465873      0.498413      0.489683
#
#               numerosity 5  numerosity 6
# numerosity 1      0.523016      0.480952
# numerosity 2      0.500794      0.465873
# numerosity 3      0.499206      0.498413
# numerosity 4      0.478571      0.489683
# numerosity 5           NaN      0.494444
# numerosity 6      0.494444           NaN
#
#
# Decoding Accuracy Matrix for entry 11:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.505556      0.538095      0.473810
# numerosity 2      0.505556           NaN      0.508730      0.496825
# numerosity 3      0.538095      0.508730           NaN      0.519841
# numerosity 4      0.473810      0.496825      0.519841           NaN
# numerosity 5      0.523810      0.502381      0.492857      0.484127
# numerosity 6      0.489683      0.470635      0.486508      0.486508
#
#               numerosity 5  numerosity 6
# numerosity 1      0.523810      0.489683
# numerosity 2      0.502381      0.470635
# numerosity 3      0.492857      0.486508
# numerosity 4      0.484127      0.486508
# numerosity 5           NaN      0.502381
# numerosity 6      0.502381           NaN
#
#
# Decoding Accuracy Matrix for entry 12:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.509524      0.532540      0.480159
# numerosity 2      0.509524           NaN      0.506349      0.512698
# numerosity 3      0.532540      0.506349           NaN      0.502381
# numerosity 4      0.480159      0.512698      0.502381           NaN
# numerosity 5      0.520635      0.504762      0.492857      0.487302
# numerosity 6      0.491270      0.473016      0.491270      0.489683
#
#               numerosity 5  numerosity 6
# numerosity 1      0.520635      0.491270
# numerosity 2      0.504762      0.473016
# numerosity 3      0.492857      0.491270
# numerosity 4      0.487302      0.489683
# numerosity 5           NaN      0.505556
# numerosity 6      0.505556           NaN
#
#
# Decoding Accuracy Matrix for entry 13:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.514286      0.537302      0.473810
# numerosity 2      0.514286           NaN      0.516667      0.515873
# numerosity 3      0.537302      0.516667           NaN      0.504762
# numerosity 4      0.473810      0.515873      0.504762           NaN
# numerosity 5      0.523810      0.513492      0.496032      0.482540
# numerosity 6      0.500794      0.483333      0.496032      0.489683
#
#               numerosity 5  numerosity 6
# numerosity 1      0.523810      0.500794
# numerosity 2      0.513492      0.483333
# numerosity 3      0.496032      0.496032
# numerosity 4      0.482540      0.489683
# numerosity 5           NaN      0.514286
# numerosity 6      0.514286           NaN
#
#
# Decoding Accuracy Matrix for entry 14:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.515079      0.536508      0.493651
# numerosity 2      0.515079           NaN      0.499206      0.519048
# numerosity 3      0.536508      0.499206           NaN      0.492857
# numerosity 4      0.493651      0.519048      0.492857           NaN
# numerosity 5      0.523810      0.513492      0.492063      0.476984
# numerosity 6      0.515079      0.471429      0.516667      0.496825
#
#               numerosity 5  numerosity 6
# numerosity 1      0.523810      0.515079
# numerosity 2      0.513492      0.471429
# numerosity 3      0.492063      0.516667
# numerosity 4      0.476984      0.496825
# numerosity 5           NaN      0.518254
# numerosity 6      0.518254           NaN
#
#
# Decoding Accuracy Matrix for entry 15:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.517460      0.529365      0.488095
# numerosity 2      0.517460           NaN      0.511111      0.517460
# numerosity 3      0.529365      0.511111           NaN      0.481746
# numerosity 4      0.488095      0.517460      0.481746           NaN
# numerosity 5      0.521429      0.497619      0.502381      0.475397
# numerosity 6      0.517460      0.486508      0.511905      0.500000
#
#               numerosity 5  numerosity 6
# numerosity 1      0.521429      0.517460
# numerosity 2      0.497619      0.486508
# numerosity 3      0.502381      0.511905
# numerosity 4      0.475397      0.500000
# numerosity 5           NaN      0.521429
# numerosity 6      0.521429           NaN
#
#
# Decoding Accuracy Matrix for entry 16:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.508730      0.526190      0.495238
# numerosity 2      0.508730           NaN      0.502381      0.520635
# numerosity 3      0.526190      0.502381           NaN      0.479365
# numerosity 4      0.495238      0.520635      0.479365           NaN
# numerosity 5      0.526984      0.502381      0.516667      0.492857
# numerosity 6      0.521429      0.491270      0.511111      0.492857
#
#               numerosity 5  numerosity 6
# numerosity 1      0.526984      0.521429
# numerosity 2      0.502381      0.491270
# numerosity 3      0.516667      0.511111
# numerosity 4      0.492857      0.492857
# numerosity 5           NaN      0.510317
# numerosity 6      0.510317           NaN
#
#
# Decoding Accuracy Matrix for entry 17:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.511905      0.524603      0.502381
# numerosity 2      0.511905           NaN      0.515873      0.519048
# numerosity 3      0.524603      0.515873           NaN      0.479365
# numerosity 4      0.502381      0.519048      0.479365           NaN
# numerosity 5      0.530952      0.500000      0.520635      0.493651
# numerosity 6      0.514286      0.487302      0.507937      0.489683
#
#               numerosity 5  numerosity 6
# numerosity 1      0.530952      0.514286
# numerosity 2      0.500000      0.487302
# numerosity 3      0.520635      0.507937
# numerosity 4      0.493651      0.489683
# numerosity 5           NaN      0.508730
# numerosity 6      0.508730           NaN
#
#
# Decoding Accuracy Matrix for entry 18:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.522222      0.518254      0.513492
# numerosity 2      0.522222           NaN      0.519841      0.512698
# numerosity 3      0.518254      0.519841           NaN      0.484921
# numerosity 4      0.513492      0.512698      0.484921           NaN
# numerosity 5      0.517460      0.509524      0.518254      0.491270
# numerosity 6      0.518254      0.495238      0.503968      0.486508
#
#               numerosity 5  numerosity 6
# numerosity 1      0.517460      0.518254
# numerosity 2      0.509524      0.495238
# numerosity 3      0.518254      0.503968
# numerosity 4      0.491270      0.486508
# numerosity 5           NaN      0.515079
# numerosity 6      0.515079           NaN
#
#
# Decoding Accuracy Matrix for entry 19:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.523016      0.507143      0.512698
# numerosity 2      0.523016           NaN      0.514286      0.507937
# numerosity 3      0.507143      0.514286           NaN      0.491270
# numerosity 4      0.512698      0.507937      0.491270           NaN
# numerosity 5      0.510317      0.508730      0.523016      0.497619
# numerosity 6      0.517460      0.496032      0.492063      0.495238
#
#               numerosity 5  numerosity 6
# numerosity 1      0.510317      0.517460
# numerosity 2      0.508730      0.496032
# numerosity 3      0.523016      0.492063
# numerosity 4      0.497619      0.495238
# numerosity 5           NaN      0.530952
# numerosity 6      0.530952           NaN
#
#
# Decoding Accuracy Matrix for entry 20:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.525397      0.496032      0.510317
# numerosity 2      0.525397           NaN      0.514286      0.512698
# numerosity 3      0.496032      0.514286           NaN      0.481746
# numerosity 4      0.510317      0.512698      0.481746           NaN
# numerosity 5      0.510317      0.507143      0.532540      0.507143
# numerosity 6      0.518254      0.498413      0.490476      0.500000
#
#               numerosity 5  numerosity 6
# numerosity 1      0.510317      0.518254
# numerosity 2      0.507143      0.498413
# numerosity 3      0.532540      0.490476
# numerosity 4      0.507143      0.500000
# numerosity 5           NaN      0.532540
# numerosity 6      0.532540           NaN
#
#
# Decoding Accuracy Matrix for entry 21:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.531746      0.492857      0.502381
# numerosity 2      0.531746           NaN      0.508730      0.507143
# numerosity 3      0.492857      0.508730           NaN      0.490476
# numerosity 4      0.502381      0.507143      0.490476           NaN
# numerosity 5      0.500794      0.506349      0.519841      0.506349
# numerosity 6      0.518254      0.503968      0.489683      0.490476
#
#               numerosity 5  numerosity 6
# numerosity 1      0.500794      0.518254
# numerosity 2      0.506349      0.503968
# numerosity 3      0.519841      0.489683
# numerosity 4      0.506349      0.490476
# numerosity 5           NaN      0.538889
# numerosity 6      0.538889           NaN
#
#
# Decoding Accuracy Matrix for entry 22:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.524603      0.491270      0.496032
# numerosity 2      0.524603           NaN      0.502381      0.509524
# numerosity 3      0.491270      0.502381           NaN      0.495238
# numerosity 4      0.496032      0.509524      0.495238           NaN
# numerosity 5      0.497619      0.507143      0.502381      0.507143
# numerosity 6      0.511111      0.497619      0.494444      0.485714
#
#               numerosity 5  numerosity 6
# numerosity 1      0.497619      0.511111
# numerosity 2      0.507143      0.497619
# numerosity 3      0.502381      0.494444
# numerosity 4      0.507143      0.485714
# numerosity 5           NaN      0.526190
# numerosity 6      0.526190           NaN
#
#
# Decoding Accuracy Matrix for entry 23:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.519048      0.488095      0.501587
# numerosity 2      0.519048           NaN      0.502381      0.501587
# numerosity 3      0.488095      0.502381           NaN      0.503968
# numerosity 4      0.501587      0.501587      0.503968           NaN
# numerosity 5      0.503175      0.495238      0.504762      0.497619
# numerosity 6      0.519048      0.494444      0.502381      0.492063
#
#               numerosity 5  numerosity 6
# numerosity 1      0.503175      0.519048
# numerosity 2      0.495238      0.494444
# numerosity 3      0.504762      0.502381
# numerosity 4      0.497619      0.492063
# numerosity 5           NaN      0.523810
# numerosity 6      0.523810           NaN
#
#
# Decoding Accuracy Matrix for entry 24:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.516667      0.495238      0.503175
# numerosity 2      0.516667           NaN      0.500000      0.503968
# numerosity 3      0.495238      0.500000           NaN      0.508730
# numerosity 4      0.503175      0.503968      0.508730           NaN
# numerosity 5      0.496825      0.487302      0.507937      0.501587
# numerosity 6      0.500794      0.485714      0.504762      0.490476
#
#               numerosity 5  numerosity 6
# numerosity 1      0.496825      0.500794
# numerosity 2      0.487302      0.485714
# numerosity 3      0.507937      0.504762
# numerosity 4      0.501587      0.490476
# numerosity 5           NaN      0.522222
# numerosity 6      0.522222           NaN
#
#
# Decoding Accuracy Matrix for entry 25:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.496825      0.509524      0.500000
# numerosity 2      0.496825           NaN      0.497619      0.504762
# numerosity 3      0.509524      0.497619           NaN      0.493651
# numerosity 4      0.500000      0.504762      0.493651           NaN
# numerosity 5      0.501587      0.487302      0.502381      0.507937
# numerosity 6      0.498413      0.487302      0.511905      0.492857
#
#               numerosity 5  numerosity 6
# numerosity 1      0.501587      0.498413
# numerosity 2      0.487302      0.487302
# numerosity 3      0.502381      0.511905
# numerosity 4      0.507937      0.492857
# numerosity 5           NaN      0.513492
# numerosity 6      0.513492           NaN
#
#
# Decoding Accuracy Matrix for entry 26:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.491270      0.516667      0.488889
# numerosity 2      0.491270           NaN      0.484921      0.513492
# numerosity 3      0.516667      0.484921           NaN      0.496032
# numerosity 4      0.488889      0.513492      0.496032           NaN
# numerosity 5      0.503968      0.491270      0.503968      0.511111
# numerosity 6      0.508730      0.470635      0.523016      0.488095
#
#               numerosity 5  numerosity 6
# numerosity 1      0.503968      0.508730
# numerosity 2      0.491270      0.470635
# numerosity 3      0.503968      0.523016
# numerosity 4      0.511111      0.488095
# numerosity 5           NaN      0.501587
# numerosity 6      0.501587           NaN
#
#
# Decoding Accuracy Matrix for entry 27:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.479365      0.529365      0.474603
# numerosity 2      0.479365           NaN      0.487302      0.503968
# numerosity 3      0.529365      0.487302           NaN      0.500794
# numerosity 4      0.474603      0.503968      0.500794           NaN
# numerosity 5      0.503175      0.493651      0.490476      0.507937
# numerosity 6      0.501587      0.464286      0.519841      0.492063
#
#               numerosity 5  numerosity 6
# numerosity 1      0.503175      0.501587
# numerosity 2      0.493651      0.464286
# numerosity 3      0.490476      0.519841
# numerosity 4      0.507937      0.492063
# numerosity 5           NaN      0.504762
# numerosity 6      0.504762           NaN
#
#
# Decoding Accuracy Matrix for entry 28:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.476984      0.536508      0.474603
# numerosity 2      0.476984           NaN      0.486508      0.493651
# numerosity 3      0.536508      0.486508           NaN      0.504762
# numerosity 4      0.474603      0.493651      0.504762           NaN
# numerosity 5      0.504762      0.489683      0.479365      0.510317
# numerosity 6      0.501587      0.465079      0.519048      0.496825
#
#               numerosity 5  numerosity 6
# numerosity 1      0.504762      0.501587
# numerosity 2      0.489683      0.465079
# numerosity 3      0.479365      0.519048
# numerosity 4      0.510317      0.496825
# numerosity 5           NaN      0.509524
# numerosity 6      0.509524           NaN
#
#
# Decoding Accuracy Matrix for entry 29:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.472222      0.540476      0.473016
# numerosity 2      0.472222           NaN      0.484921      0.494444
# numerosity 3      0.540476      0.484921           NaN      0.513492
# numerosity 4      0.473016      0.494444      0.513492           NaN
# numerosity 5      0.498413      0.481746      0.481746      0.511905
# numerosity 6      0.522222      0.458730      0.512698      0.495238
#
#               numerosity 5  numerosity 6
# numerosity 1      0.498413      0.522222
# numerosity 2      0.481746      0.458730
# numerosity 3      0.481746      0.512698
# numerosity 4      0.511905      0.495238
# numerosity 5           NaN      0.507143
# numerosity 6      0.507143           NaN
#
#
# Decoding Accuracy Matrix for entry 30:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.473016      0.542063      0.480159
# numerosity 2      0.473016           NaN      0.483333      0.492857
# numerosity 3      0.542063      0.483333           NaN      0.523016
# numerosity 4      0.480159      0.492857      0.523016           NaN
# numerosity 5      0.496825      0.487302      0.480952      0.508730
# numerosity 6      0.507937      0.460317      0.507143      0.501587
#
#               numerosity 5  numerosity 6
# numerosity 1      0.496825      0.507937
# numerosity 2      0.487302      0.460317
# numerosity 3      0.480952      0.507143
# numerosity 4      0.508730      0.501587
# numerosity 5           NaN      0.509524
# numerosity 6      0.509524           NaN
#
#
# Decoding Accuracy Matrix for entry 31:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.479365      0.534921      0.480159
# numerosity 2      0.479365           NaN      0.488095      0.483333
# numerosity 3      0.534921      0.488095           NaN      0.522222
# numerosity 4      0.480159      0.483333      0.522222           NaN
# numerosity 5      0.499206      0.495238      0.483333      0.502381
# numerosity 6      0.513492      0.463492      0.514286      0.512698
#
#               numerosity 5  numerosity 6
# numerosity 1      0.499206      0.513492
# numerosity 2      0.495238      0.463492
# numerosity 3      0.483333      0.514286
# numerosity 4      0.502381      0.512698
# numerosity 5           NaN      0.511905
# numerosity 6      0.511905           NaN
#
#
# Decoding Accuracy Matrix for entry 32:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.492857      0.550794      0.484921
# numerosity 2      0.492857           NaN      0.498413      0.484127
# numerosity 3      0.550794      0.498413           NaN      0.506349
# numerosity 4      0.484921      0.484127      0.506349           NaN
# numerosity 5      0.519048      0.495238      0.489683      0.500794
# numerosity 6      0.508730      0.463492      0.501587      0.510317
#
#               numerosity 5  numerosity 6
# numerosity 1      0.519048      0.508730
# numerosity 2      0.495238      0.463492
# numerosity 3      0.489683      0.501587
# numerosity 4      0.500794      0.510317
# numerosity 5           NaN      0.496825
# numerosity 6      0.496825           NaN
#
#
# Decoding Accuracy Matrix for entry 33:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.495238      0.555556      0.489683
# numerosity 2      0.495238           NaN      0.488095      0.482540
# numerosity 3      0.555556      0.488095           NaN      0.508730
# numerosity 4      0.489683      0.482540      0.508730           NaN
# numerosity 5      0.516667      0.501587      0.492857      0.503175
# numerosity 6      0.507143      0.453968      0.505556      0.502381
#
#               numerosity 5  numerosity 6
# numerosity 1      0.516667      0.507143
# numerosity 2      0.501587      0.453968
# numerosity 3      0.492857      0.505556
# numerosity 4      0.503175      0.502381
# numerosity 5           NaN      0.488095
# numerosity 6      0.488095           NaN
#
#
# Decoding Accuracy Matrix for entry 34:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.503175      0.551587      0.487302
# numerosity 2      0.503175           NaN      0.497619      0.489683
# numerosity 3      0.551587      0.497619           NaN      0.504762
# numerosity 4      0.487302      0.489683      0.504762           NaN
# numerosity 5      0.515873      0.517460      0.492857      0.499206
# numerosity 6      0.495238      0.467460      0.491270      0.503175
#
#               numerosity 5  numerosity 6
# numerosity 1      0.515873      0.495238
# numerosity 2      0.517460      0.467460
# numerosity 3      0.492857      0.491270
# numerosity 4      0.499206      0.503175
# numerosity 5           NaN      0.476984
# numerosity 6      0.476984           NaN
#
#
# Decoding Accuracy Matrix for entry 35:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.508730      0.553968      0.492063
# numerosity 2      0.508730           NaN      0.507143      0.486508
# numerosity 3      0.553968      0.507143           NaN      0.491270
# numerosity 4      0.492063      0.486508      0.491270           NaN
# numerosity 5      0.507143      0.509524      0.496825      0.491270
# numerosity 6      0.496825      0.465873      0.495238      0.511905
#
#               numerosity 5  numerosity 6
# numerosity 1      0.507143      0.496825
# numerosity 2      0.509524      0.465873
# numerosity 3      0.496825      0.495238
# numerosity 4      0.491270      0.511905
# numerosity 5           NaN      0.479365
# numerosity 6      0.479365           NaN
#
#
# Decoding Accuracy Matrix for entry 36:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.511905      0.546032      0.483333
# numerosity 2      0.511905           NaN      0.503968      0.498413
# numerosity 3      0.546032      0.503968           NaN      0.496825
# numerosity 4      0.483333      0.498413      0.496825           NaN
# numerosity 5      0.509524      0.511111      0.504762      0.496825
# numerosity 6      0.516667      0.484127      0.490476      0.508730
#
#               numerosity 5  numerosity 6
# numerosity 1      0.509524      0.516667
# numerosity 2      0.511111      0.484127
# numerosity 3      0.504762      0.490476
# numerosity 4      0.496825      0.508730
# numerosity 5           NaN      0.491270
# numerosity 6      0.491270           NaN
#
#
# Decoding Accuracy Matrix for entry 37:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.516667      0.538095      0.474603
# numerosity 2      0.516667           NaN      0.500000      0.501587
# numerosity 3      0.538095      0.500000           NaN      0.496825
# numerosity 4      0.474603      0.501587      0.496825           NaN
# numerosity 5      0.511111      0.506349      0.500794      0.484127
# numerosity 6      0.521429      0.490476      0.491270      0.510317
#
#               numerosity 5  numerosity 6
# numerosity 1      0.511111      0.521429
# numerosity 2      0.506349      0.490476
# numerosity 3      0.500794      0.491270
# numerosity 4      0.484127      0.510317
# numerosity 5           NaN      0.492857
# numerosity 6      0.492857           NaN
#
#
# Decoding Accuracy Matrix for entry 38:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.519048      0.534921      0.478571
# numerosity 2      0.519048           NaN      0.499206      0.502381
# numerosity 3      0.534921      0.499206           NaN      0.493651
# numerosity 4      0.478571      0.502381      0.493651           NaN
# numerosity 5      0.512698      0.504762      0.496032      0.480952
# numerosity 6      0.522222      0.496825      0.492857      0.511905
#
#               numerosity 5  numerosity 6
# numerosity 1      0.512698      0.522222
# numerosity 2      0.504762      0.496825
# numerosity 3      0.496032      0.492857
# numerosity 4      0.480952      0.511905
# numerosity 5           NaN      0.494444
# numerosity 6      0.494444           NaN
#
#
# Decoding Accuracy Matrix for entry 39:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.522222      0.530159      0.470635
# numerosity 2      0.522222           NaN      0.517460      0.505556
# numerosity 3      0.530159      0.517460           NaN      0.496825
# numerosity 4      0.470635      0.505556      0.496825           NaN
# numerosity 5      0.503175      0.500794      0.508730      0.471429
# numerosity 6      0.520635      0.502381      0.503175      0.510317
#
#               numerosity 5  numerosity 6
# numerosity 1      0.503175      0.520635
# numerosity 2      0.500794      0.502381
# numerosity 3      0.508730      0.503175
# numerosity 4      0.471429      0.510317
# numerosity 5           NaN      0.513492
# numerosity 6      0.513492           NaN
#
#
# Decoding Accuracy Matrix for entry 40:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.517460      0.526190      0.474603
# numerosity 2      0.517460           NaN      0.511905      0.506349
# numerosity 3      0.526190      0.511905           NaN      0.503175
# numerosity 4      0.474603      0.506349      0.503175           NaN
# numerosity 5      0.504762      0.502381      0.506349      0.479365
# numerosity 6      0.524603      0.504762      0.503968      0.506349
#
#               numerosity 5  numerosity 6
# numerosity 1      0.504762      0.524603
# numerosity 2      0.502381      0.504762
# numerosity 3      0.506349      0.503968
# numerosity 4      0.479365      0.506349
# numerosity 5           NaN      0.512698
# numerosity 6      0.512698           NaN
#
#
# Decoding Accuracy Matrix for entry 41:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.519048      0.534921      0.479365
# numerosity 2      0.519048           NaN      0.513492      0.509524
# numerosity 3      0.534921      0.513492           NaN      0.503968
# numerosity 4      0.479365      0.509524      0.503968           NaN
# numerosity 5      0.500794      0.482540      0.500794      0.470635
# numerosity 6      0.520635      0.494444      0.510317      0.504762
#
#               numerosity 5  numerosity 6
# numerosity 1      0.500794      0.520635
# numerosity 2      0.482540      0.494444
# numerosity 3      0.500794      0.510317
# numerosity 4      0.470635      0.504762
# numerosity 5           NaN      0.505556
# numerosity 6      0.505556           NaN
#
#
# Decoding Accuracy Matrix for entry 42:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.512698      0.521429      0.477778
# numerosity 2      0.512698           NaN      0.509524      0.502381
# numerosity 3      0.521429      0.509524           NaN      0.503175
# numerosity 4      0.477778      0.502381      0.503175           NaN
# numerosity 5      0.487302      0.489683      0.491270      0.465079
# numerosity 6      0.519048      0.493651      0.505556      0.499206
#
#               numerosity 5  numerosity 6
# numerosity 1      0.487302      0.519048
# numerosity 2      0.489683      0.493651
# numerosity 3      0.491270      0.505556
# numerosity 4      0.465079      0.499206
# numerosity 5           NaN      0.511111
# numerosity 6      0.511111           NaN
#
#
# Decoding Accuracy Matrix for entry 43:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.515873      0.515873      0.460317
# numerosity 2      0.515873           NaN      0.509524      0.507143
# numerosity 3      0.515873      0.509524           NaN      0.497619
# numerosity 4      0.460317      0.507143      0.497619           NaN
# numerosity 5      0.482540      0.486508      0.495238      0.473810
# numerosity 6      0.519841      0.494444      0.505556      0.497619
#
#               numerosity 5  numerosity 6
# numerosity 1      0.482540      0.519841
# numerosity 2      0.486508      0.494444
# numerosity 3      0.495238      0.505556
# numerosity 4      0.473810      0.497619
# numerosity 5           NaN      0.512698
# numerosity 6      0.512698           NaN
#
#
# Decoding Accuracy Matrix for entry 44:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.515873      0.517460      0.449206
# numerosity 2      0.515873           NaN      0.508730      0.508730
# numerosity 3      0.517460      0.508730           NaN      0.499206
# numerosity 4      0.449206      0.508730      0.499206           NaN
# numerosity 5      0.479365      0.481746      0.480159      0.461905
# numerosity 6      0.518254      0.484921      0.499206      0.491270
#
#               numerosity 5  numerosity 6
# numerosity 1      0.479365      0.518254
# numerosity 2      0.481746      0.484921
# numerosity 3      0.480159      0.499206
# numerosity 4      0.461905      0.491270
# numerosity 5           NaN      0.519048
# numerosity 6      0.519048           NaN
#
#
# Decoding Accuracy Matrix for entry 45:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.508730      0.514286      0.452381
# numerosity 2      0.508730           NaN      0.503175      0.502381
# numerosity 3      0.514286      0.503175           NaN      0.502381
# numerosity 4      0.452381      0.502381      0.502381           NaN
# numerosity 5      0.474603      0.489683      0.479365      0.461905
# numerosity 6      0.511111      0.492063      0.500794      0.492063
#
#               numerosity 5  numerosity 6
# numerosity 1      0.474603      0.511111
# numerosity 2      0.489683      0.492063
# numerosity 3      0.479365      0.500794
# numerosity 4      0.461905      0.492063
# numerosity 5           NaN      0.508730
# numerosity 6      0.508730           NaN
#
#
# Decoding Accuracy Matrix for entry 46:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.493651      0.519048      0.478571
# numerosity 2      0.493651           NaN      0.496825      0.500794
# numerosity 3      0.519048      0.496825           NaN      0.500794
# numerosity 4      0.478571      0.500794      0.500794           NaN
# numerosity 5      0.465079      0.492857      0.480952      0.455556
# numerosity 6      0.511905      0.491270      0.502381      0.487302
#
#               numerosity 5  numerosity 6
# numerosity 1      0.465079      0.511905
# numerosity 2      0.492857      0.491270
# numerosity 3      0.480952      0.502381
# numerosity 4      0.455556      0.487302
# numerosity 5           NaN      0.511111
# numerosity 6      0.511111           NaN
#
#
# Decoding Accuracy Matrix for entry 47:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.485714      0.513492      0.485714
# numerosity 2      0.485714           NaN      0.495238      0.500000
# numerosity 3      0.513492      0.495238           NaN      0.506349
# numerosity 4      0.485714      0.500000      0.506349           NaN
# numerosity 5      0.467460      0.499206      0.481746      0.461111
# numerosity 6      0.519841      0.500000      0.503968      0.489683
#
#               numerosity 5  numerosity 6
# numerosity 1      0.467460      0.519841
# numerosity 2      0.499206      0.500000
# numerosity 3      0.481746      0.503968
# numerosity 4      0.461111      0.489683
# numerosity 5           NaN      0.518254
# numerosity 6      0.518254           NaN
#
#
# Decoding Accuracy Matrix for entry 48:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.481746      0.516667      0.499206
# numerosity 2      0.481746           NaN      0.492857      0.504762
# numerosity 3      0.516667      0.492857           NaN      0.506349
# numerosity 4      0.499206      0.504762      0.506349           NaN
# numerosity 5      0.469841      0.503968      0.475397      0.469048
# numerosity 6      0.513492      0.493651      0.511111      0.488095
#
#               numerosity 5  numerosity 6
# numerosity 1      0.469841      0.513492
# numerosity 2      0.503968      0.493651
# numerosity 3      0.475397      0.511111
# numerosity 4      0.469048      0.488095
# numerosity 5           NaN      0.530952
# numerosity 6      0.530952           NaN
#
#
# Decoding Accuracy Matrix for entry 49:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.476984      0.510317      0.487302
# numerosity 2      0.476984           NaN      0.480159      0.514286
# numerosity 3      0.510317      0.480159           NaN      0.507143
# numerosity 4      0.487302      0.514286      0.507143           NaN
# numerosity 5      0.460317      0.507143      0.474603      0.476984
# numerosity 6      0.507143      0.493651      0.500794      0.489683
#
#               numerosity 5  numerosity 6
# numerosity 1      0.460317      0.507143
# numerosity 2      0.507143      0.493651
# numerosity 3      0.474603      0.500794
# numerosity 4      0.476984      0.489683
# numerosity 5           NaN      0.530952
# numerosity 6      0.530952           NaN
#
#
# Decoding Accuracy Matrix for entry 50:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.470635      0.515079      0.493651
# numerosity 2      0.470635           NaN      0.478571      0.512698
# numerosity 3      0.515079      0.478571           NaN      0.512698
# numerosity 4      0.493651      0.512698      0.512698           NaN
# numerosity 5      0.465873      0.505556      0.471429      0.479365
# numerosity 6      0.511111      0.493651      0.499206      0.492857
#
#               numerosity 5  numerosity 6
# numerosity 1      0.465873      0.511111
# numerosity 2      0.505556      0.493651
# numerosity 3      0.471429      0.499206
# numerosity 4      0.479365      0.492857
# numerosity 5           NaN      0.533333
# numerosity 6      0.533333           NaN
#
#
# Decoding Accuracy Matrix for entry 51:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.473016      0.510317      0.499206
# numerosity 2      0.473016           NaN      0.469841      0.523016
# numerosity 3      0.510317      0.469841           NaN      0.517460
# numerosity 4      0.499206      0.523016      0.517460           NaN
# numerosity 5      0.466667      0.516667      0.474603      0.483333
# numerosity 6      0.507937      0.491270      0.502381      0.500794
#
#               numerosity 5  numerosity 6
# numerosity 1      0.466667      0.507937
# numerosity 2      0.516667      0.491270
# numerosity 3      0.474603      0.502381
# numerosity 4      0.483333      0.500794
# numerosity 5           NaN      0.544444
# numerosity 6      0.544444           NaN
#
#
# Decoding Accuracy Matrix for entry 52:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.467460      0.511111      0.500000
# numerosity 2      0.467460           NaN      0.465079      0.523016
# numerosity 3      0.511111      0.465079           NaN      0.514286
# numerosity 4      0.500000      0.523016      0.514286           NaN
# numerosity 5      0.476190      0.508730      0.478571      0.485714
# numerosity 6      0.504762      0.485714      0.496825      0.492063
#
#               numerosity 5  numerosity 6
# numerosity 1      0.476190      0.504762
# numerosity 2      0.508730      0.485714
# numerosity 3      0.478571      0.496825
# numerosity 4      0.485714      0.492063
# numerosity 5           NaN      0.534127
# numerosity 6      0.534127           NaN
#
#
# Decoding Accuracy Matrix for entry 53:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.479365      0.500794      0.497619
# numerosity 2      0.479365           NaN      0.454762      0.515873
# numerosity 3      0.500794      0.454762           NaN      0.519841
# numerosity 4      0.497619      0.515873      0.519841           NaN
# numerosity 5      0.470635      0.505556      0.475397      0.490476
# numerosity 6      0.507143      0.494444      0.492063      0.489683
#
#               numerosity 5  numerosity 6
# numerosity 1      0.470635      0.507143
# numerosity 2      0.505556      0.494444
# numerosity 3      0.475397      0.492063
# numerosity 4      0.490476      0.489683
# numerosity 5           NaN      0.533333
# numerosity 6      0.533333           NaN
#
#
# Decoding Accuracy Matrix for entry 54:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.476190      0.496032      0.501587
# numerosity 2      0.476190           NaN      0.451587      0.505556
# numerosity 3      0.496032      0.451587           NaN      0.515079
# numerosity 4      0.501587      0.505556      0.515079           NaN
# numerosity 5      0.478571      0.493651      0.479365      0.493651
# numerosity 6      0.502381      0.497619      0.496032      0.483333
#
#               numerosity 5  numerosity 6
# numerosity 1      0.478571      0.502381
# numerosity 2      0.493651      0.497619
# numerosity 3      0.479365      0.496032
# numerosity 4      0.493651      0.483333
# numerosity 5           NaN      0.529365
# numerosity 6      0.529365           NaN
#
#
# Decoding Accuracy Matrix for entry 55:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.476190      0.496825      0.496825
# numerosity 2      0.476190           NaN      0.457937      0.500794
# numerosity 3      0.496825      0.457937           NaN      0.502381
# numerosity 4      0.496825      0.500794      0.502381           NaN
# numerosity 5      0.488095      0.490476      0.489683      0.499206
# numerosity 6      0.511905      0.492857      0.496825      0.485714
#
#               numerosity 5  numerosity 6
# numerosity 1      0.488095      0.511905
# numerosity 2      0.490476      0.492857
# numerosity 3      0.489683      0.496825
# numerosity 4      0.499206      0.485714
# numerosity 5           NaN      0.534921
# numerosity 6      0.534921           NaN
#
#
# Decoding Accuracy Matrix for entry 56:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.469048      0.496825      0.491270
# numerosity 2      0.469048           NaN      0.452381      0.492857
# numerosity 3      0.496825      0.452381           NaN      0.511905
# numerosity 4      0.491270      0.492857      0.511905           NaN
# numerosity 5      0.493651      0.503968      0.485714      0.499206
# numerosity 6      0.513492      0.480159      0.500794      0.468254
#
#               numerosity 5  numerosity 6
# numerosity 1      0.493651      0.513492
# numerosity 2      0.503968      0.480159
# numerosity 3      0.485714      0.500794
# numerosity 4      0.499206      0.468254
# numerosity 5           NaN      0.534921
# numerosity 6      0.534921           NaN
#
#
# Decoding Accuracy Matrix for entry 57:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.469841      0.502381      0.496032
# numerosity 2      0.469841           NaN      0.447619      0.497619
# numerosity 3      0.502381      0.447619           NaN      0.502381
# numerosity 4      0.496032      0.497619      0.502381           NaN
# numerosity 5      0.496032      0.515873      0.478571      0.502381
# numerosity 6      0.520635      0.497619      0.495238      0.472222
#
# ...
# numerosity 1           NaN      0.480159      0.527778      0.538889
# numerosity 2      0.480159           NaN      0.502381      0.492063
# numerosity 3      0.527778      0.502381           NaN      0.499206
# numerosity 4      0.538889      0.492063      0.499206           NaN
# numerosity 5      0.564286      0.549206      0.538095      0.511905
# numerosity 6      0.533333      0.511111      0.502381      0.461111
#
#               numerosity 5  numerosity 6
# numerosity 1      0.564286      0.533333
# numerosity 2      0.549206      0.511111
# numerosity 3      0.538095      0.502381
# numerosity 4      0.511905      0.461111
# numerosity 5           NaN      0.500000
# numerosity 6      0.500000           NaN
#
#
# Decoding Accuracy Matrix for entry 534:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.480952      0.529365      0.537302
# numerosity 2      0.480952           NaN      0.503968      0.498413
# numerosity 3      0.529365      0.503968           NaN      0.492063
# numerosity 4      0.537302      0.498413      0.492063           NaN
# numerosity 5      0.564286      0.540476      0.543651      0.503968
# numerosity 6      0.530159      0.503175      0.507143      0.457143
#
#               numerosity 5  numerosity 6
# numerosity 1      0.564286      0.530159
# numerosity 2      0.540476      0.503175
# numerosity 3      0.543651      0.507143
# numerosity 4      0.503968      0.457143
# numerosity 5           NaN      0.500000
# numerosity 6      0.500000           NaN
#
#
# Decoding Accuracy Matrix for entry 535:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.485714      0.525397      0.534127
# numerosity 2      0.485714           NaN      0.502381      0.500794
# numerosity 3      0.525397      0.502381           NaN      0.490476
# numerosity 4      0.534127      0.500794      0.490476           NaN
# numerosity 5      0.561111      0.534127      0.541270      0.507143
# numerosity 6      0.539683      0.498413      0.514286      0.452381
#
#               numerosity 5  numerosity 6
# numerosity 1      0.561111      0.539683
# numerosity 2      0.534127      0.498413
# numerosity 3      0.541270      0.514286
# numerosity 4      0.507143      0.452381
# numerosity 5           NaN      0.494444
# numerosity 6      0.494444           NaN
#
#
# Decoding Accuracy Matrix for entry 536:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.489683      0.521429      0.538889
# numerosity 2      0.489683           NaN      0.498413      0.499206
# numerosity 3      0.521429      0.498413           NaN      0.491270
# numerosity 4      0.538889      0.499206      0.491270           NaN
# numerosity 5      0.563492      0.526190      0.545238      0.500794
# numerosity 6      0.536508      0.500794      0.519048      0.456349
#
#               numerosity 5  numerosity 6
# numerosity 1      0.563492      0.536508
# numerosity 2      0.526190      0.500794
# numerosity 3      0.545238      0.519048
# numerosity 4      0.500794      0.456349
# numerosity 5           NaN      0.494444
# numerosity 6      0.494444           NaN
#
#
# Decoding Accuracy Matrix for entry 537:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.489683      0.527778      0.534127
# numerosity 2      0.489683           NaN      0.500000      0.500794
# numerosity 3      0.527778      0.500000           NaN      0.488889
# numerosity 4      0.534127      0.500794      0.488889           NaN
# numerosity 5      0.566667      0.528571      0.544444      0.500000
# numerosity 6      0.532540      0.503175      0.524603      0.452381
#
#               numerosity 5  numerosity 6
# numerosity 1      0.566667      0.532540
# numerosity 2      0.528571      0.503175
# numerosity 3      0.544444      0.524603
# numerosity 4      0.500000      0.452381
# numerosity 5           NaN      0.503175
# numerosity 6      0.503175           NaN
#
#
# Decoding Accuracy Matrix for entry 538:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.490476      0.528571      0.536508
# numerosity 2      0.490476           NaN      0.511905      0.506349
# numerosity 3      0.528571      0.511905           NaN      0.488095
# numerosity 4      0.536508      0.506349      0.488095           NaN
# numerosity 5      0.556349      0.530159      0.542063      0.503175
# numerosity 6      0.526190      0.500000      0.524603      0.460317
#
#               numerosity 5  numerosity 6
# numerosity 1      0.556349      0.526190
# numerosity 2      0.530159      0.500000
# numerosity 3      0.542063      0.524603
# numerosity 4      0.503175      0.460317
# numerosity 5           NaN      0.500000
# numerosity 6      0.500000           NaN
#
#
# Decoding Accuracy Matrix for entry 539:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.489683      0.528571      0.542857
# numerosity 2      0.489683           NaN      0.508730      0.500794
# numerosity 3      0.528571      0.508730           NaN      0.479365
# numerosity 4      0.542857      0.500794      0.479365           NaN
# numerosity 5      0.557937      0.537302      0.534921      0.501587
# numerosity 6      0.530952      0.507143      0.520635      0.455556
#
#               numerosity 5  numerosity 6
# numerosity 1      0.557937      0.530952
# numerosity 2      0.537302      0.507143
# numerosity 3      0.534921      0.520635
# numerosity 4      0.501587      0.455556
# numerosity 5           NaN      0.499206
# numerosity 6      0.499206           NaN
#
#
# Decoding Accuracy Matrix for entry 540:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.500000      0.524603      0.541270
# numerosity 2      0.500000           NaN      0.510317      0.503968
# numerosity 3      0.524603      0.510317           NaN      0.484127
# numerosity 4      0.541270      0.503968      0.484127           NaN
# numerosity 5      0.562698      0.543651      0.530952      0.499206
# numerosity 6      0.531746      0.510317      0.523810      0.457937
#
#               numerosity 5  numerosity 6
# numerosity 1      0.562698      0.531746
# numerosity 2      0.543651      0.510317
# numerosity 3      0.530952      0.523810
# numerosity 4      0.499206      0.457937
# numerosity 5           NaN      0.496825
# numerosity 6      0.496825           NaN
#
#
# Decoding Accuracy Matrix for entry 541:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.505556      0.529365      0.537302
# numerosity 2      0.505556           NaN      0.512698      0.511905
# numerosity 3      0.529365      0.512698           NaN      0.489683
# numerosity 4      0.537302      0.511905      0.489683           NaN
# numerosity 5      0.565079      0.553968      0.538889      0.496032
# numerosity 6      0.536508      0.507937      0.523016      0.463492
#
#               numerosity 5  numerosity 6
# numerosity 1      0.565079      0.536508
# numerosity 2      0.553968      0.507937
# numerosity 3      0.538889      0.523016
# numerosity 4      0.496032      0.463492
# numerosity 5           NaN      0.498413
# numerosity 6      0.498413           NaN
#
#
# Decoding Accuracy Matrix for entry 542:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.508730      0.526190      0.538889
# numerosity 2      0.508730           NaN      0.519841      0.518254
# numerosity 3      0.526190      0.519841           NaN      0.484921
# numerosity 4      0.538889      0.518254      0.484921           NaN
# numerosity 5      0.567460      0.553968      0.540476      0.505556
# numerosity 6      0.541270      0.514286      0.530952      0.465079
#
#               numerosity 5  numerosity 6
# numerosity 1      0.567460      0.541270
# numerosity 2      0.553968      0.514286
# numerosity 3      0.540476      0.530952
# numerosity 4      0.505556      0.465079
# numerosity 5           NaN      0.496032
# numerosity 6      0.496032           NaN
#
#
# Decoding Accuracy Matrix for entry 543:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.510317      0.531746      0.534921
# numerosity 2      0.510317           NaN      0.523016      0.518254
# numerosity 3      0.531746      0.523016           NaN      0.491270
# numerosity 4      0.534921      0.518254      0.491270           NaN
# numerosity 5      0.567460      0.553968      0.536508      0.500794
# numerosity 6      0.540476      0.517460      0.531746      0.473016
#
#               numerosity 5  numerosity 6
# numerosity 1      0.567460      0.540476
# numerosity 2      0.553968      0.517460
# numerosity 3      0.536508      0.531746
# numerosity 4      0.500794      0.473016
# numerosity 5           NaN      0.501587
# numerosity 6      0.501587           NaN
#
#
# Decoding Accuracy Matrix for entry 544:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.510317      0.527778      0.530952
# numerosity 2      0.510317           NaN      0.522222      0.524603
# numerosity 3      0.527778      0.522222           NaN      0.491270
# numerosity 4      0.530952      0.524603      0.491270           NaN
# numerosity 5      0.565873      0.550794      0.533333      0.503175
# numerosity 6      0.542857      0.523810      0.528571      0.476190
#
#               numerosity 5  numerosity 6
# numerosity 1      0.565873      0.542857
# numerosity 2      0.550794      0.523810
# numerosity 3      0.533333      0.528571
# numerosity 4      0.503175      0.476190
# numerosity 5           NaN      0.500000
# numerosity 6      0.500000           NaN
#
#
# Decoding Accuracy Matrix for entry 545:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.508730      0.530952      0.537302
# numerosity 2      0.508730           NaN      0.532540      0.516667
# numerosity 3      0.530952      0.532540           NaN      0.502381
# numerosity 4      0.537302      0.516667      0.502381           NaN
# numerosity 5      0.562698      0.551587      0.535714      0.493651
# numerosity 6      0.539683      0.521429      0.530952      0.474603
#
#               numerosity 5  numerosity 6
# numerosity 1      0.562698      0.539683
# numerosity 2      0.551587      0.521429
# numerosity 3      0.535714      0.530952
# numerosity 4      0.493651      0.474603
# numerosity 5           NaN      0.502381
# numerosity 6      0.502381           NaN
#
#
# Decoding Accuracy Matrix for entry 546:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.511111      0.534921      0.527778
# numerosity 2      0.511111           NaN      0.530952      0.518254
# numerosity 3      0.534921      0.530952           NaN      0.504762
# numerosity 4      0.527778      0.518254      0.504762           NaN
# numerosity 5      0.570635      0.555556      0.541270      0.494444
# numerosity 6      0.541270      0.523016      0.523810      0.477778
#
#               numerosity 5  numerosity 6
# numerosity 1      0.570635      0.541270
# numerosity 2      0.555556      0.523016
# numerosity 3      0.541270      0.523810
# numerosity 4      0.494444      0.477778
# numerosity 5           NaN      0.503968
# numerosity 6      0.503968           NaN
#
#
# Decoding Accuracy Matrix for entry 547:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.519048      0.534127      0.535714
# numerosity 2      0.519048           NaN      0.530159      0.508730
# numerosity 3      0.534127      0.530159           NaN      0.507143
# numerosity 4      0.535714      0.508730      0.507143           NaN
# numerosity 5      0.567460      0.553968      0.547619      0.497619
# numerosity 6      0.542063      0.525397      0.514286      0.484127
#
#               numerosity 5  numerosity 6
# numerosity 1      0.567460      0.542063
# numerosity 2      0.553968      0.525397
# numerosity 3      0.547619      0.514286
# numerosity 4      0.497619      0.484127
# numerosity 5           NaN      0.507937
# numerosity 6      0.507937           NaN
#
#
# Decoding Accuracy Matrix for entry 548:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.518254      0.544444      0.534127
# numerosity 2      0.518254           NaN      0.526984      0.507143
# numerosity 3      0.544444      0.526984           NaN      0.510317
# numerosity 4      0.534127      0.507143      0.510317           NaN
# numerosity 5      0.559524      0.552381      0.534921      0.505556
# numerosity 6      0.541270      0.521429      0.515079      0.487302
#
#               numerosity 5  numerosity 6
# numerosity 1      0.559524      0.541270
# numerosity 2      0.552381      0.521429
# numerosity 3      0.534921      0.515079
# numerosity 4      0.505556      0.487302
# numerosity 5           NaN      0.511111
# numerosity 6      0.511111           NaN
#
#
# Decoding Accuracy Matrix for entry 549:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.526984      0.542063      0.527778
# numerosity 2      0.526984           NaN      0.511905      0.507143
# numerosity 3      0.542063      0.511905           NaN      0.508730
# numerosity 4      0.527778      0.507143      0.508730           NaN
# numerosity 5      0.560317      0.550000      0.532540      0.514286
# numerosity 6      0.534921      0.511905      0.523810      0.491270
#
#               numerosity 5  numerosity 6
# numerosity 1      0.560317      0.534921
# numerosity 2      0.550000      0.511905
# numerosity 3      0.532540      0.523810
# numerosity 4      0.514286      0.491270
# numerosity 5           NaN      0.506349
# numerosity 6      0.506349           NaN
#
#
# Decoding Accuracy Matrix for entry 550:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.527778      0.547619      0.532540
# numerosity 2      0.527778           NaN      0.518254      0.503968
# numerosity 3      0.547619      0.518254           NaN      0.508730
# numerosity 4      0.532540      0.503968      0.508730           NaN
# numerosity 5      0.557937      0.550794      0.534921      0.508730
# numerosity 6      0.529365      0.503968      0.520635      0.492857
#
#               numerosity 5  numerosity 6
# numerosity 1      0.557937      0.529365
# numerosity 2      0.550794      0.503968
# numerosity 3      0.534921      0.520635
# numerosity 4      0.508730      0.492857
# numerosity 5           NaN      0.517460
# numerosity 6      0.517460           NaN
#
#
# Decoding Accuracy Matrix for entry 551:
#               numerosity 1  numerosity 2  numerosity 3  numerosity 4  \
# numerosity 1           NaN      0.529365      0.543651      0.523810
# numerosity 2      0.529365           NaN      0.518254      0.504762
# numerosity 3      0.543651      0.518254           NaN      0.505556
# numerosity 4      0.523810      0.504762      0.505556           NaN
# numerosity 5      0.559524      0.549206      0.530952      0.514286
# numerosity 6      0.530159      0.503968      0.523016      0.490476
#
#               numerosity 5  numerosity 6
# numerosity 1      0.559524      0.530159
# numerosity 2      0.549206      0.503968
# numerosity 3      0.530952      0.523016
# numerosity 4      0.514286      0.490476
# numerosity 5           NaN      0.515079
# numerosity 6      0.515079           NaN

# %%
# ~~~~~~~~~~~~~~~~ Save the list of accuracy matrices
save_folder = f"/u/kazma/MINT/data/{group}/processed/{modality}/{subject}"
save_path = os.path.join(save_folder, "accuracy_matrices.pkl") #  a pickle file
with open(save_path, "wb") as f:
    pickle.dump(all_accuracy_matrices, f)
print(f"{subject}: matrices saved in 'accuracy_matrices.pkl'")
# ~~~~~~~~~~~~~~~~ Save the list of accuracy matrices ~~~~~~~~~~~~~~~~
# Out:
# sub-04: matrices saved in 'accuracy_matrices.pkl'
